# %% [markdown]
# ## 모델 불러오기

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install transformers;
# !pip install sentencepiece;
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.29.2-py3-none-any.whl (7.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 36.5 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.0)
# Collecting huggingface-hub<1.0,>=0.14.1 (from transformers)
#   Downloading huggingface_hub-0.14.1-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 15.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.27.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 95.7 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (2023.4.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.14.1 tokenizers-0.13.3 transformers-4.29.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 19.0 MB/s eta 0:00:00
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.99

# %%
from transformers import (
    PreTrainedTokenizerFast as BaseGPT2Tokenizer,
    EncoderDecoderModel,
    DataCollatorForSeq2Seq,
)
import pickle
from drive.MyDrive.WARNING_PRIVATE_FOLDER.OSSP2AntiGPT9.ai.tokenization_kobert import KoBertTokenizer
#from drive.MyDrive.WARNING_PRIVATE_FOLDER.OSSP2AntiGPT9.ai.lib import tokenization_kobert
import json
src_tokenizer = KoBertTokenizer.from_pretrained('monologg/kobert')
# Out:
# Downloading (…)zer_78b3253a26.model:   0%|          | 0.00/371k [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/77.8k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/51.0 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/426 [00:00<?, ?B/s]
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'BertTokenizer'.
# The class this function is called from is 'KoBertTokenizer'.

# %%
class GPT2Tokenizer(BaseGPT2Tokenizer):
    def build_inputs_with_special_tokens(self, token_ids, _):
        return token_ids + [self.eos_token_id]
trg_tokenizer = GPT2Tokenizer.from_pretrained("skt/kogpt2-base-v2",
  bos_token='</s>', eos_token='</s>', unk_token='<unk>',
  pad_token='<pad>', mask_token='<mask>')
# Out:
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/2.83M [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.00k [00:00<?, ?B/s]

# %%
# %cd /content/drive/MyDrive/WARNING_PRIVATE_FOLDER/OSSP2AntiGPT9/ai
# with open('/content/drive/MyDrive/WARNING_PRIVATE_FOLDER/OSSP2AntiGPT9/ai/no_commit/save_src_tk.pickle','rb') as f:
#     src_tokenizer = pickle.load(f)
# there's an error in this code when activating in local
# Out:
# /content/drive/MyDrive/WARNING_PRIVATE_FOLDER/OSSP2AntiGPT9/ai

# %%
with open("/content/drive/MyDrive/WARNING_PRIVATE_FOLDER/OSSP2AntiGPT9/ai/kobert_tokenizer_add/added_tokens.json", 'rb') as f:
    dw_dict = json.load(f)
dict_swap = {v:k for k,v in dw_dict.items()}
ma=12290
mi=8002
for i in range(8002,12291):
    src_tokenizer.add_tokens(dict_swap[i])

# %%
model = EncoderDecoderModel.from_pretrained('leadawon/ossp-v0_3')
model.eval()
model.config.decoder_start_token_id = trg_tokenizer.bos_token_id
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/5.27k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/1.02G [00:00<?, ?B/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/132 [00:00<?, ?B/s]

# %% [markdown]
# ## 테스트데이터 불러오기

# %%
def read_input(path):
    with open(path, 'rb') as f:
        test_dict = json.load(f)
    test_standard = []
    test_dialect = []
    for pairs in test_dict['utterance']:
        test_standard.append(pairs['standard_form'])
        test_dialect.append(pairs['dialect_form'])

    return test_standard ,test_dialect

# %%
test_s ,test_d= read_input("/content/drive/MyDrive/WARNING_PRIVATE_FOLDER/OSSP2AntiGPT9/ai/no_commit/test_data_big.json")

# %% [markdown]
# ## 후처리

# %%
import re

# %%
def translate(text, num_beam=1):
    embeddings = src_tokenizer(text, return_attention_mask=False, return_token_type_ids=False, return_tensors='pt')
    embeddings = {k: v for k, v in embeddings.items()}
    output = model.generate(**embeddings, num_beams=num_beam)[0, 1:-1]
    tmp = trg_tokenizer.decode(output.cpu())
    tmp = re.sub('<unk>', '', tmp).strip()
    return tmp

# %%
print("size of full : ",len(test_s))
# Out:
# size of full :  12451

# %%
for i in range(len(test_s)):
    sr_text = test_d[i] # dialect
    tg_text = translate(sr_text) # translate
    print("source_text : ",sr_text)
    print("result :      ",tg_text)
    print("ground_truth :",test_s[i])
    print()
    print()
    if i%50==0:
        print("iteration num : ",i)
    if i==100:
        break
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1255: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed soon, in a future version. Please use a generation configuration file (see https://huggingface.co/docs/transformers/main_classes/text_generation)
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1346: UserWarning: Using `max_length`'s default (20) to control the generation length. This behaviour is deprecated and will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# source_text :  언니 만낭 반가워 아 오늘 제주 방언 에이 아이 데이터
# result :       언니 만나서 반가워 아 오늘 제주 방언 에이 아이 데이터
# ground_truth : 언니 만나서 반가워 아 오늘 제주 방언 에이 아이 데이터
#
#
# iteration num :  0
# source_text :  어 명절 설 명절 추석 명절 요로케 나누어서 해볼 거예
# result :       어 명절 설 명절 추석 명절 이렇게 나누어서 해볼 거예요
# ground_truth : 어 명절 설 명절 추석 명절 요로케 나누어서 해볼 거예요
#
#
# source_text :  자 그믄 이제부터 얘기해 보게예
# result :       자 그러면 이제부터 얘기해 봐요
# ground_truth : 자 그러면 이제부터 얘기해 봐요
#
#
# source_text :  어 그믄 언니네 설 명절 때 음식 어떵 해
# result :       어 그러면 언니네 설 명절 때 음식 어떻게 해
# ground_truth : 어 그러면 언니네 설 명절 때 음식 어떻게 해
#
#
# source_text :  음식을 막 준비했던 기억이 나게
# result :       음식을 막 준비했던 기억이 나겠어요
# ground_truth : 음식을 막 준비했던 기억이 나
#
#
# source_text :  밀가룬지 쌀가룬지를 모르크라  근데 그거를 푹
# result :       밀가루인지 쌀가루인지 모르겠어 근데 그거를 푹
# ground_truth : 밀가룬지 쌀가룬지를 모르겠어  근데 그거를 푹
#
#
# source_text :  반죽을 해그내 날 납작하게
# result :       반죽을 해서 날 납작하게
# ground_truth : 반죽을 해서 날 납작하게
#
#
# source_text :  게 밀어 밀대로 밀어그내
# result :       게 밀어 밀대로 밀어서
# ground_truth : 게 밀어 밀대로 밀어서
#
#
# source_text :  어 방바닥에다 똣똣한 방
# result :       어 방바닥에다 따뜻한 방
# ground_truth : 어 방바닥에다 따뜻한 방
#
#
# source_text :  밀가룬지 쌀가룬지 몰라 근데 이케 떼가지고 이케 밀어그내
# result :       밀가루인지 쌀가루인지 몰라 근데 이렇게 떼가지고 이렇게 밀어서
# ground_truth : 밀가룬지 쌀가룬지 몰라 근데 이케 떼가지고 이케 밀어서
#
#
# source_text :  아니 기름떡하고 달르주게
# result :       아니 기름떡하고 다르지요게
# ground_truth : 아니 기름떡하고 다르지
#
#
# source_text :  과즐을 하는데 그거를 으 밀어그내 인제 바짝 마르잖아
# result :       과즐을 하는데 그거를 으 밀어서 인제 바짝 마르잖아
# ground_truth : 과즐을 하는데 그거를 으 밀어서 인제 바짝 마르잖아
#
#
# source_text :  엿을 확 입혀그내 거기다가 그
# result :       엿을 확 입혀서 거기다가 그
# ground_truth : 엿을 확 입혀서 거기다가 그
#
#
# source_text :  그냥 쌀을 통째로 해가지고 그거에다  이렇게 발라그내 이
# result :       그냥 쌀을 통째로 해가지고 그거에다 이렇게 발라서 이
# ground_truth : 그냥 쌀을 통째로 해가지고 그거에다  이렇게 발라서 이
#
#
# source_text :  해서 만들어내 내가 이러 밥 히 이따만한 소쿠리 담아그내
# result :       해서 만들어서 내가 이러 밥 히 이따만한 소쿠리 담아서
# ground_truth : 해서 만들어내 내가 이러 밥 히 이따만한 소쿠리 담아서
#
#
# source_text :  어 완전 못 좋주게
# result :       어 완전 못 좋지
# ground_truth : 어 완전 못 좋지
#
#
# source_text :  그거 하믄 동네도 나눠줘
# result :       그거 하면 동네도 나눠줘
# ground_truth : 그거 하면 동네도 나눠줘
#
#
# source_text :  설 명질이니까 자기네만 먹캔 하겠다
# result :       설 명질이니까 자기네만 먹겠다고 하겠다
# ground_truth : 설 명절이니까 자기네만 먹겠다고 하겠다
#
#
# source_text :  우리 에 큰 어머니랑 또 작은 어머니랑 이서그내 그냥 다 이
# result :       우리 에 큰어머니랑 또 작은어머니랑 있어서 그냥 다 이
# ground_truth : 우리 에 큰 어머니랑 또 작은 어머니랑 있어서 그냥 다 이
#
#
# source_text :  이케 오빠 와가지고 이 같이 했주게
# result :       이렇게 오빠 와가지고 이 같이 했지 게
# ground_truth : 이케 오빠 와가지고 이 같이 했지
#
#
# source_text :  그다음에 그전에 인제 또 엿 만든댄 이
# result :       그다음에 그전에 인제 또 엿 만든대 이
# ground_truth : 그다음에 그전에 인제 또 엿 만든다고 이
#
#
# source_text :  해갖고 너 엿 만들어 봔
# result :       해갖고 너 엿 만들어 봤어
# ground_truth : 해갖고 너 엿 만들어 봤어
#
#
# source_text :  안 봐봔
# result :       안 봐봤어      봤어
# ground_truth : 안 봤었어
#
#
# source_text :  안 봐봤지
# result :       안 봤지
# ground_truth : 안 봤었지
#
#
# source_text :  엿 만들때 경 해
# result :       엿 만들 때 그렇게 해
# ground_truth : 엿 만들때 그렇게 해
#
#
# source_text :  막 달여 엿기름인가 뭔갈 달여그내 이
# result :       막 달여 엿기름인가 뭔갈 달여서 이
# ground_truth : 막 달여 엿기름인가 뭔갈 달여서 이
#
#
# source_text :  그거를 식혀그내 이렇게
# result :       그거를 식혀서 이렇게
# ground_truth : 그거를 식혀서 이렇게
#
#
# source_text :  게게
# result :       그렇지
# ground_truth : 그렇지
#
#
# source_text :  겅 해서 이렇게 해가지고 딱 잡으면 또 저쪽에서
# result :       그래서 이렇게 해가지고 딱 잡으면 또 저쪽에서
# ground_truth : 그렇게 해서 이렇게 해가지고 딱 잡으면 또 저쪽에서
#
#
# source_text :  탁 잡아가고 영 영 이렇게 이렇게 서로 영
# result :       탁 잡아 가고 이렇게 이렇게 이렇게 이렇게 서로 이렇게
# ground_truth : 탁 잡아가고 이렇게 이렇게 이렇게 이렇게 서로 이렇게
#
#
# source_text :  그렇게 해서 엿도 만들고 이 경 했주게 그니까
# result :       그렇게 해서 엿도 만들고 이 그렇게 했지 그니까
# ground_truth : 그렇게 해서 엿도 만들고 이 그렇게 했지 그니까
#
#
# source_text :  기지 기지
# result :       그렇지 그렇지
# ground_truth : 그렇지 그렇지
#
#
# source_text :  아 식구는 막 우리 그디 그쪽에 우리 또
# result :       아 식구는 막 우리 거기 그쪽에 우리 또
# ground_truth : 아 식구는 막 우리 거기 그쪽에 우리 또
#
#
# source_text :  육 남매에다가 뭐 우리 식구밖에 어시난 이
# result :       육 남매에다가 뭐 우리 식구밖에 없으니까 이
# ground_truth : 육 남매에다가 뭐 우리 식구밖에 없으니까 이
#
#
# source_text :  겅 해신디 우리 큰 집
# result :       그랬는데 우리 큰 집
# ground_truth : 그렇게 했는데 우리 큰 집
#
#
# source_text :  크 나 큰 집에서 우리 할머니도 인제 같이 사셔시난 이
# result :       크 나 큰 집에서 우리 할머니도 인제 같이 사셨으니까 이
# ground_truth : 크 나 큰 집에서 우리 할머니도 인제 같이 사셨으니까 이
#
#
# source_text :  우리 큰 집은 큰 집 나름대로 했던 거 닮아
# result :       우리 큰 집은 큰 집 나름대로 했던 거 같아
# ground_truth : 우리 큰 집은 큰 집 나름대로 했던 거 같아
#
#
# source_text :  이렇게 했주게
# result :       이렇게 했지 게
# ground_truth : 이렇게 했지
#
#
# source_text :  용돈 용돈 할때 세뱃돈 줄 때 어른들은 명절만 되믄
# result :       용돈 용돈 할때 세뱃돈 줄 때 어른들은 명절만 되면
# ground_truth : 용돈 용돈 할때 세뱃돈 줄 때 어른들은 명절만 되면
#
#
# source_text :  세뱃돈 일일이 다 챙기잰 하민
# result :       세뱃돈 일일이 다 챙기려고 하면
# ground_truth : 세뱃돈 일일이 다 챙기려고 하면
#
#
# source_text :  어어어 기주게
# result :       어어어 그렇지
# ground_truth : 어어어 그렇지
#
#
# source_text :  그 봉투에 일일이 이름 적어가멍 누구
# result :       그 봉투에 일일이 이름 적어가면서 누구
# ground_truth : 그 봉투에 일일이 이름 적어가면서 누구
#
#
# source_text :  다 틀리게 담아줘야 되나네
# result :       다 틀리게 담아줘야 되니까
# ground_truth : 다 틀리게 담아줘야 되니까
#
#
# source_text :  것도 식구 많으면 우리 친정집 같은 경우에 식구가
# result :       그것도 식구 많으면 우리 친정집 같은 경우에 식구가
# ground_truth : 그것도 식구 많으면 우리 친정집 같은 경우에 식구가
#
#
# source_text :  세뱃돈 주잰 하면
# result :       세뱃돈 주려고 하면
# ground_truth : 세뱃돈 주려고 하면
#
#
# source_text :  어른 허리 휘켜게
# result :       어른 허리 휘겠다게
# ground_truth : 어른 허리 휘겠어
#
#
# source_text :  아이고 일 년을 모아야 되큰게게
# result :       아이고 일 년을 모아야 되겠네 게
# ground_truth : 아이고 일 년을 모아야 되겠다
#
#
# source_text :  일 년 모아야 되고  겅 하고 또
# result :       일 년 모아야 되고 그렇게 하고 또
# ground_truth : 일 년 모아야 되고  그렇게 하고 또
#
#
# source_text :  경 했잖아 이
# result :       그렇게 했잖아 이
# ground_truth : 그렇게 했잖아 이
#
#
# source_text :  할머니 할아버지가 봉투에 미리 다 담아그내
# result :       할머니 할아버지가 봉투에 미리 다 담아서
# ground_truth : 할머니 할아버지가 봉투에 미리 다 담아서
#
#
# source_text :  아이덜 세배하면 봉투에 담앙
# result :       아이들 세배하면 봉투에 담아서
# ground_truth : 아이들 세배하면 봉투에 담아서
#
#
# iteration num :  50
# source_text :  옷 사입은 거 이 입엉 가그내 세배해그내 세뱃돈 받고
# result :       옷 사입은 거 이 입고 가서 세배해서 세뱃돈 받고
# ground_truth : 옷 사입은 거 이 입고 가서 세배해서 세뱃돈 받고
#
#
# source_text :  아 근데 그게 세월이 많이 바 변해선게
# result :       아 근데 그게 세월이 많이 바 변했더라
# ground_truth : 아 근데 그게 세월이 많이 바 변했더라
#
#
# source_text :  나 때는 우린 우리때는 경 안 핸 그냥
# result :       나 때는 우린 우리때는 그렇게 안 했어 그냥
# ground_truth : 나 때는 우린 우리때는 그렇게 안 했어 그냥
#
#
# source_text :  어어 그래서 하루죙일 세배해 동네에  다니멍이게 해 해도
# result :       어어 그래서 하루종일 세배해 동네에 다니면서게 해 해도
# ground_truth : 어어 그래서 하루죙일 세배해 동네에  다니면서 해 해도
#
#
# source_text :  아 그때 경 해난
# result :       아 그때 그렇게 했었어
# ground_truth : 아 그때 그렇게 했었어
#
#
# source_text :  기지 십 원 이십 원 삼십 원 오십 원 영 줬으니까
# result :       그렇지 십 원 이십 원 삼십 원 오십 원 이렇게 줬으니까
# ground_truth : 그렇지 십 원 이십 원 삼십 원 오십 원 이렇게 줬으니까
#
#
# source_text :  벌써 오십 년 전도 넘었네
# result :       벌써 오십 년 전도 넘었잖아
# ground_truth : 벌써 오십 년 전도 넘었잖아
#
#
# source_text :  봉투가 어딨져게
# result :       봉투가 어디있어게
# ground_truth : 봉투가 어딨어
#
#
# source_text :  야 화장실에 가사 저기 방귀
# result :       야 화장실에 가야 저기 방귀
# ground_truth : 야 화장실에 가야 저기 방귀
#
#
# source_text :  신문 찾아   해그내
# result :       신문 찾아 해서
# ground_truth : 신문 찾아   해서
#
#
# source_text :  했네
# result :       했잖아
# ground_truth : 했잖아
#
#
# source_text :  지나가멍도 그냥 막 인사할려고도 하고 막 겅 하지 안해 이
# result :       지나가면서도 그냥 막 인사할려고도 하고 막 그러지 않아 이
# ground_truth : 지나가면서도 그냥 막 인사할려고도 하고 막 그렇게 하지 않아 이
#
#
# source_text :  응 아이들은 겅 하지 세배허잰 하믄
# result :       응 아이들은 그렇게 하지 세배하려고 하면
# ground_truth : 응 아이들은 그렇게 하지 세배하려고 하면
#
#
# source_text :  게 세뱃돈 받아난 다음에는 또 차례 지내야 되잖아
# result :       게 세뱃돈 받은 다음에는 또 차례 지내야 되잖아
# ground_truth : 게 세뱃돈 받은 다음에는 또 차례 지내야 되잖아
#
#
# source_text :  차례 지낼 때 어떵 해
# result :       차례 지낼 때 어떻게 해
# ground_truth : 차례 지낼 때 어떻게 해
#
#
# source_text :  딸이랜 이 참여를 못 했주게 딸 딸 딸은
# result :       딸이라고 이 참여를 못 했지 딸 딸 딸은
# ground_truth : 딸이라고 이 참여를 못 했지 딸 딸 딸은
#
#
# source_text :  저 상에 그 제사상 올린데 가그내 절 하고
# result :       저 상에 그 제사상 올린 데 가서 절 하고
# ground_truth : 저 상에 그 제사상 올린데 가서 절 하고
#
#
# source_text :  놀기만 했주게 밖에서
# result :       놀기만 했지 밖에서
# ground_truth : 놀기만 했지 밖에서
#
#
# source_text :  어어 겅 했구나
# result :       어어 그랬구나
# ground_truth : 어어 그렇게 했구나
#
#
# source_text :  큰 댁에 있을 때는 뭐 세배만 끝나고 집에와그내 뭐 하고
# result :       큰 댁에 있을 때는 뭐 세배만 끝나고 집에와서 뭐 하고
# ground_truth : 큰 댁에 있을 때는 뭐 세배만 끝나고 집에와서 뭐 하고
#
#
# source_text :  차례를 지내면 옛날에는 목욕을 뭐 자주 해시냐
# result :       차례를 지내면 옛날에는 목욕을 뭐 자주 했냐
# ground_truth : 차례를 지내면 옛날에는 목욕을 뭐 자주 했냐
#
#
# source_text :  그래서 꼭두새벽에 일어나그내
# result :       그래서 꼭두새벽에 일어나서
# ground_truth : 그래서 꼭두새벽에 일어나서
#
#
# source_text :  알 정도로 이 겅 행
# result :       알 정도로 이 그렇게 해서
# ground_truth : 알 정도로 이 그렇게 해서
#
#
# source_text :  때 뿔려그내
# result :       때 불려서
# ground_truth : 때 불려서
#
#
# source_text :  목욕하고 그리고나서 인제 세배 갔다그내 와서
# result :       목욕하고 그리고 나서 이제 세배 갔다가 와서
# ground_truth : 목욕하고 그리고나서 인제 세배 갔다가 와서
#
#
# source_text :  거 저 집에서
# result :       그거 저 집에서
# ground_truth : 그거 저 집에서
#
#
# source_text :  목욕 하 저 아니 그 저 명절 하잰 하 하기 전에는
# result :       목욕 하 저 아니 그 저 명절 하려고 하 하기 전에는
# ground_truth : 목욕 하 저 아니 그 저 명절 하려고 하 하기 전에는
#
#
# source_text :  요새야 겅 잘 안 하주만은 목욕탕 강 일 년 묵은 때
# result :       요새야 그렇게 잘 안 하지만 목욕탕 가서 일 년 묵은 때
# ground_truth : 요새야 그렇게 잘 안 하지만은 목욕탕 가서 일 년 묵은 때
#
#
# source_text :  게니까
# result :       그러니까
# ground_truth : 그러니까
#
#
# source_text :  겅 하여 겅 하잖아
# result :       그렇게 해 그렇게 하잖아
# ground_truth : 그렇게 해 그렇게 하잖아
#
#
# source_text :  겅허고 맹질 옷 같은 것도 사래 맹질 때 되민 옛날에는 그닥
# result :       그리고 명절 옷 같은 것도 사러 명절 때 되면 옛날에는 그닥
# ground_truth : 겅허고 맹질 옷 같은 것도 사러 명절 때 되면 옛날에는 그닥
#
#
# source_text :  나 어릴 때 그추룩 해난
# result :       나 어릴 때 그렇게 했었어
# ground_truth : 나 어릴 때 그렇게 했었어
#
#
# source_text :  그 옷 사래 그날은 진짜 맹질날은 체 곱딱하게 찰령 나가고
# result :       그 옷 사러 그날은 진짜 명절날은 체 예쁘게 차려서 나가고
# ground_truth : 그 옷 사러 그날은 진짜 명절날은 체 예쁘게 차려서 나가고
#
#
# source_text :  1이는 들으면 생소하켜게
# result :       1이는 들으면 생소하겠다게
# ground_truth : 1이는 들으면 생소하겠다
#
#
# source_text :  그치 으응 야네 때야게 친구들이랑 너네
# result :       그치 으응 얘네 때야 친구들이랑 너네
# ground_truth : 그치 으응 얘네 때야 친구들이랑 너네
#
#
# source_text :  맹질 때 되민 야넨 세뱃돈 받으믄 뭐 어디
# result :       명절 때 되면 얘넨 세뱃돈 받으면 뭐 어디
# ground_truth : 명절 때 되면 얘네는 세뱃돈 받으면 뭐 어디
#
#
# source_text :  게 영화보래나 가잰 하고  놀래가잰 하고
# result :       게 영화보러나 가려고하고 놀러가려고하고
# ground_truth : 게 영화보러나 가려고 하고  놀러가려고 하고
#
#
# source_text :  뭐 햄나 이젠
# result :       뭐 하냐 이젠
# ground_truth : 뭐 해 이젠
#
#
# source_text :  촌에 살아나서 그렇게 하고
# result :       촌에 살았었어 그렇게 하고
# ground_truth : 촌에 살았어서 그렇게 하고
#
#
# source_text :   많이 받았구나 오래가는 거 보난
# result :       많이 받았구나 오래가는 거 보니까
# ground_truth :  많이 받았구나 오래가는 거 보니까
#
#
# source_text :  기지  가늘고 길게
# result :       그렇지 가늘고 길게
# ground_truth : 그렇지  가늘고 길게
#
#
# source_text :  어어 겅 해야 쑤
# result :       어어 그렇게 해야 쑤셔
# ground_truth : 어어 그렇게 해야 쑤
#
#
# source_text :  아이덜도 차례 재 일부러 막 세배하래 가멍 또 길 가다가
# result :       아이들도 차례 재 일부러 막 세배하러 가면서 또 길 가다가
# ground_truth : 아이들도 차례 재 일부러 막 세배하러 가면서 또 길 가다가
#
#
# source_text :  애들도 보이고 막 영 하믄 겅 하는디
# result :       애들도 보이고 막 이렇게 하면 그렇게 하는데
# ground_truth : 애들도 보이고 막 이렇게 하면 그렇게 하는데
#
#
# source_text :  어린애들은 안 입었주게
# result :       어린애들은 안 입었지
# ground_truth : 어린애들은 안 입었지
#
#
# source_text :  어린애들은 안 입은디 어른들 남자
# result :       어린애들은 안 입는데 어른들 남자
# ground_truth : 어린애들은 안 입었는데 어른들 남자
#
#
# source_text :  어른들 입주 입주
# result :       어른들 입니다 입니다
# ground_truth : 어른들 입지 입지
#
#
# source_text :  아 언니네 지으 남편도 입언
# result :       아 언니네 지으 남편도 입었어
# ground_truth : 아 언니네 지으 남편도 입었어
#
#
# source_text :  당연히 입주게
# result :       당연히 이죠게
# ground_truth : 당연히 입지
#
#
# source_text :  우리 오빠 맨날 그래 저거 무신 내복만 입고와그내
# result :       우리 오빠 맨날 그래 저거 무슨 내복만 입고와서
# ground_truth : 우리 오빠 맨날 그래 저거 무슨 내복만 입고와서
#
#
# iteration num :  100

# %% [markdown]
# ## scoring

# %%
# !pip install "sacrebleu[ko]"
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sacrebleu[ko]
#   Downloading sacrebleu-2.3.1-py3-none-any.whl (118 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.9/118.9 kB 3.7 MB/s eta 0:00:00
# Collecting portalocker (from sacrebleu[ko])
#   Downloading portalocker-2.7.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from sacrebleu[ko]) (2022.10.31)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.10/dist-packages (from sacrebleu[ko]) (0.8.10)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from sacrebleu[ko]) (1.22.4)
# Collecting colorama (from sacrebleu[ko])
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from sacrebleu[ko]) (4.9.2)
# Collecting mecab-ko==1.0.0 (from sacrebleu[ko])
#   Downloading mecab_ko-1.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (582 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 582.5/582.5 kB 19.0 MB/s eta 0:00:00
# Collecting mecab-ko-dic<2.0,>=1.0 (from sacrebleu[ko])
#   Downloading mecab-ko-dic-1.0.0.tar.gz (33.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.2/33.2 MB 19.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: mecab-ko-dic
#   Building wheel for mecab-ko-dic (setup.py) ... done
#   Created wheel for mecab-ko-dic: filename=mecab_ko_dic-1.0.0-py3-none-any.whl size=33424394 sha256=436fef92faf3034713b081c52cf5d6cdaac4152e3490f2338a1b571636c537f9
#   Stored in directory: /root/.cache/pip/wheels/0d/46/b8/996432c9998690a5a66fb82f6499222e48a23ff5b6c7d80322
# Successfully built mecab-ko-dic
# Installing collected packages: mecab-ko-dic, portalocker, mecab-ko, colorama, sacrebleu
# Successfully installed colorama-0.4.6 mecab-ko-1.0.0 mecab-ko-dic-1.0.0 portalocker-2.7.0 sacrebleu-2.3.1

# %%
from sacrebleu.metrics import BLEU

# %%
def score_B(sr_text, tg_text):

    candidate=[tg_text]
    reference=[[sr_text]]

    bleu = BLEU()

    bleuscore = bleu.corpus_score(candidate,reference).score
    return bleuscore
    #bleu_save.append(bleuscore)

# %%
# def bstest(tn, nb=1):
#     sum_score = 0
#     TEST_NUM = tn
#     for i in range(TEST_NUM):
#         sr_text = test_d[i] # dialect
#         tg_text = translate(sr_text,nb) # translate
#     #print("source_text : ",sr_text)
#     #print("result      : ",tg_text)
#     #print("ground_truth: ",test_s[i])
#         scb = score_B(tg_text.strip(),test_s[i].strip())
#     #print("bleu_socre  :  {:.2f}".format(scb))
#     #print()
#     #print()
#         sum_score += scb
#         if i%100==0:
#             print("iteration num : ",i)
#     print("bleu score mean : {}".format(sum_score/TEST_NUM))

# %%
# bstest(500,4) #60.306662232015825
# bstest(500,3) #60.26833177503664
# bstest(500,2) #60.40712645345418
# bstest(500,1) #60.201772530857795

# %%
# sum_score = 0
# TEST_NUM = 500
# for i in range(TEST_NUM):
#     sr_text = test_d[i] # dialect
#     tg_text = translate(sr_text,4) # translate
#     #print("source_text : ",sr_text)
#     #print("result      : ",tg_text)
#     #print("ground_truth: ",test_s[i])
#     scb = score_B(tg_text.strip(),test_s[i].strip())
#     #print("bleu_socre  :  {:.2f}".format(scb))
#     #print()
#     #print()
#     sum_score += scb
#     if i%50==0:
#         print("iteration num : ",i)
# print(sum_score/TEST_NUM)

# %% [markdown]
# ## chatgpt api test

# %%
# !pip install openai
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting openai
#   Downloading openai-0.27.7-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.10/dist-packages (from openai) (2.27.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from openai) (4.65.0)
# Collecting aiohttp (from openai)
#   Downloading aiohttp-3.8.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 20.9 MB/s eta 0:00:00
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (3.4)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (23.1.0)
# Collecting multidict<7.0,>=4.5 (from aiohttp->openai)
#   Downloading multidict-6.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 10.0 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3 (from aiohttp->openai)
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp->openai)
#   Downloading yarl-1.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 25.3 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1 (from aiohttp->openai)
#   Downloading frozenlist-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (149 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 18.4 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2 (from aiohttp->openai)
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Installing collected packages: multidict, frozenlist, async-timeout, yarl, aiosignal, aiohttp, openai
# Successfully installed aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 frozenlist-1.3.3 multidict-6.0.4 openai-0.27.7 yarl-1.9.2

# %%
import openai
import json
import time

# %%
# with open("/content/drive/MyDrive/WARNING_PRIVATE_FOLDER/OSSP2AntiGPT9/ai/no_commit/chatgptapikey.json", 'rb') as f:
#     tempjson = json.load(f)
#     YOUR_API_KEY = tempjson["api_key"]

# %%
# def ChatGPT(prompt, API_KEY=YOUR_API_KEY):
#     # api key 세팅
#     openai.api_key = API_KEY

#     # ChatGPT API 호출 및 최신 언어 모델인 text-davinci-003을 가져옴
#     completion = openai.Completion.create(
#         engine='text-davinci-003'  # 'text-curie-001'  # 'text-babbage-001' #'text-ada-001' # 'gpt-3.5-turbo'
#         , prompt=prompt
#         , temperature=0.5
#         , max_tokens=64
#         , top_p=1
#         , frequency_penalty=0
#         , presence_penalty=0
# )

#     return completion['choices'][0]['text']

# %%
# ChatGPT("이거 공짜로 해주면 안될까? ㅠㅠ")

# %%
out_json = {"tp":[("제주방언","번역모델","정답")]}

# %%
# prompt_helper = "이 말을 이해했으면 1 아니면 0을 말해줘"
# #prompt_helper = ""

# %%
for i in range(len(test_s)):
    sr_text = test_d[i] # dialect
    tg_text = translate(sr_text) # translate
    print("source_text : ",sr_text)
    # di_gpt = ChatGPT(sr_text+prompt_helper)
    # print("chatgpt res : ",di_gpt)
    print("result :      ",tg_text)
    # st_gpt = ChatGPT(tg_text+prompt_helper)
    # print("chatgpt res : ",st_gpt)
    print("ground_truth :",test_s[i])
    print()
    if tg_text.strip() != test_s[i].strip(): 
        out_json["tp"].append((sr_text,tg_text,test_s[i]))
    if i%50==0:
        print("iteration num : ",i)
    # if i==5000:
    #     print("end")
    #     break
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# result :       다 팔았어
# ground_truth : 다 팔았다
#
# source_text :  하나도 어서 다 폴안 제주시 완예 저기 도남에 와네
# result :       하나도 없어 다 팔아서 제주시 와서 저기 도남에 와서
# ground_truth : 하나도 없어 다 팔어서 제주시 와가지고요 저기 도남에 와서
#
# source_text :  야시랜 한 다방을
# result :       야시라고 한 다방을
# ground_truth : 야시라고 한 다방을
#
# source_text :  야시인가 뭐해가지고 다방을 하나 차려서
# result :       야시인가 뭐해서 다방을 하나 차려서
# ground_truth : 야시인가 그런거같은데 다방을 하나 차렸어
#
# source_text :  다방차리난 그 어떤 여자가 땅 봔
# result :       다방차리니까 그 어떤 여자가 땅 봤어요
# ground_truth : 다방을 개업하니까 그 어떤 여자가 땅 있어
#
# source_text :  촌의 땅이시난예 땅봔에 이제 결혼해 살켄해신디 것도 안 돼
# result :       촌의 땅있으니까 땅 보고 이제 결혼해 살겠다고 했는데 그것도 안 돼
# ground_truth : 촌의 땅이있어서 땅보고서 이제 결혼해 살려고했는데 것도 안 돼
#
# source_text :  결국은 그 아이들예 낙천에 간예
# result :       결국은 그 아이들요 낙천에 가서요
# ground_truth : 결국은 그 아이들이랑 낙천에 가서요
#
# source_text :  녹음 오늘 못하켜
# result :       녹음 오늘 못하겠다
# ground_truth : 녹음 오늘 못할거같아
#
# source_text :  겅핸양
# result :       그래서요
# ground_truth : 그러니까요
#
# source_text :  그 아이들이 이제 고아 되부런
# result :       그 아이들이 이제 고아 되버렸어
# ground_truth : 그 아이들이 이제 고아 되버렸어
#
# source_text :  이 뭐랜하더라
# result :       이 뭐라고하더라
# ground_truth : 이 뭐라고했더라
#
# source_text :  제일 제일 무서운거
# result :       제일 제일 무서운거야
# ground_truth : 제일 제일 무서운거야
#
# source_text :  집이 잘 안되어부런 까지 행 끊어부러시면
# result :       집이 잘 안되어 버렸어  까지 해서 끊어버렸으면
# ground_truth : 집이 잘 안됬어 까지 해서 끊었으면
#
# source_text :  좋아실건디
# result :       좋았을텐데
# ground_truth : 좋았을텐데
#
# source_text :  이제 그 집 어서젼
# result :       이제 그 집 없어졌어
# ground_truth : 이제 그 집 없어졌어
#
# source_text :  집도 어서지고
# result :       집도 없어지고
# ground_truth : 집도 없어지고
#
# source_text :  그 아들 둘이 이신디 아들 둘이도 어떵 사는지 모르크라 진짜 고아되부런 하나도 어서
# result :       그 아들 둘이 있는데 아들 둘이도 어떻게 사는지 모르겠어 진짜 고아어 하나도 없어
# ground_truth : 그 아들 둘이 있는데 아들 둘이도 어떻게 사는지 모르겠어 진짜 고아되버렸어 하나도 없어
#
# source_text :  거기 그 뱀이 그 올레
# result :       거기 그 뱀이 그 골목
# ground_truth : 거기 그 뱀이 그 집앞길
#
# source_text :  길 가운데 죽언이성게
# result :       길 가운데 죽어있었어게
# ground_truth : 길 가운데 죽어있었어
#
# source_text :  죽은거봐도양
# result :       죽은거봐도요
# ground_truth : 죽은거봐도요
#
# source_text :  죽엉이시난 지팡이로
# result :       죽어있으니 지팡이로
# ground_truth : 죽어있으니까 지팡이로
#
# source_text :  근데 꿈에 배염 보면 좋덴안허나
# result :       근데 꿈에 뱀 보면 좋다고 안하니까
# ground_truth : 근데 꿈에 뱀 보면 좋다고안하나
#
# source_text :  태몽이라
# result :       태몽이야
# ground_truth : 태몽이야
#
# source_text :  꿈에 배염은 태몽
# result :       꿈에 뱀은 태몽
# ground_truth : 꿈에 뱀은 태몽
#
# source_text :  기지
# result :       그렇지
# ground_truth : 그렇지
#
# source_text :  그 어디꽈 그 가시리인가 어디강 살아났덴
# result :       그 어디냐 그 가시리인가 어디 가서 살았었데
# ground_truth : 그 어디지 그 가시리인가 어디가서 살았었데
#
# source_text :  살아신디예
# result :       살았는데요예
# ground_truth : 살았었는데요
#
# source_text :  그 저기 뭐냐 그 주인 할망이
# result :       그 저기 뭐냐 그 주인 할머니가
# ground_truth : 그 저기 뭐냐 그 주인 할머니가
#
# source_text :  뭐 모시는 할망
# result :       뭐 모시는 할머니
# ground_truth : 뭐 모시는 할머니
#
# source_text :  몰란에 아기 아프난 거기도 빌어주는 모양이라 그런거에 아기 아프난 빌어주라 해신디
# result :       몰라서 아기 아프니까 거기도 빌어주는 모양이라 그런거에 아기 아프니까 빌어
# ground_truth : 몰랐는데 아기 아프니까 거기도 빌어주는 모양이라 그런거에 아기 아프니까 빌어주라 했는데
#
# source_text :  그게 막 뭐랜말하더라 그 자기도 모르게 그걸 모시게 되는 그런 상황이 와분거
# result :       그게 막 뭐라고말하더라 그 자기도 모르게 그걸 모시게 되는
# ground_truth : 그게 막 뭐라고말하더라 그 자기도 모르게 그걸 모시게 되는 그런 상황이 와버렸어
#
# source_text :  겅행 이제 어멍이 굿을 한거라 굿 허난예
# result :       그래서 이제 엄마가 굿을 한거야 굿 하니까요
# ground_truth : 그래서 이제 엄마가 굿을 한거야 굿 하니까
#
# source_text :  배염이 진짜예
# result :       뱀이 진짜요
# ground_truth : 뱀이 진짜예
#
# source_text :  배염이 크지도 않은 배염
# result :       뱀이 크지도 않은 뱀
# ground_truth : 뱀이 크지도 않은 뱀
#
# source_text :  빛나는 배염이에요 울타리에 걸쳥으네
# result :       빛나는 뱀이에요 울타리에 걸쳐서
# ground_truth : 빛나는 뱀이에요 울타리에 걸쳐져있는데
#
# source_text :  아 기
# result :       아 그래
# ground_truth : 아 정말
#
# source_text :  옛날 무사 우리 이모님 녹취할 때 저 칠성 한 번 시에 와났덴 안허냐 굿허래
# result :       옛날 왜 우리 이모님 녹취할 때 저 칠성 한 번 시에 왔다고 안했냐
# ground_truth : 옛날 왜 우리 이모님 녹취할 때 저 칠성 한 번 시에 왔었다고 하지않았니 굿하러
#
# source_text :   굿허래 칠성 건드련 굿허래 와났덴 하멍이
# result :       굿하러 칠성 건드렸어 굿하러 왔었다고 하면서이
# ground_truth :  굿하러 칠성 건드려서 굿하러 왔었다고 하면서
#
# source_text :  아 진짜 배염이 나온데 굿 해가믄 칠성
# result :       아 진짜 뱀이 나온데 굿 하면 칠성
# ground_truth : 아 진짜 뱀이 나온데 굿 하고나면 칠성
#
# source_text :  칠성뱀이랜 헌거는 집에 집 지키는 뱀
# result :       칠성뱀이라고 한거는 집에 집 지키는 뱀
# ground_truth : 칠성뱀이랜 하는거는 집에 집 지키는 뱀
#
# source_text :  칠성뱀은 집 지키는 뱀이꽈
# result :       칠성뱀은 집 지키는 뱀입니까
# ground_truth : 칠성뱀은 집 지키는 뱀이에요
#
# source_text :  그니까 집터에 사는 배염을 잘못 건드려 부니까
# result :       그니까 집터에 사는 뱀을 잘못 건드려 버리니까
# ground_truth : 그니까 집터에 사는 뱀을 잘못 건드려 버리니까
#
# source_text :  동티가 나니까 가이신디 비는거주게
# result :       동티가 나니까 한테 비는거지
# ground_truth : 동티가 나니까 그거한테 비는거지
#
# source_text :  지금은 막 아스팔트 해불고 콘크리트 행 집에 뱀이 없덴하는디
# result :       지금은 막 아스팔트 해버리고 콘크리트 해서 집에 뱀이 없다고 하는데
# ground_truth : 지금은 막 아스팔트 해버리고 콘크리트 하니까 집에 뱀이 없다고하는데
#
# iteration num :  11250
# source_text :  옛날에 하소
# result :       옛날에 하소야
# ground_truth : 옛날에 했어
#
# source_text :  뱀 하영 이서
# result :       뱀 많이 있어
# ground_truth : 뱀 많이 이서
#
# source_text :  구랭이
# result :       뱀
# ground_truth : 구렁이
#
# source_text :  구랭이지
# result :       뱀이지
# ground_truth : 구렁이지
#
# source_text :  저거 아니 독 독새기 잡아먹고
# result :       저거 아니 닭 닭 잡아 먹고
# ground_truth : 저거 아니 독 새끼돼지 잡아먹고
#
# source_text :  그건 도둑놈이란 곳주게
# result :       그건 도둑놈이란 말하거든요
# ground_truth : 그건 도둑놈이란 말하지
#
# source_text :  구랭이가 집이 하나씩은
# result :       구렁이가 집이 하나씩은
# ground_truth : 구렁이가 집이 하나씩은
#
# source_text :  그런 뱀 그런 뱀 얘기하는거 아니
# result :       그런 뱀 그런 뱀 얘기하는거 아니야
# ground_truth : 그런 뱀 그런 뱀 얘기하는거 아니야
#
# source_text :  집터 뱀이 이신디양 우리도양
# result :       집터 뱀이 있는데요 우리도요
# ground_truth : 집터 뱀이 있는데요 우리도요
#
# source_text :  새로 짓기도 하고 했주게
# result :       새로 짓기도 하고 했지 게
# ground_truth : 새로 짓기도 하고 했잖아
#
# source_text :  경허영 집을 초가집 오래된 집을 차장보민 그 안에 뱀 굴이 이서
# result :       그래서 집을 초가집 오래된 집을 찾아보면 그 안에 뱀 굴이 있어
# ground_truth : 그래서 집을 초가집 오래된 집을 찾아보면 그 안에 뱀 굴이 이서
#
# source_text :  사람 살고 허난 온도가 똣똣허네
# result :       사람 살고 하니까 온도가 따뜻하네
# ground_truth : 사람 살고 하니까 온도가 따뜻하잖아
#
# source_text :  다른디 안가
# result :       다른데 안가
# ground_truth : 다른곳으로 안가
#
# source_text :  아니 겅허고양 집이 망하젠하믄
# result :       아니 그리고요 집이 망하려고 하면
# ground_truth : 아니 그리고요 집이 망할려고하면
#
# source_text :  배염이 나와 집 망하젠하믄
# result :       뱀이 나와 집 망하려고 하면
# ground_truth : 뱀이 나와 집 망할려고하면
#
# source_text :  우리 어멍이 고란게
# result :       우리 엄마가 말하더라
# ground_truth : 우리 어머니가 말씀하셨는데
#
# source_text :  때에 안맞는 배염이 나와
# result :       때에 안맞는 뱀이 나와
# ground_truth : 때에 안맞는 뱀이 나와
#
# source_text :  때에 안맞는 배염이
# result :       때에 안맞는 뱀이
# ground_truth : 때에 안맞는 뱀이
#
# source_text :  간접 빼떼기 할 때 허믄 그 철 뱀이 들어갈 때 잖아
# result :       간접적으로 빼떼기 할 때 하면 그 철 뱀이 들어갈 때 잖아
# ground_truth : 간접 빼떼기 할 때 하면 그 철 뱀이 들어갈 때 잖아
#
# source_text :  겅헌디 그 우리 저기 우리 집이 낙천 집이 어디냐 하면 예
# result :       그런데 그 우리 저기 우리 집이 낙천 집이 어디냐 하면 예
# ground_truth : 그런데 그 우리 저기 우리 집이 낙천 집이 어디냐 하면 예
#
# source_text :  상점이란 해신디 상점에서 아버지가 이제
# result :       상점이란 했는데 상점에서 아버지가 이제
# ground_truth : 상점이란 했는데 상점에서 아버지가 이제
#
# source_text :  밭에 갔다 오면 시끄기 실프덴
# result :       밭에 갔다 오면 실기 싫데
# ground_truth : 밭에 갔다 오면 씻기 싫다고
#
# source_text :  부엌 정지애 지득하영 패와지난예 불 때면
# result :       부엌 부엌애 불 땔것많이 펴져서 불 때면
# ground_truth : 부엌 부엌애 깊은곳 패어져있으니까예 불 때면
#
# source_text :  그 지득하게영 쓰러져 자부러
# result :       그 불 땔것처럼 쓰러져 자버려
# ground_truth : 그 깊은데서 쓰러져 잠드셔
#
# source_text :  싞엉 내일도 이제 갈거네 막 우리 아방 옛날 그 일본식 지가다비 신발 있잖아요
# result :       그러면 내일도 이제 갈거네 막 우리 아빠 옛날 그 일본식 지가다비
# ground_truth : 씻고 내일도 이제 갈거네 막 우리 아버지 옛날 그 일본식 작업화 신발 있잖아요
#
# source_text :  지가다비
# result :       자기가다비
# ground_truth : 작업화
#
# source_text :  지가다비 지가다비랜허난 알아지지
# result :       지가다비 지가다 라고 하니까 알지
# ground_truth : 작업화 작업화라고하니까 알아지지
#
# source_text :  일어낭보난 뱀이예 아방
# result :       일어나보니 뱀이요 아빠
# ground_truth : 일어나보니까 뱀이예 아방
#
# source_text :  아방은 길이 영행 똑같이
# result :       아빠는 길이 이렇게해서 똑같이
# ground_truth : 아방은 길이 이렇게해서 똑같이
#
# source_text :  영 드러누엉이서
# result :       이렇게 드러누워있어
# ground_truth : 이렇게 누워있어
#
# source_text :  겅허난 이제 어멍이 막
# result :       그러니까 이제 엄마가 막
# ground_truth : 그러니까 이제 어머니가 막
#
# source_text :  움직이지맙서 배염있수다 움직이지맙서
# result :       움직이지마세요 뱀있어요 움직이지마세요
# ground_truth : 움직이지마세요 뱀있어요 움직이지마세요
#
# source_text :  뱀은 영 함부로 건들지 못해서
# result :       뱀은 이렇게 함부로 건들지 못했어
# ground_truth : 뱀은 그렇게 함부로 건들지 못해서
#
# source_text :  겅행으네 영허난 그 저기 아방이 겅해랜 건들지 않으면 물지않아요
# result :       그래서 이러니까 그 저기 아빠가 그렇게 하더래 건들지 않으면 물
# ground_truth : 그러니까 이렇게말하니까 그 저기 아버지이 이렇게말했데 건들지 않으면 물지않아요
#
# source_text :  배염은
# result :       뱀은
# ground_truth : 뱀은
#
# source_text :  공격을 안한덴 했잖나
# result :       공격을 안한다고 했잖나
# ground_truth : 공격을 안한다고 했잖나
#
# source_text :  경헌디 솟강알로 밥하는 솟강알로 가맨
# result :       그런데 앉으니까 부엌하는 부엌아래로 가요
# ground_truth : 그런데 아궁이로 밥하는 아궁이로 가더라고
#
# source_text :  겐디 우리는 어릴 때 배염보면 막 겅해났자나 물까부덴
# result :       그런데 우리는 어릴 때 뱀보면 막 그렇게 했었잖아 물까봐서
# ground_truth : 그런데 우리는 어릴 때 뱀보면 막 그렇게했었잖아 물릴까봐
#
# source_text :  손썩으덴하멍
# result :       손 썩는다고 하면서
# ground_truth : 손썩는다고하면서
#
# source_text :  반죽에다 물 댄거주게
# result :       반죽에다 물 댄거지
# ground_truth : 반죽에다 물 대어놓은거지
#
# source_text :  아니 겅허영 노래 불러나자네 노래
# result :       아니 그렇게 해서 노래 부르고나서 노래
# ground_truth : 아니 그래서 노래 불러나자네 노래
#
# source_text :  우리 큰 족은 우리 그것도 막행 완전 주문이라
# result :       우리 큰 작은 우리 그것도 막해서 완전 주식이야
# ground_truth : 우리 큰 작은 우리 그것도 계속해서 완전 주문이라
#
# source_text :  크게도 안허여 큰 족은
# result :       크게도 안해 큰 작은
# ground_truth : 크게도 않해 큰 작은
#
# source_text :  배염 잡젠이
# result :       뱀 잡으려고이
# ground_truth : 뱀 잡으려고
#
# source_text :  이하다가 물리민 안되난 어른들
# result :       이하다가 물리면 안되니까 어른들
# ground_truth : 이하다가 물리면 안되니까 어른들
#
# source_text :  손썩어분덴
# result :       손 썩는다고
# ground_truth : 손썩는다고
#
# source_text :  게난 경해나신가
# result :       그러니까 그랬었나
# ground_truth : 그래서 그렇게말했었나
#
# source_text :  경해놨주게
# result :       그랬었지
# ground_truth : 그랬었지
#
# source_text :  우리 동네엔 보민 그 포장하기전에
# result :       우리 동네엔 보면 그 포장하기전에
# ground_truth : 우리 동네엔 보면 그 포장하기전에
#
# source_text :  사곰파리 들으려 하
# result :       사 곰파리 들으려 하
# ground_truth : 사금파리 들으려 하
#
# iteration num :  11300
# source_text :  사곰파리
# result :       사돈파리
# ground_truth : 사금파리
#
# source_text :  사곰파리
# result :       사돈파리
# ground_truth : 사금파리
#
# source_text :  사곰파리 했잖아
# result :       사돈파리 했잖아
# ground_truth : 사금파리 했잖아
#
# source_text :  사곰파리
# result :       사돈파리
# ground_truth : 사금파리
#
# source_text :  그거 가졍 놀때도
# result :       그거 가지고 놀때도
# ground_truth : 그거 가지고 놀때도
#
# source_text :  밤에 고봄재기 안해난 동네에 사람
# result :       밤에 고봄재기 안했던 동네에 사람
# ground_truth : 밤에 숨바꼭질 안했었어 동네에 사람
#
# source_text :  고봄재기 하당 좀도 자불고
# result :       고봄재기 하다가 잠도 자버리고
# ground_truth : 숨바꼭질 하다가 잠도 자버리고
#
# source_text :  집에 들어갈 생각도 안행이네 고봄재기가 썸 타는 거라
# result :       집에 들어갈 생각도 안하고 고봄재기가 썸 타는 거야
# ground_truth : 집에 들어갈 생각도 안하고 숨바꼭질가 썸 타는 거야
#
# source_text :  아니 그런데 우리 어릴때는 경
# result :       아니 그런데 우리 어릴때는 그렇게
# ground_truth : 아니 그런데 우리 어릴때는 그렇게
#
# source_text :  어린때난 그런걸 몰라신디
# result :       어릴때니까 그런걸 몰랐는데
# ground_truth : 어릴때라서 그런걸 몰랐는데
#
# source_text :  그때 큰 어른들도 그때 곹이 했잖아 어른들은 고방 썸 탓지 않아신가
# result :       그때 큰 어른들도 그때 같이 했잖아 어른들은 가만히 썸 탓지 않았
# ground_truth : 그때 큰 어른들도 그때 같이 했잖아 어른들은 숨어서 썸 탓지 않았었나
#
# source_text :  어른들은 곹이 해시민 어른들도 썸 탓쥬
# result :       어른들은 같이 했으면 어른들도 썸 탓지
# ground_truth : 어른들은 같이 했으면 어른들도 썸 탓쥬
#
# source_text :  어른들은 곹이 안해서
# result :       어른들은 같이 안했어
# ground_truth : 어른들은 같이 안해서
#
# source_text :   아이들 청년들은 곹이 해놔서
# result :       아이들 청년들은 같이 했었어요
# ground_truth :  아이들 청년들은 같이 했었어
#
# source_text :  이제 생각해보믄이 우리가 어린 마음에 어른들 하는디 꼽사리 낀거 닮아이
# result :       이제 생각해보면 우리가 어린 마음에 어른들 하는디 꼽사리 낀거 같아요
# ground_truth : 이제 생각해보면 우리가 어린 마음에 어른들 하는데 꼽사리 낀거 같아
#
# source_text :  몇 살 서 너 살 위 아래로 행으네
# result :       몇 살 서 너 살 위 아래로 해서
# ground_truth : 몇 살 서 너 살 위 아래로 해서
#
# source_text :  그 사이당 불러주기 하여 알아져
# result :       그 사이당 불러주기 하여 알아져요
# ground_truth : 그 사이당 불러주기 해서 알겠어
#
# source_text :   집으래가고
# result :       집으러가고
# ground_truth :  잡으러가고
#
# source_text :  무궁화 알암신게 무궁화 꽃이 피었습니다
# result :       무궁화 알고있네 무궁화 꽃이 피었습니다
# ground_truth : 무궁화 알고있네 무궁화 꽃이 피었습니다
#
# source_text :  아니요 아니요 사이당 불러주기 하여그네 하민
# result :       아니요 아니요 사이당 불러주기 해서 하면
# ground_truth : 아니요 아니요 사이당 불러주기 해가지고 하면
#
# source_text :  팡에 붙엉들 팡지키기 하고 잽혀온 사람들
# result :       팡에 붙어서 팡 지키기 하고 잡혀 온 사람들 팡에 붙어서
# ground_truth : 자리에 붙어서 자리지키기 하고 잡혀온 사람들
#
# source_text :  확 강으네 툭 쳐냉하믄 다 살앙 도망가불고
# result :       확 가서 툭 쳐내서 하면 다 살아서 도망가버리고
# ground_truth : 확 가서 툭 쳐가지고 다 살아서 도망가고
#
# source_text :  그게 무궁화꽃하고 닮은거 아니
# result :       그게 무궁화꽃하고 닮은거 아니야
# ground_truth : 그게 무궁화꽃하고 같은거 아니
#
# source_text :  나 고라줄께
# result :       나 말해줄께
# ground_truth : 나 말해줄께
#
# source_text :  거 완전 재미서
# result :       거 완전 재밌어
# ground_truth : 거 완전 재미있어
#
# source_text :  만약에 우리 네 명이만 했잖아 그럼 혼 팀이 두 명씩이잖아 그러면 두 개 그리는 거라 이렇게
# result :       만약에 우리 네 명만 했잖아 그럼 한 팀이 두 명씩이잖아
# ground_truth : 만약에 우리 네 명이만 했잖아 그럼 한 팀이 두 명씩이잖아 그러면 두 개 그리는 거라 이렇게
#
# source_text :  잘도 재미서
# result :       엄청 재밌어
# ground_truth : 엄청 재미있어
#
# source_text :  거믄 이 선을 이거를 세 명이하면 세 개 그려
# result :       그러면 이 선을 이거를 세 명이하면 세 개 그려
# ground_truth : 그러면 이 선을 이거를 세 명이하면 세 개 그려
#
# source_text :  여기에 하나 이서 거믄 여기 넘어가는 거는 거
# result :       여기에 하나 있어 그러면 여기 넘어가는 거는 거야
# ground_truth : 여기에 하나 있어 그러면 여기 넘어가는 거는 거
#
# source_text :  거믄 이제 여기서 일로 넘어가야 하는데 못 넘어가게 막아야 하는 거라
# result :       그러면 이제 여기서 일로 넘어가야 하는데 못 넘어가게 막아야 하는 거야
# ground_truth : 그러면 이제 여기서 일로 넘어가야 하는데 못 넘어가게 막아야 하는 거야
#
# source_text :  거믄 못 넘어가게 하면 여기 한 사람이 넘어갔다
# result :       그러면 못 넘어가게 하면 여기 한 사람이 넘어갔다
# ground_truth : 그러면 못 넘어가게 하면 여기 한 사람이 넘어갔다
#
# source_text :  이 사람이 또 이대로 넘어가젠 하믄 막 여기서 손
# result :       이 사람이 또 이대로 넘어가려고 하면 막 여기서 손
# ground_truth : 이 사람이 또 이대로 넘어가려고 하면 막 여기서 손
#
# source_text :  땡겨주고 겅행 넘어강 끝까지 가면 이기는거야
# result :       땡겨주고 그렇게 해서 넘어가서 끝까지 가면 이기는거야
# ground_truth : 땡겨주고 그렇게해서 넘어가서 끝까지 가면 이기는거야
#
# source_text :  기지양
# result :       그렇죠양
# ground_truth : 맞죠
#
# source_text :  팡 하나 행으네
# result :       팡 하나 해서
# ground_truth : 자리에 하나 해서
#
# source_text :  사이당은 팡을 하나 정해 놓고
# result :       사이당은 자리을 하나 정해 놓고
# ground_truth : 사이당은 자리를 하나 정해 놓고
#
# source_text :  진돌이 아니
# result :       진돌이 아니야
# ground_truth : 진돌이 아니야
#
# source_text :  진돌이 우린 진돌이랜 해신디
# result :       진돌이 우린 진돌이라고 했는데
# ground_truth : 진돌이 우린 진돌이라고 했는데
#
# source_text :  팡 두 개를 놓아갔고
# result :       파서 두 개를 놓아가고
# ground_truth : 자리 두 개를 놓아갔고
#
# source_text :  하나 이 쪽 팡 이 쪽 팡 해가고 진돌이라고 해서
# result :       하나 이 쪽 팡 이 쪽 팡 해가고 진돌이라고 했어
# ground_truth : 하나 이 쪽 자리 이 쪽 자리 해가고 진돌이라고 해서
#
# source_text :  이거는 밤에 경 잘 놀아나서 여기
# result :       이거는 밤에 그렇게 잘 놀았었어 여기
# ground_truth : 이거는 밤에 그렇게 잘 놀아나서 여기
#
# source_text :  여기 동네에 이런 길에다가 여기 팡 하나 놓고
# result :       여기 동네에 이런 길에다가 여기 파서 하나 놓고
# ground_truth : 여기 동네에 이런 길에다가 여기 자리 하나 놓고
#
# source_text :  여기 팡 하나 놓고
# result :       여기 파서 하나 놓고
# ground_truth : 여기 자리 하나 놓고
#
# source_text :  그건 어떵하는거
# result :       그건 어떻게 하는거야
# ground_truth : 그건 어떻게하는거야
#
# source_text :  막 집으로 밭으로 튀어넘엉으네
# result :       막 집으로 밭으로 튀어넘어서
# ground_truth : 막 집으로 밭으로 뛰어넘어서
#
# source_text :  여기 강으네 이쪽 사람들이 여기 강으네 점령하면 이기는 건데
# result :       여기 가서 이쪽 사람들이 여기 가서 점령하면 이기는 건데
# ground_truth : 여기 가서 이쪽 사람들이 여기 가서 점령하면 이기는 건데
#
# source_text :  여기 하당이네 죽은 아인 이쪽 아인
# result :       여기 하다가 죽은 아인 이쪽 아인
# ground_truth : 여기 하다가 죽은 아이는 이쪽 아이는
#
# source_text :  여기왕 손잡아 이서난 살려주랜 해가지고
# result :       여기 와서 손잡아 있어서 살려주라고 해가지고
# ground_truth : 여기와서 손잡아 있었어 살려달라고 해가지고
#
# source_text :  경허믄 거쳐가믄 다 살아나고
# result :       그러면 거쳐가면 다 살아나고
# ground_truth : 그러면 건들고가면 다 살아나고
#
# source_text :  탁 거치면
# result :       탁 거르면
# ground_truth : 탁 건들면
#
# iteration num :  11350
# source_text :  우리는 팡 하나 가졍해서
# result :       우리는 팡 하나 가지고 했어요
# ground_truth : 우리는 자리 하나 가지고했어
#
# source_text :  우리 진돌이에게 하면 영행이네 이거 진돌이를
# result :       우리 진돌에게 하면 이렇게해서 이거 진돌이를
# ground_truth : 우리 진돌이에게 하면 그렇게해서 이거 진돌이를
#
# source_text :  경 밤에 놈이 담  넘어가멍
# result :       그렇게 밤에 남의 담 넘어가면서
# ground_truth : 그렇게 밤에 남에 담  넘어가면서
#
# source_text :  그디 뚜껑
# result :       거기 뚜껑
# ground_truth : 거기 뚜껑
#
# source_text :  오징어처럼 영 그령이네 하는거고
# result :       오징어처럼 이렇게 그려서 하는거고
# ground_truth : 오징어처럼 이렇게 그려서 하는거고
#
# source_text :  사이당 할 때는 하나 행으네 두 편으로 나눠
# result :       사이당 할 때는 하나 해서 두 편으로 나눠
# ground_truth : 사이당 할 때는 하나 해서 두 편으로 나눠
#
# source_text :  좇앙으네 다 잡아불때까지 잡아 드릴 때까지
# result :       쫓아서 다 잡아버릴때까지 잡아드릴 때까지
# ground_truth : 쫓아가서 다 잡아버릴때까지 잡아 드릴 때까지
#
# source_text :  다 잡아들이면 끝나는 거주게
# result :       다 잡아들이면 끝나는 거지 그래야지
# ground_truth : 다 잡아들이면 끝나는 거야
#
# source_text :  사이당이 틀리면 이제 영 건너오면
# result :       사이당이 틀리면 이제 이렇게 건너오면
# ground_truth : 사이당이 틀리면 이제 이렇게 건너오면
#
# source_text :  요걸 사이당이랜 하더라고
# result :       요걸 사이당이라고 하더라고
# ground_truth : 요걸 사이당이라고 하더라고
#
# source_text :  저거 닮아
# result :       저거 같아
# ground_truth : 저거 같아
#
# source_text :  하시다리랜 했고
# result :       하시 다리라고 했고
# ground_truth : 하시다리라고 했고
#
# source_text :  지우는건 어서
# result :       지우는건 없어
# ground_truth : 지우는건 없어
#
# source_text :  지우멍 하면이거 야 이거 진짜 오랜만에 생각남쪄이
# result :       지우면서 하면이거 야 이거 진짜 오랜만에 생각난다 이
# ground_truth : 지우면서 하면이거 야 이거 진짜 오랜만에 생각난다
#
# source_text :  이것만 영허믄 못넘어가주
# result :       이것만 이렇게 하면 못 넘어가지
# ground_truth : 이것만 이렇게하면 못넘어가죠
#
# source_text :  팔 잡아땡기멍 하는거 생각나지양
# result :       팔 잡아 당기면서 하는거 생각나죠
# ground_truth : 팔 잡아당기면서 하는거 생각나지양
#
# source_text :  사이당 하당 보난 하시다리 진돌이는
# result :       사이당 하다가 보니까 하찮은지 진돌이는
# ground_truth : 사이당 하다가 보니까 하시다리 진돌이는
#
# source_text :  비슷한 놀이네 저거는 팡 두개를 나눠서
# result :       비슷한 놀이잖아 저거는 팡 두개를 나눠서
# ground_truth : 비슷한 놀이네 저거는 자리 두개를 나눠서
#
# source_text :  팡 두 개는 이 쪽 팡 저쪽 팡
# result :       자리 두 개는 이 쪽 자리 저쪽 자리
# ground_truth : 자리 두 개는 이 쪽 자리 저쪽 자리
#
# source_text :  그리고 저기 강이네 점령해도 이기는 거고
# result :       그리고 저기 가서 점령해도 이기는 거고
# ground_truth : 그리고 저기 가서 점령해도 이기는 거고
#
# source_text :  여기 두 팀이라 여겨 온 이들이 여기 있고 여기 이서
# result :       여기 두 팀이라 여겨 온 이들 여기 있고 여기 있어
# ground_truth : 여기 두 팀이라 여겨 온 이들이 여기 있고 여기 있어
#
# source_text :  거믄 사람 우리가 할 땐 맨 처음 여기서 일로 건너가 건너강
# result :       그러면 사람 우리가 할 땐 맨 처음 여기서 일로 건너가 건너가서
# ground_truth : 그러면 사람 우리가 할 땐 맨 처음 여기서 일로 건너가 건너가서
#
# source_text :  저기 발 짚으믄 이기는거라
# result :       저기 발 짚으면 이기는거야
# ground_truth : 저기 발 짚으면 이기는거라
#
# source_text :  우리는 오징어 다리만 해났져
# result :       우리는 오징어 다리만 했었어
# ground_truth : 우리는 오징어 다리만 했었어
#
# source_text :  이게 관건이라 먼저 넘어와 일로 간 가야 되난 한 명
# result :       이게 관건이라 먼저 넘어와 이리로 간 가야 되니까 한 명
# ground_truth : 이게 관건이야 먼저 넘어와 일로 간 가야 되니까 한 명
#
# source_text :  이제 여기왕 여기 넘어가젠 하니까
# result :       이제 여기 와서 여기 넘어가려고 하니까
# ground_truth : 이제 여기왕 여기 넘어가려고 하니까
#
# source_text :  그냥 발 치멍
# result :       그냥 발 치면서
# ground_truth : 그냥 발 치면서
#
# source_text :  넘어오는거는 어떵 막아
# result :       넘어오는거는 어떻게 막아
# ground_truth : 넘어오는거는 어떻게 막아
#
# source_text :  사람이 막아 막 여기서 막아 막는데 여기 넘어와 일로 들어가면 분산 되잖아양
# result :       사람이 막아 막 여기서 막아 막는데 여기 넘어와 일로 들어가면 분산 되잖아요
# ground_truth : 사람이 막아 막 여기서 막아 막는데 여기 넘어와 일로 들어가면 분산 되잖아요
#
# source_text :  분산되면 여기서도 막고 여기서도 막고 허는디
# result :       분산되면 여기서도 막고 여기서도 막고 하는데
# ground_truth : 분산되면 여기서도 막고 여기서도 막고 하는데
#
# source_text :  이제 하나 뚫르믄 이제 이제는 이게 넘어오면서
# result :       이제 하나 뚫으면 이제 이제는 이게 넘어오면서
# ground_truth : 이제 하나 뚫리면 이제 이제는 이게 넘어오면서
#
# source_text :  처음에는 무조건 다리를 막아야되여 무조건 저기 가지는 다리를 건너 배달하여야 할까 요
# result :       처음에는 무조건 다리를 막아야돼 무조건 저기 가지는 다리를 건너 배달하여야 할까 요
# ground_truth : 처음에는 무조건 다리를 막아야되 무조건 저기 가지는 다리를 건너 배달하여야 할까 요
#
# source_text :  무조건 저기 가젠하믄 다리를 건너되요
# result :       무조건 저기 가려고 하면 다리를 건너되요
# ground_truth : 무조건 저기 가려고하면 다리를 건너되요
#
# source_text :  그런데 다리 하나 뚫려불믄 두 군데마다 막아야 되잖아
# result :       그런데 다리 하나 뚫려버리면 두 군데마다 막아야 되잖아
# ground_truth : 그런데 다리 하나 뚫리면 두 군데마다 막아야 되잖아
#
# source_text :  그냥 와랑와랑 나도 넘고 너도 넘고 와랑와랑
# result :       그냥 우럭우럭 나도 넘고 너도 넘고 우럭우럭
# ground_truth : 그냥 전부다 나도 넘고 너도 넘고 전부다
#
# source_text :  다 넘어 불젠카믄 이제는
# result :       다 넘어버릴려고 하면 이제는
# ground_truth : 다 넘어 가버리고 하면 이제는
#
# source_text :  못넘어가게 막 밀려불고 잡아댕겨불고 하고 저기 다리에서
# result :       못 넘어가게 막 밀려버리고 잡아당겨버리고 하고 저기 다리에서
# ground_truth : 못넘어가게 막 밀고 잡아댕기고 하고 저기 다리에서
#
# source_text :  밀령 선 나가불면 죽어
# result :       밀려서 선 나가버리면 죽어
# ground_truth : 밀려서 선 나가버리면 죽어
#
# source_text :  그리고 이거는 이거는 무신거 우리 이것도 했었죠 이거 있잖아요
# result :       그리고 이거는 이거는 무슨거 우리 이것도 했었죠 이거 있잖아요
# ground_truth : 그리고 이거는 이거는 어떤거야 우리 이것도 했었죠 이거 있잖아요
#
# source_text :  달팽이 이거 돌팽이
# result :       달팽이 이거 돌팽이
# ground_truth : 달팽이 이거 달팽이
#
# source_text :  나는 잘 안해난
# result :       나는 잘 안했었어
# ground_truth : 나는 잘 안했어
#
# source_text :  저건 모르켜
# result :       저건 모르겠다
# ground_truth : 저건 모르겠다
#
# source_text :  돌맹이 같이 그려난 영해나신디
# result :       돌맹이 같이 그려서 이랬었는데
# ground_truth : 달팽이 같이 그려서 이렇게했는데
#
# source_text :  아니 우리는 이렇게 그령해난 에스자로
# result :       아니 우리는 이렇게 그렸던 에스자로
# ground_truth : 아니 우리는 이렇게 그려서 했었어 에스자로
#
# source_text :  놀이가 잘도 웃기긴 하다
# result :       놀이가 너무 웃기긴 하다
# ground_truth : 놀이가 엄청 웃기긴 하다
#
# source_text :  문을 그냥 열엉 내부러 그냥 자꾸 소리나 녹음하는디 잡소리들어 가면 그렇잖아
# result :       문을 그냥 열어서 놔둬 그냥 자꾸 소리나 녹음하는데 잡소리들어 가면
# ground_truth : 문을 그냥 열어서 냅눠 그냥 자꾸 소리나 녹음하는데 잡소리들어 가면 그렇잖아
#
# source_text :  돌팽이집은
# result :       돌팽이집은
# ground_truth : 달팽이집은
#
# source_text :  그냥 돌멩이 집 그려
# result :       그냥 돌멩이 집 그려
# ground_truth : 그냥 달팽이 집 그려
#
# source_text :  겅했딘하믄 계속
# result :       그랬다고 하면 계속
# ground_truth : 그렇게하면 계속
#
# source_text :  계속 돌멍 하는데 시작행 돌면 이제 막 이제 누가 누가 빨리 나가
# result :       계속 돌면서 하는데 시작해서 돌면 이제 막 이제 누가 누가 빨리 나가
# ground_truth : 계속 돌면서 하는데 시작해서 돌면 이제 막 이제 누가 누가 빨리 나가
#
# iteration num :  11400
# source_text :  영행으네 싸우는 거고 하여튼 다 몸싸움이야
# result :       이렇게 싸우는 거고 하여튼 다 몸싸움이야
# ground_truth : 그렇게해서 싸우는 거고 하여튼 다 몸싸움이야
#
# source_text :  이제는 그런 것이 어신디
# result :       이제는 그런 것이 없는데
# ground_truth : 이제는 그런 것이 없는데
#
# source_text :  하나도 어성이네
# result :       하나도 없어서
# ground_truth : 하나도 없어이젠
#
# source_text :  손바닥으로 영 올리는 걸 못해
# result :       손바닥으로 이렇게 올리는 걸 못해
# ground_truth : 손바닥으로 이렇게 올리는 걸 못해
#
# source_text :  보라 이게
# result :       봐 이게
# ground_truth : 봐 이게
#
# source_text :  다 어디가부런
# result :       다 어디 가버렸어
# ground_truth : 다 어디가버렸어
#
# source_text :  이 십 칠 분 뿐이 안해서
# result :       이 십 칠 분 밖에 안했어
# ground_truth : 이 십 칠 분 뿐이 안했어
#
# source_text :  혼저 고라봐
# result :       빨리 말해봐
# ground_truth : 혼자서라도 말해봐
#
# source_text :  허맨
# result :       해
# ground_truth : 하고있어
#
# source_text :  나  고랐잖아 나 저
# result :       나 말했잖아 나 저
# ground_truth : 나  말했잖아 나 저
#
# source_text :  곧젠허난 해신디 우리 집이 우리 집이 배염
# result :       말하려니까 했는데 우리 집이 우리 집이 뱀이 배염
# ground_truth : 말하려고 했는데 우리 집이 우리 집이 뱀
#
# source_text :  우리집이 우리 법당 알아져
# result :       우리집이 우리 법당 알아요
# ground_truth : 우리집이 우리 법당 알겠어
#
# source_text :  야 요번에 가보난 너무 족아부런 부르니 물통도 두 개씩 이서난거
# result :       야 요번에 가보니까 너무 작아버려서 부르니 물통도 두 개씩 있었던거
# ground_truth : 야 요번에 가보니까 너무 작아버려서 부르니 우물도 두 개씩 있던거
#
# source_text :  물통하나는 있어
# result :       물탕하나는 있어
# ground_truth : 우물하나는 있어
#
# source_text :  집 안에 화단도 육화랑 똥글랑 화단에서 난거 다 어서져부런
# result :       집 안에 화단도 육화랑 동글랑 화단에서 난거 다 없어져
# ground_truth : 집 안에 화단도 육화랑 동그란 화단에서 난거 다 없어져버렸어
#
# source_text :  어멍은 또 따로 여기 초가집에 살아나신디
# result :       엄마는 또 따로 여기 초가집에 살았었는데
# ground_truth : 어머니은 또 따로 여기 초가집에 살았었는데
#
# source_text :  그때 그 배염이 구렝이라이 물페기는 아니라이
# result :       그때 그 뱀이 뱀이라서 물회는 아니라 이
# ground_truth : 그때 그 뱀이 구렁이라이 살무사는 아니라이
#
# source_text :  통구랭이
# result :       통구렁이
# ground_truth : 통구렁이
#
# source_text :  그 저 독새기 먹어부난
# result :       그 저 계란 먹어서
# ground_truth : 그 저 새끼돼지 먹어버려서
#
# source_text :  게난 그게 굴묵에 강 독이 독새기를 낳아신디
# result :       그러니까 그게 아궁이에 가서 닭이 달걀을 낳았는데
# ground_truth : 그래서 그게 아궁이에 가서 돼지가 새끼돼지를 낳아신디
#
# source_text :  굴묵에 강 계속 구렝이가 먹어분거아니 배염이
# result :       굴뚝에 가서 계속 구쟁이가 먹어버린거 아니 뱀이
# ground_truth : 아궁이에 가서 계속 구렁이가 먹어버린거야 뱀이
#
# source_text :  게난이 독이 방에 들어완 이불밑이 독새기를 난게
# result :       그러니까 닭이 방에 들어와서 이불밑이 달걀을 낳았어게
# ground_truth : 그래서 돼지가 방에 들어와서 이불밑에 새끼돼지를 낳았어
#
# source_text :  아 진짜 이불밑이 아니 우리 독이 배염이 골목에 간
# result :       아 진짜 이불밑이 아니 우리 독이 뱀이 골목에 갔어
# ground_truth : 아 진짜 이불밑에 아니 우리 돼지가 뱀이 골목에 간
#
# source_text :  자꾸 독새기난걸 먹어가난 이제는 집이
# result :       자꾸 달걀을 먹으니까 이제는 집이
# ground_truth : 자꾸 새끼돼지 낳은걸 먹으니까 이제는 집이
#
# source_text :  구들에 보믄 이불영 어신 집은 구석에 이불 놔두잖아
# result :       방에 보면 이불이랑 없는 집은 구석에 이불 놔두잖아
# ground_truth : 구들에 보면 이불이렇게 없는 집은 구석에 이불 놔두잖아
#
# source_text :  그 방은 족은 방이난 구들 구석에 이불을 놔둬신디 거기완 독새기를 낳아놘
# result :       그 방은 작은 방이니까 방 구들 구석에 이불을 놔뒀는데 거기
# ground_truth : 그 방은 작은 방이난 구들 구석에 이불을 놓았는데 거기와서 새끼돼지를 낳은거야
#
# source_text :  배염이 구들 까지 들어온거 아니
# result :       뱀이 방망 까지 들어온거 아니야
# ground_truth : 뱀이 구들 까지 들어온거 아니
#
# source_text :  우리 아방이 어떵 잡아신디 있잖아이 안 보이잖아 우리가
# result :       우리 아빠가 어떻게 잡았는데 있잖아 안 보이잖아 우리가
# ground_truth : 우리 아버지가 어떻게 잡았는데 있잖아이 안 보이잖아 우리가
#
# source_text :  아버지 저기 배염 들어간 독새기 먹어불맨 허난 우리 아버지
# result :       아버지 저기 뱀 들어간 달걀 먹어버렸어 하니까 우리 아버지
# ground_truth : 아버지 저기 뱀 들어간 새끼돼지 먹고있어요 하니까 우리 아버지
#
# source_text :  보이지도 않으멍
# result :       보이지도 않으면서
# ground_truth : 보이지도 않으면서
#
# source_text :  망댕 진짜 망댕이 가져강
# result :       아깝다 진짜 아깝다 이 가져가서
# ground_truth : 몽둥이 진짜 몽둥이 가져가서
#
# source_text :  영 허맨 겅하난이
# result :       이렇게 해 그러니까이
# ground_truth : 이렇게 하면서 그러니까
#
# source_text :  우리는 또 얼마나 머숩나 아버지 배염 물면 어떵하나
# result :       우리는 또 얼마나 무섭나 아버지 뱀 물면 어떻게 하나
# ground_truth : 우리는 또 얼마나 무서워 아버지 뱀 물면 어떡하지
#
# source_text :  배염물맨 막 해도 우리 아버지는이 그냥 보이지도 않는데 막 영 하는거라
# result :       뱀물맨 막 해도 우리 아버지는 그냥 보이지도 않는데 막 이렇게 하는거야
# ground_truth : 뱀물어요 막 해도 우리 아버지는이 그냥 보이지도 않는데 막 이렇게 하는거야
#
# source_text :  우리가 보난이 배염은 진짜 독새기 먹엉이 목에 동글락 걸러정 이서
# result :       우리가 보니까 뱀은 진짜 달걀 먹고 목에 동글락 걸러져서 있어
# ground_truth : 우리가 보니까 뱀은 진짜 새끼돼지 먹어서 목에 동그랗게 걸려져서 있어
#
# source_text :  동글락하게 입고 걸려정 이서
# result :       동그랗게 입고 걸려 있어
# ground_truth : 동글락하게 입고 걸려져서 있어
#
# source_text :  그건 안 먹는 배염인가
# result :       그건 안 먹는 뱀인가
# ground_truth : 그건 안 먹는 뱀인가
#
# source_text :  구렁이 안 물언 경핸 걔도 물진 않아요 막
# result :       구렁이 안 물었어 그래서 도 물진 않아요 막
# ground_truth : 구렁이 안 물었어 그렇게해서 걔도 물진 않아요 막
#
# source_text :  아버지 해가난 밖에 나완
# result :       아버지 해가니까 밖에 나왔어
# ground_truth : 아버지 해서 밖에 나와서
#
# source_text :  물통이 두 개 주게 큰 물통 하나 쪽은 물통 하나
# result :       물통이 두 개지 큰 물통 하나 작은 물통 하나
# ground_truth : 물통이 두 개 지 큰 물통 하나 작은 물통 하나
#
# source_text :  쪽은 물통 앞에 가니
# result :       작은 물탕 앞에 가니
# ground_truth : 작은 물통 앞에 가니
#
# source_text :  굴먹은독생이 뱉으맨게
# result :       굴먹은독생이 뱉어요게 뱉은다게
# ground_truth : 굴먹은독생이 뱉으면서
#
# source_text :  게난 지금도 우리 아이 우리 1 그
# result :       그러니까 지금도 우리 아이 우리 1 그
# ground_truth : 그러니까 지금도 우리 아이 우리 1 그
#
# source_text :  저 생활수기 쓴거보면 그 얘기 나와 아버지 옛날 영 해놔수게 하면서 가이가 영 편지식으로 썻거든 아팡
# result :       저 생활수기 쓴거보면 그 얘기 나와 아버지 옛날 이렇게 했었잖아
# ground_truth : 저 생활수기 쓴거보면 그 얘기 나와 아버지 옛날 그렇게 했었죠 하면서 그아이가 그렇게 편지식으로 썻거든 아파서
#
# source_text :  해신디 그얘길 하는데
# result :       했는데 그얘길 하는데
# ground_truth : 했는데 그얘길 하는데
#
# source_text :  나는 그때  우리 아버지는 안 보이난 경 해신가
# result :       나는 그때 우리 아버지는 안 보이니까 그렇게 했나
# ground_truth : 나는 그때  우리 아버지는 안 보이고 그렇게 했었나
#
# source_text :  아니라 우리도예 배어 나 그 저
# result :       아니라 우리도요 배어 나 그 저
# ground_truth : 아니야 우리도요 배어 나 그 저
#
# source_text :  저기 마당에 옛날에 가믄 다 깨우니께
# result :       저기 마당에 옛날에 가면 다 깨우니까
# ground_truth : 저기 마당에 옛날에 가믄 다 깨우니까
#
# source_text :  겅해으겼는데 그 저기 안거리 밖거리 이시난
# result :       그렇게 했었는데 그 저기 안채 바깥채 있으니까
# ground_truth : 겅해으겼는데 그 저기 안거리 밖거리 있으니까
#
# source_text :  밖거리 영허믄 무사 골목 들어가젠하면 영 좀
# result :       바깥채 이렇게하면 왜 골목 들어가려고하면 이렇게 좀
# ground_truth : 밖거리 그렇게하면 왜 골목 들어가려고하면 그렇게 좀
#
# iteration num :  11450
# source_text :  바깥 어 저기 뭐꽈영
# result :       바깥 어 저기 뭐죠 이렇게
# ground_truth : 바깥 어 저기 뭡니까그
#
# source_text :  하나 영 넘어 길에 가야 하잖아요 골목 들어가젠허믄
# result :       하나 이렇게 넘어 길에 가야 하잖아요 골목 들어가려고 하면
# ground_truth : 하나 그렇게 넘어 길에 가야 하잖아요 골목 들어가려고하면
#
# source_text :  저게 무슨 도로먹과 닮은거 올령으네 그냥 저기 망태기도 올려놓고막 하면 그 망태
# result :       저게 무슨 도로먹과 같은거 올려서 그냥 저기 망태기도 올려놓고막
# ground_truth : 저게 무슨 도로먹과 같은거 올려서 그냥 저기 망태기도 올려놓고막 하면 그 망태
#
# source_text :  이 우에 독새기를 놔논 거라 이 독 나는 독새기를 거를 망태기위에 두면 뱀
# result :       이 위에 달걀을 놔논 거야 이 닭 낳는 달걀을 거를 망태
# ground_truth : 이 위에 독새기를 둔 거라 이 닭 나는 병아리를 거를 망태기위에 두면 뱀
#
# source_text :  먹공 막 겅 하는데 그냥 망태기 위에서 그 독새기를 품은 거라 독이
# result :       먹고 막 그렇게 하는데 그냥 망태기 위에서 그 돼지를 품은 거야 돼지가
# ground_truth : 먹고 막 그렇게 하는데 그냥 망태기 위에서 그 병아리를 품은 거라 닭이
#
# source_text :  독새기 품엉 빙아리 깨우면
# result :       계란 품어서 병아리 깨우면
# ground_truth : 독새기 품은 병아리 깨우면
#
# source_text :  이제 딱 내놓으는데 하도 이제 배염들 잘 다녀가난
# result :       이제 딱 내놓는데 하도 이제 뱀들 잘 다니니까
# ground_truth : 이제 딱 내놓으는데 하도 이제 뱀들 잘 다녀가니까
#
# source_text :  그 땅에다가 이렇게 철사를 뽑은 거 배엄 못들어가게 그런데 그 배염이양 땅 팡 들어가 땅도 팡 들어가 땅속으로 그러니까 이제
# result :       그 땅에다가 이렇게 철사를 뽑은 거 뱀 못 들어가게 그런데 그 뱀이요 땅 파서
# ground_truth : 그 땅에다가 이렇게 철사를 뽑은 거 뱀 못들어가게 그런데 그 뱀이요 땅 파서 들어가 땅도 파서 들어가 땅속으로 그러니까 이제
#
# source_text :  배엄 못들어가게 이제 영 철망을 철조망을 다 켱이제 를 키우는데
# result :       뱀 못 들어가게 이제 이렇게 철망을 철조망을 다 켜서 이제 를 키우는데
# ground_truth : 뱀 못들어가게 이제 영 철망을 철조망을 다 켱이제 를 키우는데
#
# source_text :  어멍이 막 꼭꼭꼭꼭 삐약삐약삐약 해가난 나 어멍 저 강보라 강보라 강보라 하는거라
# result :       엄마가 막 꼭꼭꼭꼭 삐약삐약삐약 해가니까 나 엄마
# ground_truth : 엄마가 막 꼭꼭꼭꼭 삐약삐약삐약 하니까 나 엄마 저 가봐라 가봐라 가봐라 하는거라
#
# source_text :  어멍은 막 미싱허멍
# result :       엄마는 막 미싱하면서
# ground_truth : 엄마은 막 미싱하면서
#
# source_text :  아이씨 하면서 나 강보난예 어머니 배엄 해신디
# result :       아이씨 하면서 나 가서보니까 어머니 뱀 했는데
# ground_truth : 아이씨 하면서 나 가보니까요 어머니 뱀 했는데
#
# source_text :  하나는 물고 빙에게 물고 또 하나는 감앙 꼬리로 영 휘어감고 그담에이제 그
# result :       하나는 물고 빙에 물고 또 하나는 감아서 꼬리로 이렇게 휘어감고 그담에이
# ground_truth : 하나는 물고 뱀에게 물고 또 하나는 감아서 꼬리로 그렇게 휘어감고 그담에이제 그
#
# source_text :  막 허고 빙애기 들은 구석에서 삐약삐약 막 하고 하는디
# result :       막 하고 병아리 들은 구석에서 삐약삐약 막 하고 하는데
# ground_truth : 막 허고 병아리 들은 구석에서 삐약삐약 막 하고 하는디
#
# source_text :  어멍이신디 이제
# result :       어머니한테 이제
# ground_truth : 엄마있었는데 이제
#
# source_text :  그런데 배엄이
# result :       그런데 뱀이
# ground_truth : 그런데 뱀이
#
# source_text :  두껍고 커 막크난예 어멍이예 아이 이제 너무커난 잡기가 겁난거라
# result :       두껍고 커 막크니까 엄마가 아이 이제 너무 크니까 잡기가 겁난거야
# ground_truth : 두껍고 커 막크니까요 엄마가요 아이 이제 너무커서 잡기가 겁난거야
#
# source_text :  막 무서워하는디 이제 아방한테 골안 아방은예
# result :       막 무서워하는데 이제 아빠한테 말했어 아빠는요
# ground_truth : 막 무서워하는데 이제 아빠한테 말했어 아빠는요
#
# source_text :  아무서치않아게 그냥 그 배엄을 그냥 막 죽이젠 하는거라 그래 이제 나보고 그 동네에 그 할망
# result :       아무서치 않게 그냥 그 뱀을 그냥 막 죽이려고 하는거라 그래 이제 나
# ground_truth : 아무렇지않게 그냥 그 뱀을 그냥 막 죽이려고 하는거야 그래 이제 나보고 그 동네에 그 할머니
#
# source_text :  옆집에 할망 좀 나이 든 할망 나보고 어멍이가 혼디 그 할망 데려와불라
# result :       옆집에 할머니 좀 나이 든 할머니 나보고 어머니이가 같이 그 할머니 데려와라
# ground_truth : 옆집에 할머니 좀 나이 든 할머니 나보고 엄마가 빨리 그 할머니 데려와라
#
# source_text :  대려와불라 하는거아니
# result :       대려와라 하는거 아니야
# ground_truth : 데려와라 하는거아닙니까
#
# source_text :  이제 아이고 집에 배암 나왕양 빙애기 먹음시난 어멍이
# result :       이제 아이고 집에 뱀 나와서 병아리 먹고 있으니까 어머니가
# ground_truth : 이제 아이고 집에 뱀 나왔으니 병아리 먹으니까 엄마가
#
# source_text :  빨리 오랜햄수다 하니까 헤 참 하면서 와신디
# result :       빨리 오라고해요 하니까 헤 참 하면서 왔는데
# ground_truth : 빨리 오라고했어요 하니까 헤 참 하면서 와신디
#
# source_text :  아방은 벌써부터 막 그 뱀을 막 두드려
# result :       아빠는 벌써부터 막 그 뱀을 막 두드려
# ground_truth : 아빠은 벌써부터 막 그 뱀을 막 두드려
#
# source_text :  빙애기를 막 빙애기 막 입에꺼 뱉으게 아 안뱉어라 하니까 그니까 이제
# result :       병아리를 막 병아리 막 입에꺼 뱉게 아 안뱉어라 하니
# ground_truth : 병아리를 막 병아리 막 입에꺼 뱉으게 아 안뱉어요 하니까 그니까 이제
#
# source_text :  아방이 그 할망이
# result :       아빠가 그 할머니가
# ground_truth : 아빠가 그 할머니가
#
# source_text :  이놈의 도둑놈 이놈의 도둑놈 도둑놈이나 죽어야주
# result :       이놈의 도둑놈 이놈의 도둑놈 도둑놈이나 죽어야지
# ground_truth : 이놈의 도둑놈 이놈의 도둑놈 도둑놈이나 죽어야되
#
# source_text :  막 뱀 신디 시키지 않애도 도둑이랜 막 외는거라
# result :       막 뱀한테 시키지 않아도 도둑이라고 막 소리치는거야
# ground_truth : 막 뱀 한테 시키지 않아도 도둑이라고 막 말하는거야
#
# source_text :  이놈의 도둑놈 이놈의 도둑놈 도둑놈이나 때렴사주 도둑놈이나 죽염사주
# result :       이놈의 도둑놈 이놈의 도둑놈 도둑놈이나 때려야지 도둑놈
# ground_truth : 이놈의 도둑놈 이놈의 도둑놈 도둑놈이나 때려야지 도둑놈이나 죽여야지
#
# source_text :  막 도둑이랜
# result :       막 도둑이래
# ground_truth : 막 도둑이래
#
# source_text :  막 막 욕허는디
# result :       막 막 욕하는데
# ground_truth : 막 막 욕하는데
#
# source_text :  그 아방이양 나는예 겅안해도 모성 죽어지는디 어멍이 아방이 곧 죽을라 하염신디
# result :       그 아버지가요 나는요 안그래도 못하는데 어머니가 아버지가 곧 죽을라 했는데요
# ground_truth : 그 아빠가요 나는요 그렇게안해도 모성 죽어지는디 엄마가 아빠가 곧 죽을라 한다고하는데
#
# source_text :  작대기 큰 뱀 영
# result :       작대기 큰 뱀 이렇게
# ground_truth : 작대기 큰 뱀 그렇게
#
# source_text :  그거 던질핸 게난 할망이 그 할망이 어디 던지지 마랑 안 보이는디
# result :       그거 던질했어 그러니까 할머니가 그 할머니가 어디 던지지 말고 안
# ground_truth : 그거 던지려고했어 그러니까 할머니가 그 할머니가 어디 던지지 마라 안 보이는디
#
# source_text :  어 이거 이놈 도둑놈은 집이 못 찾아오게 해야 된댄허멍 겅 고르멍 막 내치랜 하는거라
# result :       어 이거 이놈 도둑놈은 집이 못 찾아오게 해야 된다고 하면서 그렇게 말하면서
# ground_truth : 어 이거 이놈 도둑놈은 집이 못 찾아오게 해야 된다고하면서 그렇게 말하면서 막 내치려고 하는거야
#
# source_text :  아방이 겅으네
# result :       아빠가 그렇게 해서
# ground_truth : 아방이 그렇게해서
#
# source_text :  날 대령 그 배암을 던지랜 가더라고
# result :       날 데리고 그 배암을 던지러 가더라고
# ground_truth : 날 대리고 그 뱀을 던지러 가더라고
#
# source_text :  아방은 여기 작대기 들고
# result :       아빠는 여기 작대기 들고
# ground_truth : 아빠는 여기 작대기 들고
#
# source_text :  나는 저기 아방뒤를
# result :       나는 저기 아빠뒤를
# ground_truth : 나는 저기 아버지뒤를
#
# source_text :  아방여기 약하나 잡고
# result :       아빠 여기 약하나 잡고
# ground_truth : 아버지여기 약하나 잡고
#
# source_text :  막 안보젠 해신디 아방이
# result :       막 안 보려고 했는데 아빠가
# ground_truth : 막 안보려고 했는데 아빠가
#
# source_text :  가신디 그게 우리 산네기 산네기라라고 밭이 이서 그 밭 가는 길에 엄강물에 휙 던져분거라
# result :       갔는데 그게 우리 산네기 산네기라라고 밭이 있어 그 밭 가는
# ground_truth : 갓는데 그게 우리 산네기 산네기라라고 밭이 있어 그 밭 가는 길에 어떤강물에 휙 던져버린거야
#
# source_text :  근데 그 산네기 밭에 가젠하면 그대 뱀 나옴시카 한데 막
# result :       근데 그 산네기 밭에 가려고하면 그대 뱀 나올까 한데 막
# ground_truth : 근데 그 산네기 밭에 가자고하면 그대 뱀 나올까봐 한데 막
#
# source_text :  경 해신디 그 뱀 죽인 후론
# result :       그렇게 했는데 그 뱀 죽인 후론
# ground_truth : 그렇게 했는데 그 뱀 죽인 후론
#
# source_text :  무슨 일 어선게 그런데 그추륵 배엄이 집에왕 해얼때는양
# result :       무슨 일 없었어 그런데 그렇게 뱀이 집에와서 해얼때는요
# ground_truth : 무슨 일 없었어 그런데 그처럼 뱀이 집에와서 할때는요
#
# source_text :  검해야 된대 겅 해야 동티가 안 난데
# result :       검해야 된대 그래야 동티가 안 난데
# ground_truth : 그렇게 된대 그렇게 해야 동티가 안 난데
#
# source_text :  경 보이지도 않아
# result :       그렇게 보이지도 않아
# ground_truth : 그렇게 보이지도 않아
#
# source_text :  보이지도 않앙 막
# result :       보이지도 않아서 막
# ground_truth : 보이지도 않고 막
#
# source_text :  영 해놘 생각만 나게 하면
# result :       이렇게 해놨어 생각만 나게 하면
# ground_truth : 그렇게 해놓은 생각만 나게 하면
#
# source_text :  뱉어놓고 도망가는 거 그런 저기 또 하나는 양
# result :       뱉어놓고 도망가는 거 그런 저기 또 하나는 양
# ground_truth : 뱉어놓고 도망가는 거 그런 저기 또 하나는 저기
#
# iteration num :  11500
# source_text :  그러니까 흰 배엄이 나완 하얀 뱀이
# result :       그러니까 흰 뱀이 나왔어 하얀 뱀이
# ground_truth : 그러니까 흰 뱀이 나완 하얀 뱀이
#
# source_text :  막 귀헌데 낙천에 하얀 뱀이 나완 소문난 백산에 백산
# result :       막 귀한데 낙천에 하얀 뱀이 나왔어 소문났어 백산에 백산
# ground_truth : 막 귀한데 낙천에 하얀 뱀이 나왔어 소문났어 백산에 백산
#
# source_text :  백사가 나와 백사는 귀도 이서래
# result :       백사가 나와 백사는 귀도 있더래
# ground_truth : 백사가 나와 백사는 귀도 있대
#
# source_text :  그런 말 있어놔서 귀 있댄허멍 실젠지는 모르지만은
# result :       그런 말 있었어 귀 있다고하면서 실젠지는 모르지만은
# ground_truth : 그런 말 있어서 귀 있다고해서 실젠지는 모르지만은
#
# source_text :  백사는 금도 하영준댄 핸
# result :       백사는 금도 많이준다고 했어요
# ground_truth : 백사는 금도 많이준대 했어
#
# source_text :  겅질매는 그런데 그거는 그냥 사람은 보지 못한대 죽을사람 뭐 무슨 어떤 뭐에 당한 사람이 보는거래 그런데 이제 그 백사를 본거라
# result :       그렇게 질매는 그런데 그거는 그냥 사람은 보지 못한대 죽을사람 뭐 무슨 어떤 뭐에
# ground_truth : 겅질매는 그런데 그거는 그냥 사람은 보지 못한대 죽을사람 뭐 무슨 어떤 뭐에 당한 사람이 보는거래 그런데 이제 그 백사를 본거야
#
# source_text :  보난 그 아이구
# result :       보니까 그 아이구
# ground_truth : 보니까 그 아이구
#
# source_text :  뱀 잡는 사람이 이제 거기 텐트촌 백사 나오는데 기다린거라
# result :       뱀 잡는 사람이 이제 거기 텐트촌 백사 나오는데 기다린거야
# ground_truth : 뱀 잡는 사람이 이제 거기 텐트촌 백사 나오는데 기다린거야
#
# source_text :  기다려신디 결국은 못잡안 못잡아신디 그 아지망이
# result :       기다렸는데 결국은 못잡았어 못잡았는데 그 아줌마가
# ground_truth : 기다렸는데 결국은 못잡았어 못잡았는데 그 아줌마가
#
# source_text :  백사 본 아지망이 집에간 갓신디 장독대에
# result :       백사 본 아줌마가 집에가서 갓는데 장독대에
# ground_truth : 백사 본 아줌마가 집에갔어 갔는데 장독대에
#
# source_text :  아침 햇빛 영 들어오면예 베엄이 땀이 창으네 장독대 옛날 그 저기
# result :       아침 햇빛 이렇게 들어오면요 뱀이 땀이 차서 장독대 옛날 그 저
# ground_truth : 아침 햇빛 그렇게 들어오면요 뱀이 땀이 차서 장독대 옛날 그 저기
#
# source_text :  고래방석의 장독에 어선의 고래방석만 나와 그 우에 배엄이 나왕 햇빛을 마신대
# result :       고래방석의 장독에 없었던 고래방석만 나와 그 위에 뱀이 나와서
# ground_truth : 고래방석의 장독에 어선의 고래방석만 나와 그 위에 뱀이 나와서 햇빛을 마신대
#
# source_text :  정지해서 불썽으멍 보면예 삠쩍삠쩍 영 보면 배엄이 나와가지고 막 이
# result :       정지해서 불 때면서 보면요 쩍쩍 이렇게 보면 뱀이 나와가
# ground_truth : 정지해서 불켜서 보면요 삠쩍삠쩍 그렇게 보면 뱀이 나와가지고 막 이
#
# source_text :  정지배리멍 있고 정지배리멍있고 해랑
# result :       부엌배리면서 있고 부엌배리면서있고 해서
# ground_truth : 정지배리멍 있고 정지배리멍있고 했어
#
# source_text :  커망한 배엄이 아유 저걸 어떵할코 해신디
# result :       커망한 뱀이 아유 저걸 어떻게 할까 했는데
# ground_truth : 큰 뱀이 아유 저걸 어떻게할까 했는데
#
# source_text :  아방 이 걸 잡아 포라분거
# result :       아빠 이 걸 잡아 팔아 버린 거야
# ground_truth : 아버지 이 걸 잡아 팔아버린거야
#
# source_text :  폴아버러신디 그때부터 그 할망이
# result :       팔아버렸는데 그때부터 그 할머니가
# ground_truth : 팔아버렸는데 그때부터 그 할망이
#
# source_text :  백사는 보고 못 잡앙 텐트를 삼일동안 쳐도 백사 안나와부난 못잡고 그후부터는 집이 그추륵 행으네 해신디
# result :       백사는 보고 못 잡아서 텐트를 삼일동안 쳐도 백사 안 나와서 못잡
# ground_truth : 백사는 보고 못 잡아서 텐트를 삼일동안 쳐도 백사 안나와서 못잡고 그후부터는 집이 그처럼 해서 했는데
#
# source_text :  그거 포라보난 그 할망예
# result :       그거 팔아보니까 그 할머니요
# ground_truth : 그거 팔아버리니까 그 할머니요
#
# source_text :  저기 독고기만 먹어
# result :       저기 닭고기만 먹어요
# ground_truth : 저기 닭고기만 먹어
#
# source_text :  다른 거 하나도 안 먹고 독고기 만들엉으네 독 고기만 먹고 그다음에 그 움직이지 못 핸양
# result :       다른 거 하나도 안 먹고  닭고기 만들어서 닭 고기만 먹고 그다음에 그 움직이지 못
# ground_truth : 다른 거 하나도 안 먹고 닭고기 만들어서 닭 고기만 먹고 그다음에 그 움직이지 못 했잖아요
#
# source_text :  모기장 했수게 옛날에는 침대가 어서놔수게
# result :       모기장 했잖아요 옛날에는 침대가 없었잖아요
# ground_truth : 모기장 했어 옛날에는 침대가 없으니까
#
# source_text :  간이침대가 어시난 모기장 몇 개 해가지고
# result :       간이침대가 없으니까 모기장 몇 개 해가지고
# ground_truth : 간이침대가 없으니까 모기장 몇 개 해가지고
#
# source_text :  모기장을 영 공중에 띄운거라 띄워행으네
# result :       모기장을 이렇게 공중에 띄운거라 띄워서
# ground_truth : 모기장을 그렇게 공중에 띄운거야 띄워가지고
#
# source_text :  오줌싸기래 털어지게끔 만들어 겅 허멍 행으네 살아난 사람이 이서
# result :       오줌싸개 털어지게끔 만들어 그러면서 해서 살았던 사람이 있어요
# ground_truth : 오줌싸기래 털어지게끔 만들어 그렇게 해서 해가지고 살아난 사람이 있어
#
# source_text :  그냥 그거 해이네 독고기만 먹고 해신디 그 네 아들은 버스운전기사 하멍
# result :       그냥 그거 해서 독고기만 먹고 했는데 그 네 아들은 버스운전기사 하면서
# ground_truth : 그냥 그거 해서 닭고기만 먹고 했는데 그 네 아들은 버스운전기사 하면서
#
# source_text :  다 그거 폴안 제주시 와부렀어
# result :       다 그거 팔아서 제주시 와버렸어
# ground_truth : 다 그거 팔아서 제주시 와버렸어
#
# source_text :  겅해도 그런거 겁나 지나가다보면
# result :       그래도 그런거 겁나 지나가다보면
# ground_truth : 그렇게해도 그런거 겁나 지나가다보면
#
# source_text :  요맘때는 방학은 안 할때라 이 지금 이맘때면 지금 십 일 월이면
# result :       요맘때는 방학은 안 할때야 이 지금 이맘때면 지금 십
# ground_truth : 요맘때는 방학은 안 할때야 이 지금 이맘때면 지금 십 일 월이면
#
# source_text :  어이고 십이월 이십 오 일날 방학하맨
# result :       어이고 십이월 이십오 일날 방학해요
# ground_truth : 어이고 십이월 이십 오 일날 방학해요
#
# source_text :  크리스마스 때 방학 이십 사 일이나 그때 방학하맨
# result :       크리스마스 때 방학 이십사일이나 그때 방학해요
# ground_truth : 크리스마스 때 방학 이십 사 일이나 그때 방학해요
#
# source_text :  이때쯤은게게 이제 막 신나게 놀때주게
# result :       이때쯤은게게 이제 막 신나게 놀때지게
# ground_truth : 이때쯤은게게 이제 막 신나게 놀때지요
#
# source_text :  밭에 강으네 요즘에는 감자 파고 콩 꺾으고
# result :       밭에 가서 요즘에는 감자 파고 콩 꺾으고
# ground_truth : 밭에 가서 요즘에는 감자 파고 콩 꺾으고
#
# source_text :  이제 감자 팔 땐가 콩은 걲었쥬
# result :       이제 감자 팔 땐가 콩은 뽑는대요
# ground_truth : 이제 감자 팔 땐가 콩은 꺾었죠
#
# source_text :  감자도 삼 강전에 판댄하잖아
# result :       감자도 삼 강전에 판다고하잖아
# ground_truth : 감자도 삼 강전에 판다고하잖아
#
# source_text :  근데 감자하면 겅 빼때기는 언제 말렸지
# result :       근데 감자하면 그렇게 빼때기는 언제 말렸지
# ground_truth : 근데 감자하면 그렇게 빼때기는 언제 말렸지
#
# source_text :  그새 이런 옷 입어주게 추워서
# result :       그새 이런 옷 입었지 추워서
# ground_truth : 그새 이런 옷 입었지 추워서
#
# source_text :  빼떼기 다할 무렵 되가면
# result :       빼떼기 다할 무렵 되가면
# ground_truth : 빼떼기 다할 무렵 되면
#
# source_text :  이제 겨울밤에 하커영
# result :       이제 겨울 밤에 할께하고
# ground_truth : 이제 겨울밤에 할꺼야
#
# source_text :  우리 감자 농사는 잘 안해놘
# result :       우리 감자 농사는 잘 안해놨어
# ground_truth : 우리 감자 농사는 잘 안했어
#
# source_text :  농사 안햄져수다게 나 그 감자농사행으네 허리 허리 아팡으네 물을 막
# result :       농사 안했어요 나 그 감자농사해서 허리 허리 아파서 물을 막
# ground_truth : 농사 안할꺼에요 나 그 감자농사하느라 허리 허리 아파서 물을 막
#
# source_text :  그 쇠 잠대기를 갈면 고랑 쫓아가멍 이거 팹지도 못허여
# result :       그 쇠 쟁기기를 갈면 고랑 쫓아가면서 이거 찾으려고도 못해
# ground_truth : 그 쇠 잠대기를 갈면 걸어서 쫓아가면 이거 팔지도 못해
#
# source_text :  계속 감자주성 내쳐야되
# result :       계속 고구마주고 내쳐야되
# ground_truth : 계속 주워서 내쳐야되
#
# source_text :  알아 알아집니까
# result :       알아 알아요
# ground_truth : 알아 압니까
#
# source_text :  여기는 그 할망 어멍은 앉앙으네 그 보둠어놓은거 하고 아이들은
# result :       여기는 그 할머니 엄마는 앉아서 그 보둠어놓은거 하고 아이들은
# ground_truth : 여기는 그 할머니 엄마는 앉아서 그 쌓아놓은거 하고 아이들은
#
# source_text :  두 명 세 명은 그 부지런히 쫓아가멍 이거 해야 돼
# result :       두 명 세 명은 그 부지런히 쫓아가면서 이거 해야 돼
# ground_truth : 두 명 세 명은 그 부지런히 쫓아가면서 이거 해야 돼
#
# source_text :  나는 앉앙 벌갱으로 파는거 카부넨 벌갱으로 파는거 아니
# result :       나는 앉아서 벌갱이로 파는거 까봐 벌갱이로 파는거 아니야
# ground_truth : 나는 앉아서 벌갱으로 파는거 인가보다 벌갱으로 파는거 아니야
#
# source_text :  그자락 안 해보니깐예
# result :       그정도 안 해보니깐 예
# ground_truth : 그처럼 안 해보니깐요
#
# source_text :  밭 하멍 전체 하니깐
# result :       밭 하면서 전체 하니깐
# ground_truth : 밭 하면 전체 하니깐
#
# source_text :  밭 하나만 할려고 감저를
# result :       밭 하나만 할려고 고구마를
# ground_truth : 밭 하나만 할려고 감자를
#
# iteration num :  11550
# source_text :  그러면 지실파고 감저는 그면 쇠
# result :       그러면 감자파고 고구마는 그러면 쇠
# ground_truth : 그러면 감자파고 감저는 그면 쇠
#
# source_text :  지실은
# result :       감자는
# ground_truth : 감자은
#
# source_text :  지실은 먹을 것만 하니까 파고 골갱이로 파고
# result :       감자은 먹을 것만 하니까 파고 호미로 파고
# ground_truth : 감자은 먹을 것만 하니까 파고 곡굉이로 파고
#
# source_text :  지실도 쇠로 해어
# result :       감자도 소로 해
# ground_truth : 감자도 쇠로 해
#
# source_text :  우리는 지실 쇠로 안 해봔
# result :       우리는 감자 소로 안 해봤어
# ground_truth : 우리는 감자 쇠로 안 해봤어
#
# source_text :  지실 같은 건 뭐 저 구좌나 이쪽 해야 많이 하니까 하영 헌 동네나 새로 하고
# result :       감자 같은 건 뭐 저 구좌나 이쪽 해야 많이 하니까 많이 한 동네나
# ground_truth : 감자 같은 건 뭐 저 구좌나 이쪽 해야 많이 하니까 하려고 하는 동네나 새로 하고
#
# source_text :  하면 지실 감자를 다 해신디 다 받지
# result :       하면 감자 감자를 다 했는데 다 받지
# ground_truth : 하면 감자 감자를 다 했는데 다 받지
#
# source_text :  몰라 난 감자 농사 안해봔
# result :       몰라 난 감자 농사 안 해봤어
# ground_truth : 몰라 난 감자 농사 안해봤어
#
# source_text :  그냥 확 갈앙으네 엎어
# result :       그냥 확 갈아서 엎어
# ground_truth : 그냥 확 갈아서 엎어
#
# source_text :  감자줄 걷는 것도 일이라
# result :       고구마줄기 걷는 것도 일이야
# ground_truth : 감자줄 걷는 것도 일이야
#
# source_text :  감자줄 걷는게 좋아 감자 주시는 것보다
# result :       고구마줄기 걷는게 좋아 고구마 주시는 것보다
# ground_truth : 감자줄 걷는게 좋아 감자 줍는 것보다
#
# source_text :  감자줄 걷는거는 그냥 호미거정 막
# result :       고구마줄기 걷는거는 그냥 호미까지 막
# ground_truth : 감자줄 걷는거는 그냥 호미가지고 막
#
# source_text :  힘이 있어야 허영
# result :       힘이 있어야 해요
# ground_truth : 힘이 있어야 할수있어요
#
# source_text :  웃긴건 뭐냐 하면 훨씬 덜 나온 아방들은 영영영영 말잖아 말면 말아놓은걸 우리는 고대기위에 날라강 거쳐가야 되는거야
# result :       웃긴건 뭐냐 하면 훨씬 덜 나온 아빠들은 이렇게이렇게이렇게 말
# ground_truth : 웃긴건 뭐냐 하면 훨씬 덜 나온 아방들은 영영영영 말잖아 말면 말아놓은걸 우리는 고대기위에 날라가서 거쳐가야 되는거야
#
# source_text :  이 동생은 진짜 농사들을 안 짓어 놨서놔게
# result :       이 동생은 진짜 농사들을 안 짓어 놨어게
# ground_truth : 이 동생은 진짜 농사들을 안 지어 봤구나
#
# source_text :  힘쓰는걸 아이들이 허여신게
# result :       힘쓰는걸 아이들이 했네요게
# ground_truth : 힘쓰는걸 아이들이 했으니까
#
# source_text :  아니 헐 수 있는게 그런거 밖에 없거든
# result :       아니 할 수 있는게 그런거 밖에 없거든
# ground_truth : 아니 할 수 있는게 그런거 밖에 없거든
#
# source_text :  질질 끄시멍
# result :       질질 끌면서
# ground_truth : 질질 끌면서
#
# source_text :  옛날에는 감저도 하영 하영막 감저 펄고 해놨잖아 저기 주정공장에도 펄고
# result :       옛날에는 고구마도 많이 많이 고구마 팔고 했었잖아 저기 주정공장에도
# ground_truth : 옛날에는 고구마도 많이 많이막 고구마 팔고 했었잖아 저기 주정공장에도 팔고
#
# source_text :  생 거는 감저공장에 팔고 빼때기는 거 뭣 때문에 빼때기는 파는지 모르크라
# result :       생 거는 고구마공장에 팔고 빼때기는 거 뭣 때문에 빼때기는
# ground_truth : 생 거는 감저공장에 팔고 껍질은 거 뭣 때문에 껍질은 파는지 몰라
#
# source_text :  게난 빼때기가 감자 빼때기 가는것도 해봅디광
# result :       그러니까 빼때기가 감자 빼때기 가는것도 해봤어요
# ground_truth : 그러니까 껍질이 감자 껍질 가는것도 해봤습니까
#
# source_text :  감저 것 생 감 거적 날르는것도 우리가 해야된다
# result :       고구마 것 생 감 거적 나르는것도 우리가 해야된다
# ground_truth : 고구마 것 생 감 그거 날르는것도 우리가 해야된다
#
# source_text :  걸채에 담앙 저기영 널엉 맞아 그거는
# result :       걸채에 담아서 저기랑 널어서 맞아 그거는
# ground_truth : 걸채에 담아서 저기에 널어 맞아 그거는
#
# source_text :  저기 뭐냐 그 감저줄도 걷엉으네 다 뭐
# result :       저기 뭐냐 그 고구마줄도 걷어서 다 뭐
# ground_truth : 저기 뭐냐 그 고구마줄도 걷어서 다 뭐
#
# source_text :  감저줄도 쇠 맥이지 않아신가
# result :       고구마줄기도 소 먹이지 않았나
# ground_truth : 감저줄도 쇠 먹이지 않았나
#
# source_text :  감저줄 위에도
# result :       고구마줄기 위에도
# ground_truth : 고구마줄 위에도
#
# source_text :  저기 조금 영 행으네 감저줄 위에도 흙 뭍지 말랜 거기다 막 겅 해놨주게
# result :       저기 조금 이렇게 해서 고구마줄기 위에도 흙 뭍지 말라고 거기다 막 그렇게
# ground_truth : 저기 조금 그렇게 해가지고 감자줄 위에도 흙 뭍지 말라고 거기다 막 그렇게 해놨지
#
# source_text :  감자 빼떼기 주시래 놈이 놈이꺼 주시랜 해 댕겨봐 빼때기를
# result :       고구마 빼떼기 주우러 남의 남의꺼 주우러 해 다녀 빼떼기를
# ground_truth : 감자 껍질 주우러 남의 남의꺼 주으러 해 다녀봐 껍질를
#
# source_text :  주시러 아니 감저빼때기
# result :       주우러 아니 고구마말랭이
# ground_truth : 주우러 아니 고구마껍질
#
# source_text :  빼때기 주시러 가난 감자 이삭 주래
# result :       빼때기 주우러 가니까 감자 이삭 주러
# ground_truth : 껍질 주우러 가니까 감자 이삭 주우러
#
# source_text :  아니 이삭 주시러가 아니고게
# result :       아니 이삭 주우러가 아니고게
# ground_truth : 아니 이삭 주우러가 아니고요
#
# source_text :  빼때기 술 쳐분것들
# result :       빼때기 술 쳐버린것들
# ground_truth : 껍질 술 친것들
#
# source_text :  이삭 주시러 가는게 아니고
# result :       이삭 주우러 가는게 아니고
# ground_truth : 이삭 주우러 가는게 아니고
#
# source_text :  빼때기는 아이들이 주실 수 있주게
# result :       빼때기는 아이들이 주을 수 있지게
# ground_truth : 껍질는 아이들이 주울 수 있죠
#
# source_text :  그거는 또 밤에도 주서진다 히앙으난
# result :       그거는 또 밤에도 주워진다 헤엄쳐서
# ground_truth : 그거는 또 밤에도 주워진다 희안하게
#
# source_text :  밤 하영 곧지마 나 밤에 그거 주시랜 행
# result :       밤 많이 말하지마 나 밤에 그거 주으라고 해서
# ground_truth : 밤 많이 말하지마 나 밤에 그거 주우라고 해서
#
# source_text :  낼 비온댄하면 그 밭 주인 잠도 안 재웡으네 주시랜하멍 캄캄해 못 주실꺼라
# result :       낼 비온다고하면 그 밭 주인 잠도 안 재워서 주라고하면서 캄캄
# ground_truth : 낼 비온다고하면 그 밭 주인 잠도 안 안재우고 주우라고하면서 캄캄해 못 주울꺼라
#
# source_text :  하면 흰 것만 주시라 흰 것만 주시라
# result :       하면 흰 것만 주라 흰 것만 주라
# ground_truth : 하면 흰 것만 주워라 흰 것만 주워라
#
# source_text :  그거는 핸 나 밤인데 어떵합니까
# result :       그거는 했어 나 밤인데 어떻게 합니까
# ground_truth : 그거는 했어 나 밤인데 어떻게합니까
#
# source_text :  비 맞으면 안 되난 막 방기들 해놘
# result :       비 맞으면 안되니까 막 방기들 해놨어
# ground_truth : 비 맞으면 안 되니까 막 방기들 해놨어
#
# source_text :  전단지하면 낼 학교 갈 건디
# result :       전단지하면 낼 학교 갈 건데
# ground_truth : 전단지하면 낼 학교 갈 건데
#
# source_text :  밖에 밭에 너는 거 말려야 될 것들은 무조건 밤새멍이라도 해
# result :       밖에 밭에 너는 거 말려야 될 것들은 무조건 밤새면서라도 해
# ground_truth : 밖에 밭에 너는 거 말려야 될 것들은 무조건 밤새면서이라도 해
#
# source_text :  맞아 비 맞으면 다 곰생이 피어불잖아
# result :       맞아 비 맞으면 다 곰팡이 피어버리잖아
# ground_truth : 맞아 비 맞으면 다 곰팡이 피어버리잖아
#
# source_text :  그 감자 찰홍차게 이제 착착착착 그 저기 기계로 하멍 그거 행으네 삐어 골고루 삐면
# result :       그 감자 찰홍차게 이제 착착착착 그 저기 기계로 하면서 그거
# ground_truth : 그 감자 찰홍차게 이제 착착착착 그 저기 기계로 하면 그거 해가지고 비어 골고루 비면
#
# source_text :  삐믄 또 두 개씩 덮어진 거 이신디 고지자방이랑으멍 다 덮어진 거 하나씩 내려놩으네
# result :       삐면 또 두 개씩 덮어진 거 있는데 고자질하고 다 덮어진 거
# ground_truth : 비면 또 두 개씩 덮어진 거 있는데 똑바로잡으라고하면 다 덮어진 거 하나씩 내려놔가지고
#
# source_text :  날래 널듯이 다 널어
# result :       곡식 널듯이 다 널어
# ground_truth : 빨래 널듯이 다 널어
#
# source_text :  그거 손 하영가는 거
# result :       그거 손 많이가는 거야
# ground_truth : 그거 손 많이가는 거
#
# source_text :  그때는 겅 빼떼기가
# result :       그때는 그렇게 빼떼기가
# ground_truth : 그때는 그렇게 빼떼기가
#
# source_text :  이만큼 큰 감자 노니까 빼떼기 착착착착 하면 또 날걸로 빼떼기 하면 막 걸어
# result :       이만큼 큰 감자 노니까 빼떼기 착착착착 하면 또 날것으로 빼
# ground_truth : 이만큼 큰 감자 노니까 껍질 착착착착 하면 또 날걸로 껍질 하면 막 걸어
#
# source_text :  감저 빼떼기 주선고마고
# result :       고구마 절간고구마 주워서 고마워요
# ground_truth : 고구마 껍질 주선고마고
#
# iteration num :  11600
# source_text :  별로 안주면 절강 행 멀리안가 돈을 하영 받았주게
# result :       별로 안주면 강 해서 멀리안가 돈을 많이 받았지
# ground_truth : 별로 안주면 절강 해서 멀리안가 돈을 많이 받았지
#
# source_text :  그 얘기는 또 빼떼기 칠 때 당 헝 놩으네
# result :       그 얘기는 또 빼떼기 칠 때 당 해서 놔서
# ground_truth : 그 얘기는 또 껍질 칠 때 다 해 놔가지고
#
# source_text :  게난
# result :       그러니까
# ground_truth : 그러니까
#
# source_text :  덜 돌안
# result :       덜 달았어
# ground_truth : 덜 돌았어
#
# source_text :  겐디 식구들은 깨끗한 빼떼기 안 먹지 않연 누릿누릿 곰생이 핀 거 먹지 않연
# result :       그런데 식구들은 깨끗한 빼떼기 안 먹지 않았어 누릿누릿 곰팡이
# ground_truth : 그런데 식구들은 깨끗한 껍질 안 먹지 않았어 누릿누릿 곰팡이 핀 거 먹지 않았어
#
# source_text :  아니 모르크라 그거는
# result :       아니 모르겠어 그거는
# ground_truth : 아니 몰라 그거는
#
# source_text :  안하남 산진 몰라도 남의 꺼 좀
# result :       안하남 산진 몰라도 남의 꺼 좀
# ground_truth : 안하면서 산진 몰라도 남의 꺼 좀
#
# source_text :  농실 있는 사람들은 좋은거 팔고
# result :       마을 있는 사람들은 좋은거 팔고
# ground_truth : 농경지 있는 사람들은 좋은거 팔고
#
# source_text :  거뭇거뭇 곰신거
# result :       거뭇거뭇 감시는거야
# ground_truth : 거뭇거뭇 곰팡이핀거
#
# source_text :  그거 고랑이네 깝 쳥 먹으멍 잘도 맛 좋았어
# result :       그거 갈아서 깝쳐서 먹으면서 잘도 맛 좋았어
# ground_truth : 그거 고아서 깝 쳐서 먹으면 매우 맛 좋았어
#
# source_text :  감자 빼때기 한번 만들어볼까
# result :       고구마 빼때기 한번 만들어볼까
# ground_truth : 감자 껍질 한번 만들어볼까
#
# source_text :  다 농사 징엉으네 농실 해봐야 돈 되는 것이 깨 농사 그 다음에 감저거
# result :       다 농사 지어서 농사 해봐야 돈 되는 것이 깨 농사 그 다음에 고구마거
# ground_truth : 다 농사 지어가지고 농경지 해봐야 돈 되는 것이 깨 농사 그 다음에 감저거
#
# source_text :  보리 조는 돈이 안되주게
# result :       보리 조는 돈이 안되거든요게
# ground_truth : 보리 조는 돈이 안되지
#
# source_text :  저게 버랭이 하영 나오는게 깨하고
# result :       저게 벌레 많이 나오는게 깨하고
# ground_truth : 저게 벌레 많이 나오는게 깨하고
#
# source_text :  유채가 아이 야 조도 하영 나완
# result :       유채가 아이 야 조도 많이 나왔어
# ground_truth : 유채가 아이 야 조도 많이 나왔어
#
# source_text :  조는 겅 하영 안 나와
# result :       조는 그렇게 많이 안 나와
# ground_truth : 조는 그렇게 많이 안 나와
#
# source_text :  하고 유채 만큼예 버랭이 안나와 난 조도 조훑으멍 그거 조 하는것도 다 해불고
# result :       하고 유채 만큼요 벌레 안나와서 조도 조 훑으면서 그거 조
# ground_truth : 하고 유채 만큼요 벌레 안나와 난 조도 조훑으멍 그거 조 하는것도 다 해버리고
#
# source_text :  그 다음에 깨도 해보고 저기 유채도 해봐신디
# result :       그 다음에 깨도 해보고 저기 유채도 해봤는데
# ground_truth : 그 다음에 깨도 해보고 저기 유채도 해봤는데
#
# source_text :  비기가 구져 여기 등 머리 다 나가
# result :       비기가 안 좋아 여기 등 머리 다 나가
# ground_truth : 배기가 궂어 여기 등 머리 다 나가
#
# source_text :  또 그냥 영 짤르면 안된다
# result :       또 그냥 이렇게 자르면 안된다
# ground_truth : 또 그냥 그렇게 짤르면 안된다
#
# source_text :  비슬멍 사선으로
# result :       비슬면서 사선으로
# ground_truth : 비스듬하게 사선으로
#
# source_text :  아이구 진짜루 우리 학교 다닐때는 중학교 때는 봉사활동으로 그 저 뭐냐 유채 비어 놓은 거에 모두래도 댕겨놨어
# result :       아이구 진짜로 우리 학교 다닐때는 중학교 때는 봉사활동으로 그 저 뭐냐
# ground_truth : 아이구 진짜루 우리 학교 다닐때는 중학교 때는 봉사활동으로 그 저 뭐냐 유채 배어 놓은 거에 모으러도 다녀놨어
#
# source_text :  경해도 우리 중학교 때 봉사활동을 해 갖고 겅행 유채 그거 뭐래난 농촌 겅행 그거 해놓은 거 모다노래
# result :       그래도 우리 중학교 때 봉사활동을 해 갖고 그래서 유채 그거 뭐라고 했어 농촌
# ground_truth : 경해도 우리 중학교 때 봉사활동을 해 갖고 그렇게해서 유채 그거 뭐라고하나 농촌 그렇게해서 그거 해놓은 거 모아놓으래
#
# source_text :  우리 그때 중학교 삼 학년 때 인데 그거 했댄 허멍으네 갖다 오는거
# result :       우리 그때 중학교 삼 학년 때 인데 그거 했다고 하면서 갖다 오는거야
# ground_truth : 우리 그때 중학교 삼 학년 때 인데 그거 했다고 하면서 갖다 오는거
#
# source_text :  유채 유채 모들때 딱 들어보면 배염 행 이서라 진짜 아니 게난 진짜 유채는 겅 해놔서
# result :       유채 유채 모들때 딱 들어보면 뱀 해서 있었어 진짜 아니 그러니까
# ground_truth : 유채 유채 모을때 딱 들어보면 뱀 해서 있어 진짜 아니 그러니까 진짜 유채는 그렇게 했었어
#
# source_text :  나 삼 학년 땐가 오 학년 때 닮아 우리 조 팟디
# result :       나 삼 학년 땐가 오 학년 때 같아 우리 조 봤는데
# ground_truth : 나 삼 학년 땐가 오 학년 때 같아 우리 조 팠어
#
# source_text :  버랭이가 얼
# result :       벌레가 얼
# ground_truth : 벌래가 얼
#
# source_text :  맨날 맨날 그 버랭이잘도 나왔어게게 조 팔때 영 약을 치는디 우리는 아버지가 일을 못 하잖아
# result :       맨날 맨날 그 벌레잘도 나왔어게게 조 팔때 이렇게 약을 치
# ground_truth : 맨날 맨날 그 벌레잘도 나왔어게게 조 팔때 그렇게 약을 치는데 우리는 아버지가 일을 못 하잖아
#
# source_text :  저 성들은 큰 사람들은 시에 영 해불고난
# result :       저 형들은 큰 사람들은 시에 이렇게 해버리고난
# ground_truth : 저 형들은 큰 사람들은 시에 그렇게 해버리고
#
# source_text :  저기 분무기를 치랜 한 거 아니 그 오 학년 때 겅허난
# result :       저기 분무기를 치라고 한 거 아니 그 오 학년 때 그러니까
# ground_truth : 저기 분무기를 치라고 한 거 아니야 그 오 학년 때 그렇게하니까
#
# source_text :  경허난 지나가던 아는 오빠가
# result :       그러니까 지나가던 아는 오빠가
# ground_truth : 그렇게하니까 지나가던 아는 오빠가
#
# source_text :  너는 너만한추륵 분무기
# result :       너는 너만한 척 분무기
# ground_truth : 너는 너만한것같은 분무기
#
# source_text :  일러염시냐 그런데 분무긴 게도 나는 깡다군 있어서 분무기 정 나 그날 일곱 통 지었어
# result :       일러서 그런건지 그런데 분무긴 그래도 나는 깡다군 있어서 분무기
# ground_truth : 일러였었냐 그런데 분무긴 그래도 나는 깡다군 있었어 분무기 저렇게 나 그날 일곱 통 지었어
#
# source_text :  해신디 그거는 괜찮은데 있잖아
# result :       했는데 그거는 괜찮은데 있잖아
# ground_truth : 했는데 그거는 괜찮은데 있잖아
#
# source_text :  이 약 해가난 발등으로 버랭이가 떨어지는디
# result :       이 약 해가니까 발등으로 벌레가 떨어지는데
# ground_truth : 이 약 해놓으니까 발등으로 벌레가 떨어지는데
#
# source_text :  조 버랭이 발등으로 파바바박 떨어지니까 그게 더 머수븐거라 이거 이거는 아무 것도 아닌디
# result :       조 벌레 발등으로 파바바박 떨어지니까 그게 더 먹어버린거
# ground_truth : 조 벌래 발등으로 파바바박 떨어지니까 그게 더 무서운거야 이거 이거는 아무 것도 아닌데
#
# source_text :  아 조 퍼랭이 잘도 퍼 조 퍼놨어
# result :       아 조 퍼랭이 완전 퍼 조 퍼놨어
# ground_truth : 아 조 벌레 잘도 퍼 조 퍼놨어
#
# source_text :  조 퍼랭이가 어떤거
# result :       조 퍼랭이가 어떤거야
# ground_truth : 조 벌레가 어떤거
#
# source_text :  그 영 꿈틀 꿈틀 하는 거
# result :       그 이렇게 꿈틀 꿈틀 하는 거야
# ground_truth : 그 그렇게 꿈틀 꿈틀 하는 거
#
# ...
# ground_truth : 내가 처음으로 한거지 초막이가 줄어드는 감을 몰라서 감이 안 잡힌거야
#
# source_text :  그거행 어느만큼 해야될지 몰라
# result :       그거해서 어느만큼 해야될지 몰라
# ground_truth : 그거해서 어느만큼 해야될지 몰라
#
# source_text :  차로 한 세 번 날라가시난게
# result :       차로 한 세 번 날라갔으니까게
# ground_truth : 차로 한 세 번 옮겨갔었어
#
# source_text :  이만큼 한 비니루로 스무 개 이상 해시난 얼마나 허영 했수과 겅허난 이제 이걸 다 어떵 팔리 해신디
# result :       이만큼 한 비닐로 스무 개 이상 했으니까 얼마나 해서 했습니까 그러니까
# ground_truth : 이만큼 한 비니루로 스무 개 이상 하니까 얼마나 많이 했어 그러니까 이제 이걸 다 어떻게 팔리 했는데
#
# source_text :  경 그자락 줄어들어 부나
# result :       그렇게 그렇게 줄어들어 버리니깐
# ground_truth : 그러니까 그처럼 줄어들어 버리나
#
# source_text :  기
# result :       그래
# ground_truth : 그래
#
# source_text :  우리 완전 황 해부런 황 해부런 겅허난 이제 그렇게 하는거라고
# result :       우리 완전 황 했어 황 했어 그러니까 이제 그렇게 하는거라고
# ground_truth : 우리 완전 황 해버렸어 황 해버렸어 그렇게하니까 이제 그렇게 하는거라고
#
# source_text :  겅행으네 고춧가루 값이 겅 엄청 들언양
# result :       그렇게 해서 고춧가루 값이 그렇게 엄청 들었어요
# ground_truth : 그래서 고춧가루 값이 그게 엄청 들었어요
#
# source_text :  싼 거 고춧가루 싼 거 사놘 망정이지
# result :       싼 거 고춧가루 싼 거 사놨어 망정이지
# ground_truth : 싼 거 고춧가루 싼 거 사놔서 망정이지
#
# source_text :  우리 서방은 그때 영국인가 어디 가불고 그때 추석 연휴일 꺼라
# result :       우리 서방은 그때 영국인가 어디 가버리고 그때 추석 연휴일 꺼야
# ground_truth : 우리 서방은 그때 영국인가 어디 가버리고 그때 추석 연휴일 꺼야
#
# source_text :  밭담길 걷자 허멍 걸으는디 거긴 다 마농 밭이어라
# result :       밭담길 걷자 하면서 걷는데 거긴 다 마늘밭이더라
# ground_truth : 밭담길 걷자 해서 걷는데 거긴 다 마늘 밭이야
#
# source_text :  패마농마늘밭 그런데 그 밭담 옆에 그 대껴분거 마농 씨들 여복한것들 대껴부난
# result :       파 마늘밭 그런데 그 밭담 옆에 그 던져버린거 마늘 씨들 여 배우니까
# ground_truth : 패마농마늘밭 그런데 그 밭담 옆에 그 버려버린거 마늘 씨들 여복한것들 버려버리니
#
# source_text :  잘도 아까와 게난 이거 주서가카 하멍 하단 거기 일하는 사람한테 삼춘 이거 줏어가도 됩니까
# result :       잘도 아까워 그러니까 이거 주워갈까 하면서 하다가 거기 일하는 사람한테
# ground_truth : 많이 아까워 그래서 이거 주워갈까 하면서 하다가 거기 일하는 사람한테 삼춘 이거 줏어가도 됩니까
#
# source_text :  하니까 줏어가랜가래 이거 누게가 먹어 허멍 하는데 그걸 주서완 3 언닌 안가져오고 4
# result :       하니까 주워가랜가래 이거 누가 먹어 하면서 하는데 그걸 주워왔어
# ground_truth : 하니까 줏어가랜가래 이거 누가 먹어 하면서 하는데 그걸 주어왔어 3 언닌 안가져오고 4
#
# source_text :  언니하고 나는 김치하켄 하멍 막 줏어오고
# result :       언니하고 나는 김치하겠다고 하면서 막 주워오고
# ground_truth : 언니하고 나는 김치해야지 하며 막 줏어오고
#
# source_text :   5 언니도 줏어오고 영해신디
# result :       5 언니도 줏어오고 이랬는데
# ground_truth :  5 언니도 줏어오고 그렇게했는데
#
# source_text :  그 요만씩 한거난 그거 밤에 다듬젠허난 그거 순바르안
# result :       그 요만큼 한거니까 그거 밤에 다듬으려니까 그거 순바르안
# ground_truth : 그 요만씩 한거 그거 밤에 다듬으려하니까 그거 순바르안
#
# source_text :  또 다듬젠 하나부난
# result :       또 다듬으려고 하니까
# ground_truth : 또 다듬으려고 하니까
#
# source_text :  버랭이잖아 사슴버렝인가 그런것도 기어 댕기고 하멍 난
# result :       벌레잖아 사슴벌레인가 그런것도 기어다니고 하면서 난
# ground_truth : 벌레잖아 사슴벌렌가 그런것도 기어 다니고 해서 난
#
# source_text :  서방도 없고 하니 그거 허젠하난 허리 아판 다듬어 엎어졍 다듬었다
# result :       서방도 없고 하니 그거 하려고 하니 허리 아파서 다듬어 엎어져서 다듬었다
# ground_truth : 서방도 없고 하니 그거 하려고하니까 허리 아팠어 다듬어 엎어져서 다듬었다
#
# source_text :  다듬엇당 허멍 해신디 또 패만한 김치는 너무 커도 맛 없잖아
# result :       다듬었다가 하면서 했는데 또 패만한 김치는 너무 커도 맛 없잖아
# ground_truth : 다듬었다가 하면서 해신디 또 패만한 김치는 너무 커도 맛 없잖아
#
# source_text :  진짜 맛 좋안
# result :       진짜 맛 좋았어
# ground_truth : 진짜 맛 좋았어
#
# source_text :  그리고 나는 원래 솜씨가 어시거든 근데
# result :       그리고 나는 원래 솜씨가 없거든 근데
# ground_truth : 그리고 나는 원래 솜씨가 없거든 근데
#
# source_text :  나가 먹어도 진짜 맛 좋아
# result :       내가 먹어도 진짜 맛 좋아
# ground_truth : 내가 먹어도 진짜 맛 좋아
#
# source_text :  경행 아이고 다음에 또 한번 저기 거르래 가자
# result :       그렇게 해서 아이고 다음에 또 한번 저기 걸으러 가자
# ground_truth : 그렇게해서 아이고 다음에 또 한번 저기 거기를 가자
#
# source_text :  그까 몽골에 게신디 아 겐디 경해신디 나는 워낙 솜씨가 어시난 게신디 고춧가루하고 설탕
# result :       그까 몽골에 그랬는데 아 그런데 그랬는데 나는 워낙 솜씨가 없으니까 그랬는데 고
# ground_truth : 그까 몽골에 그랬는데 아 그랬는데 그렇게했는데 나는 워낙 솜씨가 없어서 그랬는데 고춧가루하고 설탕
#
# source_text :  그러구 저 액젓 경해신디
# result :       그러구 저 액젓 그랬는데
# ground_truth : 그러구 저 액젓 그렇게했는데
#
# source_text :  또 생각난다 게나 거기 한 번 가봐야 할 꺼라 거기 월정 밭담길
# result :       또 생각난다 그니까 거기 한 번 가봐야 할 꺼야 거기 월정
# ground_truth : 또 생각난다 그러니까 거기 한 번 가봐야 할 꺼야 거기 월정 밭담길
#
# source_text :  흑룡만리 길 거기 가다보난 다
# result :       흑룡만리 길 거기 가다보니까 다
# ground_truth : 흑룡만리 길 거기 가다보니가 다
#
# source_text :  밑밑한데 마농밭
# result :       밑밑한데 마늘밭
# ground_truth : 밑밑한데 마늘밭
#
# source_text :  게신디 경하면 그 씨허젠 놔뒀당
# result :       그랬는데 그러면 그 씨하려고 놔뒀다가
# ground_truth : 그랬는데 그래서 그 씨하려고 놔둔
#
# source_text :  그 젠젠 한 것들은 밭뒤로 다 대껴불잖아 그게 난거라 요만
# result :       그 자잘한 한 것들은 밭뒤로 다 던져버리잖아 그게 난거
# ground_truth : 그 젠젠 한 것들은 밭뒤로 다 버려버리잖아 그게 나은거야 요만
#
# source_text :  씨 다듬는거 주게
# result :       씨 다듬는거지요게
# ground_truth : 씨 다듬는거 지
#
# source_text :  겅하난 순바르한거 대껴분거주게
# result :       그러니까 순바르한거 던져버린거지
# ground_truth : 그러니까 순바르한거 버려버린거지
#
# source_text :  영 뭐 한거만 게난
# result :       이렇게 뭐 한거만 그러니까
# ground_truth : 영 뭐 한거만 그러니까
#
# iteration num :  12350
# source_text :  그거고게 패마농은양 도날 때 어떵 도나냐하면
# result :       그거고게 파은요 도날 때 어떻게 도냐하면
# ground_truth : 그리고요 패마늘은요 도날 때 어떻게 도나냐하면
#
# source_text :  저기 밭에서 이렇게 뿌리를 딱 자르지 않읍니까 뿌리 짤랑 버린거라거야 그게
# result :       저기 밭에서 이렇게 뿌리를 딱 자르지 않읍니까 뿌리 잘라서 버린거라
# ground_truth : 저기 밭에서 이렇게 뿌리를 딱 자르지 않읍니까 뿌리 잘라서 버린거라거야 그게
#
# source_text :  뿌리 짤랑이네 그 뿌리를 버리면 그 뿌리서 또 나는거야
# result :       뿌리 잘라서 그 뿌리를 버리면 그 뿌리서 또 나는거야
# ground_truth : 뿌리 잘라서 그 뿌리를 버리면 그 뿌리서 또 나는거야
#
# source_text :  경하는거
# result :       그러는거야
# ground_truth : 그렇게하는거
#
# source_text :  게난 뭐더라 뭐더라
# result :       그러니까 뭐더라 뭐더라
# ground_truth : 그러니까 뭐더라 뭐더라
#
# source_text :  내년에 한 번 또 그 길걸으러 가야되켜
# result :       내년에 한 번 또 그 길걸으러 가야겠다
# ground_truth : 내년에 한 번 또 그 길걸으러 가야겠어
#
# source_text :  그 패마농마늘 거기 도난대 있잖아 골갱이 가지고 땅 파봐양양 굼뱅이가 거나한다
# result :       그 파 마늘 거기 도난대 있잖아 호미 가지고 땅 파봐양양
# ground_truth : 그 패마농마늘 거기 도난대 있잖아 골갱이 가지고 땅 파봐양양 굼뱅이가 많다
#
# source_text :  승게마농마늘 그 무사 영행으네 마농 그 대
# result :       성게 마늘 마늘 그 왜 이렇게해서 마늘 그 대
# ground_truth : 승게마농마늘 그 왜 그렇게해서 마늘 그 대
#
# source_text :  잘라 가믄 그 대 있지않으까양 마농 그 대 모아놔논대 그기 강 파봐
# result :       잘라 가면 그 대 있지 않습니까 마늘 그 대 모아 놓은대 거기 가서 파봐
# ground_truth : 잘라 가믄 그 대 있잖습니까 마늘 그 대 모아둔데 그기 가서 파봐
#
# source_text :  마농대 이시난데 그 굼벵이는 완전 약이라
# result :       마늘대 있는데 그 굼벵이는 완전 약이야
# ground_truth : 마늘대 있는곳에 그 굼벵이는 완전 약이야
#
# source_text :  굼벵이가 덩어리 지메
# result :       굼벵이가 덩어리 지네
# ground_truth : 굼벵이가 덩어리 지요
#
# source_text :  오 야 굼벵이를 어떵 먹어
# result :       오 야 굼벵이를 어떻게 먹어
# ground_truth : 오 야 굼벵이를 어떻게 먹어
#
# source_text :  굼벵이 그 오일장에 가서 팔믄예 키로에
# result :       굼벵이 그 오일장에 가서 팔면요 키로에
# ground_truth : 굼벵이 그 오일장에 가서 팔면요 키로에
#
# source_text :  맞아 거기 어디 굼벵이 농장도 이서라
# result :       맞아 거기 어디 굼벵이 농장도 있더라
# ground_truth : 맞아 거기 어디 굼벵이 농장도 있어
#
# source_text :  야 우리 언니가게게 옛날 형부 옛날에 결혼 초 신혼때게게 형부 저기 지방간 판정 나부난
# result :       야 우리 언니가게게 옛날 형부 옛날에 결혼 초 신혼때게게 형
# ground_truth : 야 우리 언니가게게 옛날 형부 옛날에 결혼 초 신혼때게게 형부 저기 지방간 판정 나니까
#
# source_text :  우리언니 굼벵이 사단 달여 먹였자게
# result :       우리언니 굼벵이 사단 달여 먹였잖아요게
# ground_truth : 우리언니 굼벵이 사다가 달여 먹였어
#
# source_text :  경허난
# result :       그러니까
# ground_truth : 그러니까
#
# source_text :  술 먹은댄 하면 완전 눈구럼에
# result :       술 먹는다고 하면 완전 눈구멍에
# ground_truth : 술 먹는다고 하면 완전 눈구럼에
#
# source_text :  술 먹는 거 너무 싫어허여
# result :       술 먹는 거 너무 싫어해요
# ground_truth : 술 먹는 거 너무 싫어해
#
# source_text :  응 게도 이제는 간은 좋아저서 그것때매 좋아져신가 하여튼 굼벵이 우리언니 굼벵이 달여 줘놔서
# result :       응 그래도 이제는 간은 좋아졌어 그것때매 좋아졌나 하여튼 굼
# ground_truth : 응 그래도 이제는 간은 좋아졌어 그것때매 좋아졌나 하여튼 굼벵이 우리언니 굼벵이 달여 줬었어
#
# source_text :  기침하고 영 하잖아요 그러면 굼벵이 그추륵 하영 달여먹어도 좋지만은
# result :       기침하고 이렇게 하잖아요 그러면 굼벵이 그렇게 많이 달여먹어도
# ground_truth : 기침하고 영 하잖아요 그러면 굼벵이 그것처럼 많이 달여먹어도 좋지만은
#
# source_text :  그게 고담백이라부난 너무 하영 먹어도 안좋아 살찌는건 둘째치고 몸이 속에 그게 다
# result :       그게 고담백이라서 너무 많이 먹어도 안좋아 살찌는건
# ground_truth : 그게 고담백이니까 너무 많이 먹어도 안좋아 살찌는건 둘째치고 몸이 속에 그게 다
#
# source_text :  그거 다 기름이라 겅하난양 우리아이도 어릴때 캘록캘록 기침하고 병원에가면 맨날 기침약 주고하난
# result :       그거 다 기름이야 그러니까요 우리아이도 어릴때 캘록 캘록 기
# ground_truth : 그거 다 기름이라 그러니가요 우리아이도 어릴때 캘록캘록 기침하고 병원에가면 맨날 기침약 주고하니까
#
# source_text :  에라 모르겠다 막 기관지가 겅 나빠가지고 하니까
# result :       에라 모르겠다 막 기관지가 그렇게 나빠가지고 하니까
# ground_truth : 에라 모르겠다 막 기관지가 그렇게 나빠가지고 하니까
#
# source_text :  이 굼벵이나 파기네 맥여버려야되켜 집에 그 개똥밭에 이시난 굼벵이
# result :       이 굼벵이나 파서 먹여버려야겠다 집에 그 개똥밭에 있으니까
# ground_truth : 이 굼벵이나 파서 먹여버려야겠어 집에 그 개똥밭에 있는 굼벵이
#
# source_text :  맥인거라
# result :       먹인거야
# ground_truth : 먹인거야
#
# source_text :  열 마리 열 마리 정도 숫자 샌예 아기난
# result :       열 마리 열 마리 정도 숫자 샜어요 아기니까
# ground_truth : 열 마리 열 마리 정도 숫자 셋어요 아기니까
#
# source_text :  굼벵이마다 흙 맛 나켜
# result :       굼벵이마다 흙 맛 나겠다
# ground_truth : 굼벵이마다 흙 맛 날꺼야
#
# source_text :  그냥 대 유지 위에 행
# result :       그냥 대 유지 위에 해서
# ground_truth : 그냥 대 유지 위에 해서
#
# source_text :  이제 그 굼벵이 막 다릴꺼 아닐꽈 다리면 양 굼벵이가 터뜨리지 않으면 기름이 안 떠 그믄 이제 굼벵이를 그냥 달이는게 아니라 밀가루에 굼벵이를 놔
# result :       이제 그 굼벵이 막 다릴꺼 아니에요 다리면 양 굼
# ground_truth : 이제 그 굼벵이 막 다릴꺼 아니에요 다리면 양 굼벵이가 터뜨리지 않으면 기름이 안 떠 그러면 이제 굼벵이를 그냥 달이는게 아니라 밀가루에 굼벵이를 놔
#
# source_text :  다 싸면 이제 굼벵이가 영 보면예 하양 하매 똥이 어서 배보면
# result :       다 싸면 이제 굼벵이가 이렇게 보면요 하양 해 똥이 없어 배
# ground_truth : 다 싸면 이제 굼벵이가 영 보면요 하양 하니 똥이 없어 배보면
#
# source_text :  흰 것만 있어요 밀가루 먹으면 흰 것 만 이시면 그때 이제 굼벵이를 씻처 다 씻청이네
# result :       흰 것만 있어요 밀가루 먹으면 흰 것 만 있으면 그때 이제 굼벵이를 씻어서
# ground_truth : 흰 것만 있어요 밀가루 먹으면 흰 것 만 있으면 그때 이제 굼벵이를 씻겨 다 씻긴다음에
#
# source_text :  똥구멍에 이제 흙 묻은 것까지 다 땡이네 다 씻그면
# result :       똥구멍에 이제 흙 묻은 것까지 다 때서 다 씻으면
# ground_truth : 똥구멍에 이제 흙 묻은 것까지 다 때서 다 씻그면
#
# source_text :  그걸로 놩 끌리면 이제 굼벵이를 막 쏢으면 굼벵이가 뽈록뽈록 영 되잖아 그거저기 그 저기 맛 그거
# result :       그걸로 놔서 끓이면 이제 굼벵이를 막 삶으면 굼
# ground_truth : 그걸로 놔서 끓으면 이제 굼벵이를 막 삶으면 굼벵이가 뽈록뽈록 그렇게 되잖아 그거저기 그 저기 맛 그거
#
# source_text :  뭐꽈그거
# result :       뭐에요 그거
# ground_truth : 뭐지그거
#
# source_text :  피삭피삭 하켜
# result :       피식피식 하겠다
# ground_truth : 피삭피삭 할꺼야
#
# source_text :  아 아니 아니야 바농으로 그냥 폭 눌르면
# result :       아 아니 아니야 바늘로 그냥 폭 눌르면
# ground_truth : 아 아니 아니야 바늘으로 그냥 폭 눌르면
#
# source_text :  그 새끼 먹일꺼랜해 막
# result :       그 새끼 먹일꺼라고해 막
# ground_truth : 그 새끼 먹일꺼라고 막
#
# source_text :  해서 나 다 해줜게 겅행으네 그거
# result :       해서 나 다 해주었어 그래서 그거
# ground_truth : 해서 나 다 해줬어 그렇게해서 그거
#
# source_text :  를 푹푹 눌렁으네
# result :       를 푹푹 눌러서
# ground_truth : 를 푹푹 눌러서
#
# source_text :  아니 국물을 푹 끓이면 그 국물을 이제 아기들 먹이젠하면 감기약 먹이는 물병약있지 그
# result :       아니 국물을 푹 끓이면 그 국물을 이제 아기들 먹이려고하면 감기약
# ground_truth : 아니 국물을 푹 끓이면 그 국물을 이제 아기들 먹이려고하면 감기약 먹이는 물병약있지 그
#
# source_text :  애기 입에다 그냥 쪽 쫘줘버리는 거라 그럼 이제 꿀꺽 먹잖아 겅하난예
# result :       애기 입에다 그냥 쪽 줘버리는 거야 그럼 이제 꿀꺽 먹잖아
# ground_truth : 애기 입에다 그냥 쪽 쫘줘버리는 거야 그럼 이제 꿀꺽 먹잖아 그렇게하면요
#
# source_text :  호흡기 그거 하나도 안 해 금방 나아부런게 그걸로 한 몇 번
# result :       호흡기 그거 하나도 안 해 금방 나아버렸어 그걸로 한 몇 번
# ground_truth : 호흡기 그거 하나도 안 해 금방 나아버렸어 그걸로 한 몇 번
#
# source_text :  야 근데 굼벵이 열 개 하영 어느만큼이나 나와
# result :       야 근데 굼벵이 열 개 많이 어느 만큼이나 나와
# ground_truth : 야 근데 굼벵이 열 개 하면 어느만큼이나 나와
#
# source_text :  한 사발 한 사발도 안나오켜
# result :       한 사발 한 사발도 안 나오겠다
# ground_truth : 한 사발 한 사발도 안나올꺼야
#
# source_text :  한 사발도 안나오주게
# result :       한 사발도 안 나오지
# ground_truth : 한 사발도 안나오죠
#
# source_text :  대 유지 이시난
# result :       대 유지 있으니까
# ground_truth : 대 유지 있으니까
#
# source_text :  게난 기침 콜록콜록 하난
# result :       그러니까 기침 콜록콜록 하니까
# ground_truth : 그러니까 기침 콜록콜록 하니까
#
# source_text :  호흡기 그거 하니까요 기관지 나쁘네
# result :       호흡기 그거 하니까요 기관지 나쁘잖아
# ground_truth : 호흡기 그거 하니까요 기관지 나빠서
#
# source_text :  그것도 맥일 때 맥여야지
# result :       그것도 먹일 때 먹여야지
# ground_truth : 그것도 먹일 때 먹여야지
#
# iteration num :  12400
# source_text :  버랭이 젓 버랭이 이제는 젓 버랭이 안나오잖아
# result :       벌레 젓 벌레 이제는 젓 벌레 안 나오잖아
# ground_truth : 벌레 젓 벌레 이제는 젓 벌레 안나오잖아
#
# source_text :  아니 이서 우리 하영 맥연 아니
# result :       아니 있어 우리 많이 먹였어 아니야
# ground_truth : 아니 있어 우리 많이 먹였어 아니
#
# source_text :  시노리낭나무 에도 있구양양 가시낭나무 국 가시낭나무 우리 국 가시 요롱 나는 낭 거기에도 있고
# result :       시노리낭나무 에도 있구양양 가시낭나무 국가시낭나무 우리
# ground_truth : 시노리낭나무 에도 있구양양 가시낭나무 국 가시낭나무 우리 국 가시 요렇게 나는 나무 거기에도 있고
#
# source_text :  그다음에 윷놀이 낭 거기에도 있고 그다음에 무화과낭나무
# result :       그다음에 윷놀이 나서 거기에도 있고 그다음에 무화과낭나무
# ground_truth : 그다음에 윷놀이 나무 거기에도 있고 그다음에 무화과낭나무
#
# source_text :  거기도 이서
# result :       거기도 있어
# ground_truth : 거기도 있어
#
# source_text :  기 난 젓 버랭인 말만 들어봤지 안봐봔
# result :       그래 난 젓 벌래 말만 들어봤지 안 봤어 봤어
# ground_truth : 그래 난 젓 벌레 말만 들어봤지 못봤어
#
# source_text :  국가시낭나무이 최고 그것이 최고고 그담이 시노리낭 늙은 낭에 강으네 쫄르매
# result :       꾸지뽕나무이 최고 그것이 최고고 그담이 시노리나무 늙은 나무에 가서
# ground_truth : 국가시낭나무이 최고 그것이 최고고 그담이 시노리나무 늙은 나무에 가서 조르면
#
# source_text :  아니 그게 아부지가 어떵알암수과 하면 고랭이 똥을 싼 게 나온대
# result :       아니 그게 아부지가 어떻게 알아요 하면 고양이 똥을 싼 게 나온대
# ground_truth : 아니 그게 아부지가 어떻게알았습니까 하면 고양이 똥을 싼 게 나온대
#
# source_text :  그 디 있는거라 겅허믄 영 톱으로 영 잘르고 영 잘랑으네
# result :       그 디 있는거야 그러면 이렇게 톱으로 이렇게 자르고 이렇게 잘라서
# ground_truth : 그 디 있는거라 그러면 이렇게 톱으로 이렇게 자르고 그렇게 잘라서
#
# source_text :  탁 깨면 그 속에 잣 버랭이가 영 이서
# result :       탁 깨면 그 속에 잣 벌레가 이렇게 있어
# ground_truth : 탁 깨면 그 속에 잣 벌레가 영 있어
#
# source_text :  그런데 그대로 또 덮엉 묶엉 가졍와
# result :       그런데 그대로 또 덮어서 묶어서 가져와
# ground_truth : 그런데 그대로 또 덮어서 묶어서 가져와
#
# source_text :  우리도 우리 어머니네 그거 해놨댄 해서
# result :       우리도 우리 어머니네 그거 해놨다고 했어요
# ground_truth : 우리도 우리 어머니네 그거 해놨다고 해서
#
# source_text :  감기하고 실강실강하는데 굼벵이를 안맥이고 그거 맥이래
# result :       감기하고 실강실강하는데 굼벵이를 안먹이고 그거 먹이
# ground_truth : 감기하고 실강실강하는데 굼벵이를 안먹이고 그거 먹이래
#
# source_text :  맥이고 우리 아이들도 어릴 때 우리 저기 6 7 어릴 때 하르방 맨날 아이들이 어려놨주게 저기 막 그 뭐라 해야 됩니까
# result :       먹이고 우리 아이들도 어릴 때 우리 저기 6 7 어릴 때 할아버지 맨날 아이들이
# ground_truth : 먹이고 우리 아이들도 어릴 때 우리 저기 6 7 어릴 때 할아버지 맨날 아이들이 어렸었죠 저기 막 그 뭐라 해야 됩니까
#
# source_text :  영양실조 걸린 것처럼 어릴 때 철분 결핍성빈혈 이신거
# result :       영양실조 걸린 것처럼 어릴 때 철분 결핍성빈혈 있는거야
# ground_truth : 영양실조 걸린 것처럼 어릴 때 철분 결핍성빈혈 있는거야
#
# source_text :  나가 철분 결핍성 빈혈이성있어서 좀 맥이난 아기도
# result :       내가 철분 결핍성 빈혈 이성 있어서 좀 먹이니까 아기도
# ground_truth : 내가 철분 결핍성 빈혈이성있어서 좀 먹으니까 아기도
#
# source_text :  감기도 겅 걸려불더라버리더라
# result :       감기도 그렇게 걸려불더버리더라
# ground_truth : 감기도 그렇게 걸려불더라버리더라
#
# source_text :  경허난 이제막 베리베리 해놔서 거난 할망 하르방 하는데 영 봔
# result :       그러니까 이제막 베리베리 해놔서 그러니까 할머니 할아버지 하는데 이렇게 봤어
# ground_truth : 그러니까 이제막 비실비실 했었어 그러니까 할머니 할아버지 하는데 영 봤어
#
# source_text :  손지들이 베리베허난예 그것만 하러다녀 전날 그거 해가지고예 요만큼 해
# result :       손주들이 베리베하니까요 그것만 하러 다녀 전날 그거 해가
# ground_truth : 손자들이 비실비실하니까요 그것만 하러다녀 전날 그거 해가지고요 요만큼 해
#
# source_text :  경 커
# result :       그렇게 커
# ground_truth : 그렇게 커
#
# source_text :  그건 너무 훅수다게
# result :       그건 너무 훅 하고 있어요
# ground_truth : 그건 너무 훅입니다
#
# source_text :  여기 여기 버렝이 뭐가 뭐랜해야난
# result :       여기 여기 벌레 뭐가 뭐라고해야하니까
# ground_truth : 여기 여기 벌레 뭐가 뭐라고해야되지
#
# source_text :  잔잔한건 이만큼하고 좀 큰건 이만큼 허여
# result :       작은건 이만큼하고 좀 큰건 이만큼 해요
# ground_truth : 잔잔한건 이만큼하고 좀 큰건 이만큼 해
#
# source_text :  대가리 영 하믄
# result :       대가리 이렇게 하면
# ground_truth : 머리 이렇게 하믄
#
# source_text :  대가리는 거멍 한거 아니
# result :       대가리는 까맣게 한거 아니야
# ground_truth : 대가리는 까만 한거 아니야
#
# source_text :  대가리 요 이렇게 대가리 거멍하먼
# result :       대가리요 이렇게 대가리 까맣게되면
# ground_truth : 대가리 요 이렇게 대가리 까마면
#
# source_text :  대가리 톡 쫄랑으네 짠
# result :       대가리 톡 잘라서 짰어
# ground_truth : 대가리 톡 졸라서 짯어
#
# source_text :  나는 이제 이걸 못맥여 근데 할망은 근데 저거를 영행으네 입드래 하며 촥
# result :       나는 이제 이걸 못먹여 근데 할머니는 근데 저거를 이렇게해서 입
# ground_truth : 나는 이제 이걸 못먹여 근데 할머니는 근데 저거를 그렇게해서 입드래 하며 촥
#
# source_text :  기
# result :       그래
# ground_truth : 그래
#
# source_text :  진짜 무식하게 맥였쪄
# result :       진짜 무식하게 먹였어
# ground_truth : 진짜 무식하게 먹였어
#
# source_text :  착 맥이고 나는 이거를 맥이랜 하면
# result :       착 먹이고 나는 이거를 먹이라고 하면
# ground_truth : 착 먹이고 나는 이거를 먹이라고 하면
#
# source_text :  영행으네 접시에 짜 경행으네 숟가락으로
# result :       이렇게해서 접시에 짜 그렇게 숟가락으로
# ground_truth : 그렇게해서 접시에 짜 그래서 숟가락으로
#
# source_text :  머리 똑 쫄랑으네 숟가락으로 영 살아있는거
# result :       머리 똑 잘라서 숟가락으로 이렇게 살아있는거야
# ground_truth : 머리 똑 잘라서 숟가락으로 영 살아있는거
#
# source_text :  그래 어떵 경해
# result :       그래 어떻게 그렇게해
# ground_truth : 그래 어떻게 그렇게해
#
# source_text :  할아방한테 이거
# result :       할아버지한테 이거
# ground_truth : 할아버지한테 이거
#
# source_text :  이거 여기 짜줍서 하면 할아방이
# result :       이거 여기 짜주세요 하면 할아버지가
# ground_truth : 이거 여기 짜주세요 하면 할아버지가
#
# source_text :  경행으네 영 숟가락으로 짜주면 그거 영 해 맥여
# result :       그렇게해서 이렇게 숟가락으로 짜주면 그거 이렇게 해 먹여요
# ground_truth : 그렇게해서 영 숟가락으로 짜주면 그거 영 해 먹여
#
# source_text :  게신디 할망은
# result :       그랬는데 할머니는
# ground_truth : 그랬는데 할머니는
#
# source_text :  아니 그 무사 젓 버랭이 같이 씹어먹어 불면 안되어
# result :       아니 그 왜 젓 벌레 같이 씹어먹어 버리면 안돼
# ground_truth : 아니 그 왜 젓 벌레 같이 씹어먹어 버리면 안되어
#
# source_text :  아니 못 먹는 건 아닌데 버랭이랜 생각하면 안 먹지
# result :       아니 못 먹는 건 아닌데 벌레라고 생각하면 안 먹지
# ground_truth : 아니 못 먹는 건 아닌데 벌레라고 생각하면 안 먹지
#
# source_text :  무화과 낭에 완전 컨게
# result :       무화과 나무에 완전 크더라구요
# ground_truth : 무화과 나무에 완전 컷어
#
# source_text :  아 기
# result :       아 그래
# ground_truth : 아 그래
#
# source_text :  그러면 그 그 버랭이똥이 그 복숭게 보면 그 그게 똥 아니
# result :       그러면 그 그 벌레똥이 그 복숭아 보면 그 그게 똥 아니야
# ground_truth : 그러면 그 그 벌레똥이 그 복숭아 보면 그 그게 똥 아니야
#
# source_text :  경 핸
# result :       그렇게 해서
# ground_truth : 그렇게 했어
#
# source_text :  한번 바봐야 되켜
# result :       한번 바봐야 되겠다
# ground_truth : 한번 바봐야 되겠어
#
# source_text :  게난이 딱 거기만 이신게 아니 어디 이실지 몰라 영자르고 영 자르더라
# result :       그러니까 딱 거기만 있는게 아니 어디 있을지 몰라 영자르고 이렇게 자르
# ground_truth : 그러니까 딱 거기만 있는게 아니야 어디 있을지 몰라 영자르고 영 자르더라
#
# source_text :  겅행이네 했대요
# result :       그렇게 해서 했대요
# ground_truth : 그래서 했대요
#
# source_text :  맞아 옛날에 좀베렝이는 나도 얘기 많이 들어서
# result :       맞아 옛날에 좀비래기는 나도 얘기 많이 들었어
# ground_truth : 맞아 옛날에 좀벌레는 나도 얘기 많이 들었어
#
# source_text :  난 먹언
# result :       난 먹었어
# ground_truth : 난 먹었어
#
# source_text :  난 먹어신지 모를쿠다 모를켜마는
# result :       난 먹었는지 모르겠어요 모르겠지만은
# ground_truth : 난 먹었는지 모르겠어요 모르겠지만
#
# iteration num :  12450

# %%
with open("/content/drive/MyDrive/WARNING_PRIVATE_FOLDER/OSSP2AntiGPT9/ai/no_commit/wrong_translation_stoendtrial.json", "w") as outfile:
    json.dump(out_json, outfile,ensure_ascii=False)

# %%
for i,v in enumerate(out_json["tp"]):
    out_json["tp"][i] = (v[0].strip(),v[1].strip(),v[2].strip())
