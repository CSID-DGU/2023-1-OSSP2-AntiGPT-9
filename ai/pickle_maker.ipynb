# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install transformers;
# !pip install sentencepiece;
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.29.0-py3-none-any.whl (7.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 38.5 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.0)
# Collecting huggingface-hub<1.0,>=0.11.0 (from transformers)
#   Downloading huggingface_hub-0.14.1-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 8.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.27.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 64.6 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (2023.4.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.14.1 tokenizers-0.13.3 transformers-4.29.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 17.0 MB/s eta 0:00:00
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.99

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# Token is valid.
# Your token has been saved in your configured git credential helpers (store).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
# %cd /content/drive/MyDrive/WARNING_PRIVATE_FOLDER/OSSP2AntiGPT9/ai/lib/
# !pwd
# Out:
# /content/drive/MyDrive/WARNING_PRIVATE_FOLDER/OSSP2AntiGPT9/ai/lib
# /content/drive/MyDrive/WARNING_PRIVATE_FOLDER/OSSP2AntiGPT9/ai/lib

# %%
from tokenization_kobert import KoBertTokenizer

import json
from copy import deepcopy
import random
from tqdm.notebook import tqdm

from transformers import (
    PreTrainedTokenizerFast as BaseGPT2Tokenizer,
    EncoderDecoderModel,
)

# %%
src_tokenizer = KoBertTokenizer.from_pretrained('monologg/kobert')
add_tokenizer = KoBertTokenizer.from_pretrained('monologg/kobert')
# Out:
# Downloading (…)zer_78b3253a26.model:   0%|          | 0.00/371k [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/77.8k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/51.0 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/426 [00:00<?, ?B/s]
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'BertTokenizer'.
# The class this function is called from is 'KoBertTokenizer'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'BertTokenizer'.
# The class this function is called from is 'KoBertTokenizer'.

# %%
class GPT2Tokenizer(BaseGPT2Tokenizer):
    def build_inputs_with_special_tokens(self, token_ids, _):
        return token_ids + [self.eos_token_id]
trg_tokenizer = GPT2Tokenizer.from_pretrained("skt/kogpt2-base-v2",
  bos_token='</s>', eos_token='</s>', unk_token='<unk>',
  pad_token='<pad>', mask_token='<mask>')

# %% [markdown]
# ## 제발

# %%
with open("/content/drive/MyDrive/WARNING_PRIVATE_FOLDER/OSSP2AntiGPT9/ai/plz/added_tokens.json", 'rb') as f:
    dw_dict = json.load(f)
dict_swap = {v:k for k,v in dw_dict.items()}

# %%
ma=12290
mi=8002
for i in range(8002,12291):
    src_tokenizer.add_tokens(dict_swap[i])

# %%
print(src_tokenizer.encode("가게"))
# Out:
# [2, 11596, 3]

# %%
# # 토크나이저에도 새로운 단어를 추가합니다
# src_tokenizer.add_tokens(new_words)

# 인코더의 임베딩 크기를 조정합니다
model.encoder.resize_token_embeddings(len(src_tokenizer))

# 추가한 단어가 토크나이저에 적용되었는지 확인합니다
print(src_tokenizer.decode(src_tokenizer.encode(new_words[0])))
# Out:
# [CLS] 섭췰한거 [SEP]

# %%
# # 토크나이저들을 모델에 저장합니다
model.config.encoder_attention_type = 'full'
model.config.decoder_attention_type = 'full'
model.config.src_vocab_size = len(src_tokenizer)
model.config.tgt_vocab_size = len(trg_tokenizer)

# push_to_hub() 함수를 사용하여 모델을 Hugging Face Hub에 업로드합니다
model.push_to_hub("ossp-v0_2")
# Out:
# Upload 1 LFS files:   0%|          | 0/1 [00:00<?, ?it/s]
# pytorch_model.bin:   0%|          | 0.00/1.02G [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-bf8e99986157> in <cell line: 9>()
#       7 # push_to_hub() 함수를 사용하여 모델을 Hugging Face Hub에 업로드합니다
#       8 model.push_to_hub("ossp-v0_2")
# ----> 9 src_tokenizer.push_to_hub("ossp-v0_2")
#
# /usr/local/lib/python3.9/dist-packages/transformers/utils/hub.py in push_to_hub(self, repo_id, use_temp_dir, commit_message, private, use_auth_token, max_shard_size, create_pr, **deprecated_kwargs)
#     779
#     780             # Save all files.
# --> 781             self.save_pretrained(work_dir, max_shard_size=max_shard_size)
#     782
#     783             return self._upload_modified_files(
#
# /usr/local/lib/python3.9/dist-packages/transformers/tokenization_utils_base.py in save_pretrained(self, save_directory, legacy_format, filename_prefix, push_to_hub, **kwargs)
#    2172         file_names = (tokenizer_config_file, special_tokens_map_file)
#    2173
# -> 2174         save_files = self._save_pretrained(
#    2175             save_directory=save_directory,
#    2176             file_names=file_names,
#
# /usr/local/lib/python3.9/dist-packages/transformers/tokenization_utils_base.py in _save_pretrained(self, save_directory, file_names, legacy_format, filename_prefix)
#    2220                 logger.info(f"added tokens file saved in {added_tokens_file}")
#    2221
# -> 2222         vocab_files = self.save_vocabulary(save_directory, filename_prefix=filename_prefix)
#    2223
#    2224         return file_names + vocab_files + (added_tokens_file,)
#
# TypeError: save_vocabulary() got an unexpected keyword argument 'filename_prefix'

# %%
import pickle
with open('save_edm.pickle', 'wb') as f:
    pickle.dump(model, f)
with open('save_src_tk.pickle', 'wb') as f:
    pickle.dump(src_tokenizer, f)
with open('save_trg_tk.pickle', 'wb') as f:
    pickle.dump(trg_tokenizer, f)

# %%
with open('no_commit/save_src_tk.pickle','rb') as f:
    add_tokenizer=pickle.load(f)

# %%
# %cd ..
# Out:
# /content/drive/MyDrive/WARNING_PRIVATE_FOLDER/OSSP2AntiGPT9/ai

# %%
print(len(add_tokenizer))
# Out:
# 12291

# %% [markdown]
# ## 형태소 분석기 테스트

# %%
# !pip install konlpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: konlpy in /usr/local/lib/python3.9/dist-packages (0.6.0)
# Requirement already satisfied: JPype1>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from konlpy) (1.4.1)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.9/dist-packages (from konlpy) (4.9.2)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.9/dist-packages (from konlpy) (1.22.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from JPype1>=0.7.0->konlpy) (23.0)

# %%
#install mecab
from konlpy.tag import Kkma, Komoran, Okt, Mecab

#mec = Mecab()
okt = Okt()
kkm = Kkma()
kom = Komoran()

# %%
with open("/content/drive/MyDrive/WARNING_PRIVATE_FOLDER/OSSP2AntiGPT9/ai/no_commit/real_word_data.json", 'rb') as f:
    dw_dict = json.load(f)
cnt_words = []

import time
for i,v in tqdm(enumerate(dw_dict["utterance"])):
    if 0 in src_tokenizer.encode(v["dialect_form"]) and not (v["dialect_form"] in cnt_words):
        cnt_words.append(v["dialect_form"])
        print(v["dialect_form"])
        print(okt.morphs(v["dialect_form"]))
        print("#"*50)
# Out:
# 0it [00:00, ?it/s]
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# 차가와수꽈
# ['차가와', '수', '꽈']
# ['▁차', '가', '와', '수', '꽈']
# ##################################################
# 무사마씸게
# ['무사마씸', '게']
# ['▁무', '사', '마', '씸', '게']
# ##################################################
# 겅해부나네
# ['겅', '해부', '나네']
# ['▁', '겅', '해', '부', '나', '네']
# ##################################################
# 이추룩하믄
# ['이', '추', '룩', '하믄']
# ['▁이', '추', '룩', '하', '믄']
# ##################################################
# 쭐면
# ['쭐', '면']
# ['▁', '쭐', '면']
# ##################################################
# 쭐었어이
# ['쭐었', '어', '이']
# ['▁', '쭐', '었', '어', '이']
# ##################################################
# 냄쪄
# ['냄', '쪄']
# ['▁', '냄', '쪄']
# ##################################################
# 없수꽈
# ['없수꽈']
# ['▁없', '수', '꽈']
# ##################################################
# 돌앙댕겸주
# ['돌', '앙', '댕겸주']
# ['▁돌', '앙', '댕', '겸', '주']
# ##################################################
# 물엉댕기잖아
# ['물', '엉', '댕기', '잖아']
# ['▁물', '엉', '댕', '기', '잖', '아']
# ##################################################
# 모셩으네
# ['모셩으', '네']
# ['▁모', '셩', '으', '네']
# ##################################################
# 부담되그넹
# ['부담', '되', '그', '넹']
# ['▁부담', '되', '그', '넹']
# ##################################################
# 겅허여그넹
# ['겅허여그넹']
# ['▁', '겅', '허', '여', '그', '넹']
# ##################################################
# 얘기하여 그넹
# ['얘기', '하여', '그넹']
# ['▁얘기', '하여', '▁그', '넹']
# ##################################################
# 채워불믄
# ['채워', '불', '믄']
# ['▁채', '워', '불', '믄']
# ##################################################
# 갔다그넹
# ['갔다', '그', '넹']
# ['▁', '갔다', '그', '넹']
# ##################################################
# 허그넹
# ['허그', '넹']
# ['▁허', '그', '넹']
# ##################################################
# 허멍그넹
# ['허멍그넹']
# ['▁허', '멍', '그', '넹']
# ##################################################
# 쉬잰
# ['쉬', '잰']
# ['▁쉬', '잰']
# ##################################################
# 버쳐넹
# ['버쳐넹']
# ['▁버', '쳐', '넹']
# ##################################################
# 징징대여그넹
# ['징징대여', '그', '넹']
# ['▁', '징', '징', '대', '여', '그', '넹']
# ##################################################
# 댕겨부난
# ['댕겨부', '난']
# ['▁', '댕', '겨', '부', '난']
# ##################################################
# 잘라불믄
# ['잘라', '불', '믄']
# ['▁잘', '라', '불', '믄']
# ##################################################
# 파마하믄
# ['파마', '하믄']
# ['▁파', '마', '하', '믄']
# ##################################################
# 버텸시꺼라
# ['버텸시꺼', '라']
# ['▁버', '텸', '시', '꺼', '라']
# ##################################################
# 뭣도
# ['뭣', '도']
# ['▁', '뭣', '도']
# ##################################################
# 나가졍
# ['나가졍']
# ['▁나가', '졍']
# ##################################################
# 버텽
# ['버텽']
# ['▁버', '텽']
# ##################################################
# 떨멍그넹
# ['떨멍그넹']
# ['▁떨', '멍', '그', '넹']
# ##################################################
# 불러넹
# ['불러넹']
# ['▁불러', '넹']
# ##################################################
# 하지말아그넹
# ['하지말아', '그', '넹']
# ['▁하지', '말', '아', '그', '넹']
# ##################################################
# 반이믄
# ['반', '이', '믄']
# ['▁반', '이', '믄']
# ##################################################
# 있쪄마는
# ['있', '쪄', '마는']
# ['▁있', '쪄', '마', '는']
# ##################################################
# 줘봤쪄
# ['줘', '봤', '쪄']
# ['▁', '줘', '봤', '쪄']
# ##################################################
# 퉁쳐그넹
# ['퉁쳐그넹']
# ['▁', '퉁', '쳐', '그', '넹']
# ##################################################
# 줬쪄
# ['줬', '쪄']
# ['▁', '줬', '쪄']
# ##################################################
# 시내믄
# ['시', '내', '믄']
# ['▁시', '내', '믄']
# ##################################################
# 줭이난
# ['줭이', '난']
# ['▁', '줭', '이', '난']
# ##################################################
# 다념시믄
# ['다념시믄']
# ['▁다', '념', '시', '믄']
# ##################################################
# 허영그넹
# ['허영', '그', '넹']
# ['▁허', '영', '그', '넹']
# ##################################################
# 뭣허면
# ['뭣허', '면']
# ['▁', '뭣', '허', '면']
# ##################################################
# 버스탕그넹
# ['버스', '탕', '그', '넹']
# ['▁버스', '탕', '그', '넹']
# ##################################################
# 버스타그넹
# ['버스', '타', '그', '넹']
# ['▁버스', '타', '그', '넹']
# ##################################################
# 겅
# ['겅']
# ['▁', '겅']
# ##################################################
# 설사하여그넹
# ['설사', '하여', '그', '넹']
# ['▁설', '사', '하여', '그', '넹']
# ##################################################
# 나쁘믄
# ['나쁘', '믄']
# ['▁나', '쁘', '믄']
# ##################################################
# 불켱
# ['불켱']
# ['▁불', '켱']
# ##################################################
# 따땃
# ['따땃']
# ['▁따', '땃']
# ##################################################
# 하다그넹
# ['하다', '그', '넹']
# ['▁하다', '그', '넹']
# ##################################################
# 나왐서
# ['나왐', '서']
# ['▁나', '왐', '서']
# ##################################################
# 나왐시커라
# ['나왐시커', '라']
# ['▁나', '왐', '시', '커', '라']
# ##################################################
# 먹엄쪄
# ['먹엄쪄']
# ['▁먹', '엄', '쪄']
# ##################################################
# 날려그넹
# ['날려', '그', '넹']
# ['▁날', '려', '그', '넹']
# ##################################################
# 인해그넹
# ['인해', '그', '넹']
# ['▁인해', '그', '넹']
# ##################################################
# 않앴는가
# ['않앴는', '가']
# ['▁않', '앴', '는', '가']
# ##################################################
# 봉사모임마씸
# ['봉사', '모', '임마', '씸']
# ['▁봉', '사', '모', '임', '마', '씸']
# ##################################################
# 허머그넹
# ['허머', '그', '넹']
# ['▁허', '머', '그', '넹']
# ##################################################
# 겅해났지
# ['겅해났', '지']
# ['▁', '겅', '해', '났', '지']
# ##################################################
# 촐령그넹
# ['촐령그넹']
# ['▁', '촐', '령', '그', '넹']
# ##################################################
# 하멍그넹
# ['하멍그넹']
# ['▁하', '멍', '그', '넹']
# ##################################################
# 햄데네머그넹
# ['햄데', '네', '머그', '넹']
# ['▁', '햄', '데', '네', '머', '그', '넹']
# ##################################################
# 살라믄
# ['살라', '믄']
# ['▁살', '라', '믄']
# ##################################################
# 못하멍그넹
# ['못', '하', '멍', '그', '넹']
# ['▁못', '하', '멍', '그', '넹']
# ##################################################
# 동거해그넹
# ['동거', '해', '그', '넹']
# ['▁동', '거', '해', '그', '넹']
# ##################################################
# 말암쪄
# ['말암', '쪄']
# ['▁말', '암', '쪄']
# ##################################################
# 동거햄쪄
# ['동거', '햄', '쪄']
# ['▁동', '거', '햄', '쪄']
# ##################################################
# 뭐햄쪄
# ['뭐햄', '쪄']
# ['▁뭐', '햄', '쪄']
# ##################################################
# 말았쪄
# ['말았', '쪄']
# ['▁말', '았', '쪄']
# ##################################################
# 살아지믄
# ['살아지', '믄']
# ['▁살아', '지', '믄']
# ##################################################
# 열사람이믄이
# ['열', '사람', '이', '믄', '이']
# ['▁열', '사람', '이', '믄', '이']
# ##################################################
# 잘해줘점시믄
# ['잘', '해줘', '점', '시', '믄']
# ['▁잘', '해', '줘', '점', '시', '믄']
# ##################################################
# 안불럼쪄
# ['안', '불', '럼', '쪄']
# ['▁안', '불', '럼', '쪄']
# ##################################################
# 어떵
# ['어떵']
# ['▁어', '떵']
# ##################################################
# 허믄이
# ['허', '믄', '이']
# ['▁허', '믄', '이']
# ##################################################
# 가믄이
# ['가', '믄', '이']
# ['▁', '가', '믄', '이']
# ##################################################
# 허믄
# ['허', '믄']
# ['▁허', '믄']
# ##################################################
# 어떵허는가
# ['어떵허는', '가']
# ['▁어', '떵', '허', '는', '가']
# ##################################################
# 댕기멍
# ['댕기', '멍']
# ['▁', '댕', '기', '멍']
# ##################################################
# 만남쪄이
# ['만남', '쪄이']
# ['▁만남', '쪄', '이']
# ##################################################
# 게믄
# ['게', '믄']
# ['▁게', '믄']
# ##################################################
# 겅허난
# ['겅허', '난']
# ['▁', '겅', '허', '난']
# ##################################################
# 겅허니까
# ['겅허', '니까']
# ['▁', '겅', '허', '니까']
# ##################################################
# 어떵헐거냐
# ['어떵헐거', '냐']
# ['▁어', '떵', '헐', '거', '냐']
# ##################################################
# 움직여졍
# ['움직여', '졍']
# ['▁', '움', '직', '여', '졍']
# ##################################################
# 쨔이를
# ['쨔', '이를']
# ['▁', '쨔', '이', '를']
# ##################################################
# 죽어져시믄이
# ['죽어져시', '믄', '이']
# ['▁죽', '어', '져', '시', '믄', '이']
# ##################################################
# 가잰
# ['가', '잰']
# ['▁', '가', '잰']
# ##################################################
# 겅허믄
# ['겅허믄']
# ['▁', '겅', '허', '믄']
# ##################################################
# 안 졀
# ['안', '졀']
# ['▁안', '▁', '졀']
# ##################################################
# 겅허난이
# ['겅허난', '이']
# ['▁', '겅', '허', '난', '이']
# ##################################################
# 거믄
# ['거', '믄']
# ['▁거', '믄']
# ##################################################
# 치료해보잰
# ['치료', '해보', '잰']
# ['▁치료', '해', '보', '잰']
# ##################################################
# 겅허게
# ['겅허', '게']
# ['▁', '겅', '허', '게']
# ##################################################
# 들여보내잰
# ['들여', '보내', '잰']
# ['▁들여', '보', '내', '잰']
# ##################################################
# 이시믄이
# ['이', '시', '믄', '이']
# ['▁이', '시', '믄', '이']
# ##################################################
# 이시믄이
# ['이', '시', '믄', '이']
# ['▁이', '시', '믄', '이']
# ##################################################
# 안 나왐서
# ['안', '나왐', '서']
# ['▁안', '▁나', '왐', '서']
# ##################################################
# 나다니잰
# ['나다니', '잰']
# ['▁나', '다', '니', '잰']
# ##################################################
# 물어봔
# ['물어', '봔']
# ['▁물어', '봔']
# ##################################################
# 또똣헌
# ['또똣헌']
# ['▁또', '똣', '헌']
# ##################################################
# 어떵해야
# ['어떵해', '야']
# ['▁어', '떵', '해야']
# ##################################################
# 어떵헐꺼
# ['어떵헐꺼']
# ['▁어', '떵', '헐', '꺼']
# ##################################################
# 맞추믄
# ['맞추', '믄']
# ['▁맞추', '믄']
# ##################################################
# 골으믄
# ['골으', '믄']
# ['▁골', '으', '믄']
# ##################################################
# 헙시다
# ['헙시다']
# ['▁', '헙', '시', '다']
# ##################################################
# 다허믄
# ['다', '허', '믄']
# ['▁다', '허', '믄']
# ##################################################
# 조으믄
# ['조으', '믄']
# ['▁조', '으', '믄']
# ##################################################
# 안허믄
# ['안', '허', '믄']
# ['▁안', '허', '믄']
# ##################################################
# 먹고잰
# ['먹고', '잰']
# ['▁먹고', '잰']
# ##################################################
# 타보잰게
# ['타', '보', '잰게']
# ['▁타', '보', '잰', '게']
# ##################################################
# 겅허난마씨
# ['겅', '허난', '마씨']
# ['▁', '겅', '허', '난', '마', '씨']
# ##################################################
# 따봔
# ['따봔']
# ['▁따', '봔']
# ##################################################
# 댕기잰
# ['댕기', '잰']
# ['▁', '댕', '기', '잰']
# ##################################################
# 뻗쳥
# ['뻗쳥']
# ['▁', '뻗', '쳥']
# ##################################################
# 벋치면
# ['벋치면']
# ['▁', '벋', '치', '면']
# ##################################################
# 영햄쪄이
# ['영', '햄', '쪄이']
# ['▁영', '햄', '쪄', '이']
# ##################################################
# 쪄부난
# ['쪄', '부', '난']
# ['▁', '쪄', '부', '난']
# ##################################################
# 올라가잰
# ['올라가', '잰']
# ['▁올라', '가', '잰']
# ##################################################
# 앉잰
# ['앉', '잰']
# ['▁', '앉', '잰']
# ##################################################
# 살쪄그내
# ['살쪄', '그', '내']
# ['▁살', '쪄', '그', '내']
# ##################################################
# 말햄쪄
# ['말햄', '쪄']
# ['▁말', '햄', '쪄']
# ##################################################
# 겅해나신지
# ['겅', '해나', '신지']
# ['▁', '겅', '해', '나', '신', '지']
# ##################################################
# 겅허긴
# ['겅허긴']
# ['▁', '겅', '허', '긴']
# ##################################################
# 뒹굴어가멍
# ['뒹굴', '어가', '멍']
# ['▁', '뒹', '굴', '어', '가', '멍']
# ##################################################
# 꺼내놘
# ['꺼내놘']
# ['▁꺼', '내', '놘']
# ##################################################
# 뭐허잰
# ['뭐', '허', '잰']
# ['▁뭐', '허', '잰']
# ##################################################
# 겅허는디
# ['겅', '허는디']
# ['▁', '겅', '허', '는', '디']
# ##################################################
# 겅허는데
# ['겅', '허는데']
# ['▁', '겅', '허', '는데']
# ##################################################
# 겅헙서게
# ['겅헙서', '게']
# ['▁', '겅헙', '서', '게']
# ##################################################
# 겅허멍도
# ['겅허멍', '도']
# ['▁', '겅', '허', '멍', '도']
# ##################################################
# 가봐시믄
# ['가봐시', '믄']
# ['▁', '가', '봐', '시', '믄']
# ##################################################
# 겅해그내
# ['겅', '해', '그', '내']
# ['▁', '겅', '해', '그', '내']
# ##################################################
# 겅해났구나
# ['겅', '해', '났구나']
# ['▁', '겅', '해', '났', '구나']
# ##################################################
# 따숩다
# ['따숩다']
# ['▁따', '숩', '다']
# ##################################################
# 가기넹
# ['가기', '넹']
# ['▁', '가', '기', '넹']
# ##################################################
# 겅해시민
# ['겅', '해', '시민']
# ['▁', '겅', '해', '시민']
# ##################################################
# 겅했고
# ['겅했', '고']
# ['▁', '겅', '했고']
# ##################################################
# 걸렸쪄
# ['걸렸', '쪄']
# ['▁걸', '렸', '쪄']
# ##################################################
# 겅할건디
# ['겅할건디']
# ['▁', '겅', '할', '건', '디']
# ##################################################
# 이으잰
# ['이으', '잰']
# ['▁이', '으', '잰']
# ##################################################
# 비잰
# ['비', '잰']
# ['▁비', '잰']
# ##################################################
# 겅헌진
# ['겅헌진']
# ['▁', '겅', '헌', '진']
# ##################################################
# 시켬수과
# ['시', '켬수과']
# ['▁시', '켬', '수', '과']
# ##################################################
# 겅해나부니까
# ['겅', '해', '나부', '니까']
# ['▁', '겅', '해', '나', '부', '니까']
# ##################################################
# 살아보잰
# ['살', '아보', '잰']
# ['▁살아', '보', '잰']
# ##################################################
# 바라봠신디
# ['바라', '봠', '신디']
# ['▁바라', '봠', '신', '디']
# ##################################################
# 길어가잰
# ['길어가', '잰']
# ['▁길', '어', '가', '잰']
# ##################################################
# 따잰
# ['따', '잰']
# ['▁따', '잰']
# ##################################################
# 도와주잰
# ['도와주', '잰']
# ['▁도와', '주', '잰']
# ##################################################
# 미끄러졍
# ['미끄러', '졍']
# ['▁미', '끄러', '졍']
# ##################################################
# 일어서불믄
# ['일어', '서불', '믄']
# ['▁일', '어', '서', '불', '믄']
# ##################################################
# 산악부여시믄
# ['산악', '부여', '시', '믄']
# ['▁산', '악', '부', '여', '시', '믄']
# ##################################################
# 퍼졍
# ['퍼졍']
# ['▁퍼', '졍']
# ##################################################
# 떨어그넹
# ['떨어', '그', '넹']
# ['▁떨', '어', '그', '넹']
# ##################################################
# 겅은해신디
# ['겅', '은', '해신', '디']
# ['▁', '겅', '은', '해', '신', '디']
# ##################################################
# 따땄해우다
# ['따', '땄', '해우', '다']
# ['▁따', '땄', '해', '우', '다']
# ##################################################
# 추웡으네
# ['추웡으', '네']
# ['▁추', '웡', '으', '네']
# ##################################################
# 따땃하면
# ['따땃하', '면']
# ['▁따', '땃', '하면']
# ##################################################
# 같았으믄
# ['같았으', '믄']
# ['▁같', '았', '으', '믄']
# ##################################################
# 생각허믄
# ['생각', '허', '믄']
# ['▁생각', '허', '믄']
# ##################################################
# 못해기넹에
# ['못', '해기', '넹', '에']
# ['▁못해', '기', '넹', '에']
# ##################################################
# 겅해났잖아
# ['겅', '해', '났잖아']
# ['▁', '겅', '해', '났', '잖', '아']
# ##################################################
# 깎으믄
# ['깎으', '믄']
# ['▁', '깎', '으', '믄']
# ##################################################
# 먹어나믄
# ['먹어나', '믄']
# ['▁먹', '어', '나', '믄']
# ##################################################
# 해감시믄
# ['해감', '시', '믄']
# ['▁해', '감', '시', '믄']
# ##################################################
# 조로왕해가믄
# ['조로', '왕해', '가', '믄']
# ['▁조', '로', '왕', '해', '가', '믄']
# ##################################################
# 굴엄시녠
# ['굴엄시녠']
# ['▁굴', '엄', '시', '녠']
# ##################################################
# 놔시녠
# ['놔시녠']
# ['▁', '놔', '시', '녠']
# ##################################################
# 입구에다그넹
# ['입구', '에다', '그', '넹']
# ['▁입', '구', '에', '다', '그', '넹']
# ##################################################
# 모수와그넹
# ['모수', '와', '그', '넹']
# ['▁모', '수', '와', '그', '넹']
# ##################################################
# 만들엄시녠
# ['만들엄시녠']
# ['▁만들', '엄', '시', '녠']
# ##################################################
# 겅해시크라
# ['겅', '해', '시크', '라']
# ['▁', '겅', '해', '시', '크', '라']
# ##################################################
# 식어불믄
# ['식어', '불', '믄']
# ['▁식', '어', '불', '믄']
# ##################################################
# 가루라시믄
# ['가루라', '시', '믄']
# ['▁', '가', '루', '라', '시', '믄']
# ##################################################
# 짤르믄
# ['짤르믄']
# ['▁', '짤', '르', '믄']
# ##################################################
# 고파졈쪄
# ['고파졈쪄']
# ['▁고', '파', '졈쪄']
# ##################################################
# 어떵해그네
# ['어떵해그', '네']
# ['▁어', '떵', '해', '그', '네']
# ##################################################
# 고파졈신게
# ['고파', '졈', '신게']
# ['▁고', '파', '졈', '신', '게']
# ##################################################
# 배고파졈신게
# ['배고파', '졈', '신게']
# ['▁배', '고', '파', '졈', '신', '게']
# ##################################################
# 겅하면돼
# ['겅', '하면', '돼']
# ['▁', '겅', '하면', '돼']
# ##################################################
# 잤수다
# ['잤수다']
# ['▁', '잤', '수', '다']
# ##################################################
# 축구봔
# ['축구', '봔']
# ['▁축구', '봔']
# ##################################################
# 어떈
# ['어떈']
# ['▁어', '떈']
# ##################################################
# 해야됨마씸
# ['해야', '됨마', '씸']
# ['▁해야', '됨', '마', '씸']
# ##################################################
# 돼면마씸
# ['돼면마', '씸']
# ['▁돼', '면', '마', '씸']
# ##################################################
# 괜츈핸
# ['괜츈핸']
# ['▁', '괜', '츈', '핸']
# ##################################################
# 안아푸꽈
# ['안아푸꽈']
# ['▁안', '아', '푸', '꽈']
# ##################################################
# 겅하던디
# ['겅', '하던디']
# ['▁', '겅', '하던', '디']
# ##################################################
# 영화봔
# ['영화', '봔']
# ['▁영화', '봔']
# ##################################################
# 안내려놘
# ['안', '내려', '놘']
# ['▁안내', '려', '놘']
# ##################################################
# 고졍
# ['고졍']
# ['▁고', '졍']
# ##################################################
# 댕기라
# ['댕기', '라']
# ['▁', '댕', '기', '라']
# ##################################################
# 시녜게
# ['시', '녜', '게']
# ['▁시', '녜', '게']
# ##################################################
# 해붑써
# ['해', '붑', '써']
# ['▁해', '붑', '써']
# ##################################################
# 행마씸예
# ['행마', '씸예']
# ['▁행', '마', '씸', '예']
# ##################################################
# 속쏨해
# ['속', '쏨해']
# ['▁속', '쏨', '해']
# ##################################################
# 속쏨해라
# ['속', '쏨', '해', '라']
# ['▁속', '쏨', '해', '라']
# ##################################################
# 속쏨
# ['속', '쏨']
# ['▁속', '쏨']
# ##################################################
# 속쏨하영
# ['속', '쏨', '하영']
# ['▁속', '쏨', '하', '영']
# ##################################################
# 쭐어들어서
# ['쭐', '어', '들어서']
# ['▁', '쭐', '어', '들어', '서']
# ##################################################
# 쭐어든거야
# ['쭐', '어', '든거야']
# ['▁', '쭐', '어', '든', '거', '야']
# ##################################################
# 쭐어들언
# ['쭐어들언']
# ['▁', '쭐', '어', '들', '언']
# ##################################################
# 쭐어든
# ['쭐어', '든']
# ['▁', '쭐', '어', '든']
# ##################################################
# 고라붑써
# ['고라', '붑', '써']
# ['▁고', '라', '붑', '써']
# ##################################################
# 아이들일껀디
# ['아이', '들', '일', '껀디']
# ['▁아이들', '일', '껀', '디']
# ##################################################
# 뺄래기똥
# ['뺄래', '기', '똥']
# ['▁', '뺄', '래', '기', '똥']
# ##################################################
# 뺄라젼
# ['뺄라젼']
# ['▁', '뺄', '라', '젼']
# ##################################################
# 뺄라젼은
# ['뺄라젼', '은']
# ['▁', '뺄', '라', '젼', '은']
# ##################################################
# 뺄라진 추룩
# ['뺄', '라진', '추', '룩']
# ['▁', '뺄', '라', '진', '▁추', '룩']
# ##################################################
# 뺄라지다
# ['뺄', '라지', '다']
# ['▁', '뺄', '라', '지', '다']
# ##################################################
# 뺄라진 거는
# ['뺄', '라진', '거', '는']
# ['▁', '뺄', '라', '진', '▁거', '는']
# ##################################################
# 뺄라진거랑
# ['뺄라', '진거랑']
# ['▁', '뺄', '라', '진', '거', '랑']
# ##################################################
# 뺄라졌다고
# ['뺄라', '졌다고']
# ['▁', '뺄', '라', '졌다', '고']
# ##################################################
# 뺄라진거쥬
# ['뺄라', '진거', '쥬']
# ['▁', '뺄', '라', '진', '거', '쥬']
# ##################################################
# 뺄라져는
# ['뺄라', '져는']
# ['▁', '뺄', '라', '져', '는']
# ##################################################
# 뺄라지다의
# ['뺄라', '지다', '의']
# ['▁', '뺄', '라', '지', '다', '의']
# ##################################################
# 뺄라젼이라는
# ['뺄라젼', '이라는']
# ['▁', '뺄', '라', '젼', '이라는']
# ##################################################
# 쨔이
# ['쨔이']
# ['▁', '쨔', '이']
# ##################################################
# 뺄라지다가
# ['뺄라지', '다가']
# ['▁', '뺄', '라', '지', '다', '가']
# ##################################################
# 뺄라전
# ['뺄라', '전']
# ['▁', '뺄', '라', '전']
# ##################################################
# 뺄라전도
# ['뺄라', '전도']
# ['▁', '뺄', '라', '전', '도']
# ##################################################
# 실펐구나
# ['실펐구', '나']
# ['▁실', '펐', '구나']
# ##################################################
# 대껸
# ['대껸']
# ['▁대', '껸']
# ##################################################
# 쫍아
# ['쫍', '아']
# ['▁', '쫍', '아']
# ##################################################
# 갠춘
# ['갠', '춘']
# ['▁', '갠', '춘']
# ##################################################
# 쓸껀가
# ['쓸껀', '가']
# ['▁쓸', '껀', '가']
# ##################################################
# 샛놈
# ['샛놈']
# ['▁', '샛', '놈']
# ##################################################
# 말잿놈
# ['말잿놈']
# ['▁말', '잿', '놈']
# ##################################################
# 왁왁하다
# ['왁왁', '하다']
# ['▁', '왁왁', '하다']
# ##################################################
# 웡이
# ['웡', '이']
# ['▁', '웡', '이']
# ##################################################
# 쎈디
# ['쎈디']
# ['▁', '쎈', '디']
# ##################################################
# 내줜
# ['내줜']
# ['▁내', '줜']
# ##################################################
# 어떵하고
# ['어떵', '하고']
# ['▁어', '떵', '하고']
# ##################################################
# 어떵알아
# ['어떵알', '아']
# ['▁어', '떵', '알', '아']
# ##################################################
# 어떵벌어
# ['어떵벌어']
# ['▁어', '떵', '벌', '어']
# ##################################################
# 겅할거면
# ['겅할거', '면']
# ['▁', '겅', '할', '거', '면']
# ##################################################
# 안줜
# ['안줜']
# ['▁안', '줜']
# ##################################################
# 추천해줜
# ['추천', '해', '줜']
# ['▁추천', '해', '줜']
# ##################################################
# 꿀잼이랜
# ['꿀잼이랜']
# ['▁', '꿀', '잼', '이', '랜']
# ##################################################
# 어떵할꺼
# ['어떵할꺼']
# ['▁어', '떵', '할', '꺼']
# ##################################################
# 됀주
# ['됀주']
# ['▁', '됀', '주']
# ##################################################
# 막아졍
# ['막아졍']
# ['▁막아', '졍']
# ##################################################
# 붙으믄
# ['붙으', '믄']
# ['▁붙', '으', '믄']
# ##################################################
# 겅허부난
# ['겅허부', '난']
# ['▁', '겅', '허', '부', '난']
# ##################################################
# 겅허문
# ['겅', '허문']
# ['▁', '겅', '허', '문']
# ##################################################
# 겅하는게
# ['겅', '하는게']
# ['▁', '겅', '하는', '게']
# ##################################################
# 터키껀게
# ['터키껀', '게']
# ['▁터키', '껀', '게']
# ##################################################
# 넜구나
# ['넜구', '나']
# ['▁', '넜', '구나']
# ##################################################
# 넜지
# ['넜', '지']
# ['▁', '넜', '지']
# ##################################################
# 헤집어그넹
# ['헤집어', '그', '넹']
# ['▁헤', '집', '어', '그', '넹']
# ##################################################
# 겅해신데
# ['겅', '해신', '데']
# ['▁', '겅', '해', '신', '데']
# ##################################################
# 알았수꽈
# ['알았수', '꽈']
# ['▁알', '았', '수', '꽈']
# ##################################################
# 몰랐수꽈
# ['몰랐수', '꽈']
# ['▁몰', '랐', '수', '꽈']
# ##################################################
# 알았쑤꽈
# ['알았쑤꽈']
# ['▁알', '았', '쑤', '꽈']
# ##################################################
# 잘 하게 마씸
# ['잘', '하게', '마씸']
# ['▁잘', '▁', '하게', '▁마', '씸']
# ##################################################
# 겅허게 마씸게
# ['겅허', '게', '마씸', '게']
# ['▁', '겅', '허', '게', '▁마', '씸', '게']
# ##################################################
# 겅하게 마씸
# ['겅하', '게', '마씸']
# ['▁', '겅', '하게', '▁마', '씸']
# ##################################################
# 지캔하믄
# ['지', '캔', '하믄']
# ['▁지', '캔', '하', '믄']
# ##################################################
# 아니꽈양
# ['아니', '꽈', '양']
# ['▁아니', '꽈', '양']
# ##################################################
# 내놩은
# ['내놩', '은']
# ['▁내', '놩', '은']
# ##################################################
# 이천만원쓱
# ['이천만원', '쓱']
# ['▁이', '천만원', '쓱']
# ##################################################
# 봠수다
# ['봠수', '다']
# ['▁', '봠', '수', '다']
# ##################################################
# 심그잰
# ['심그', '잰']
# ['▁심', '그', '잰']
# ##################################################
# 어떵사해신지
# ['어떵', '사해', '신지']
# ['▁어', '떵', '사', '해', '신', '지']
# ##################################################
# 어멍네꺼졍
# ['어멍네꺼졍']
# ['▁어', '멍', '네', '꺼', '졍']
# ##################################################
# 가부럼쪄
# ['가부', '럼', '쪄']
# ['▁', '가', '부', '럼', '쪄']
# ##################################################
# 왐주
# ['왐주']
# ['▁', '왐', '주']
# ##################################################
# 안하믄
# ['안', '하믄']
# ['▁안', '하', '믄']
# ##################################################
# 이실때믄
# ['이', '실때', '믄']
# ['▁이', '실', '때', '믄']
# ##################################################
# 가졍가라게
# ['가졍가라', '게']
# ['▁', '가', '졍', '가', '라', '게']
# ##################################################
# 먹을꺼아니꽈
# ['먹을꺼아니', '꽈']
# ['▁먹', '을', '꺼', '아', '니', '꽈']
# ##################################################
# 베풀잰
# ['베풀', '잰']
# ['▁베', '풀', '잰']
# ##################################################
# 씁쌘
# ['씁쌘']
# ['▁', '씁', '쌘']
# ##################################################
# 쓰느냰
# ['쓰느냰']
# ['▁쓰', '느', '냰']
# ##################################################
# 어딨느니
# ['어딨느니']
# ['▁어', '딨', '느', '니']
# ##################################################
# 헙쌘
# ['헙쌘']
# ['▁', '헙쌘']
# ##################################################
# 해짐직허댕
# ['해짐직', '허', '댕']
# ['▁해', '짐', '직', '허', '댕']
# ##################################################
# 경허믄은
# ['경허', '믄', '은']
# ['▁경', '허', '믄', '은']
# ##################################################
# 안내믄
# ['안내', '믄']
# ['▁안내', '믄']
# ##################################################
# 가느냬
# ['가느냬']
# ['▁', '가', '느', '냬']
# ##################################################
# 합쌘
# ['합쌘']
# ['▁합', '쌘']
# ##################################################
# 댕겨봤자도
# ['댕겨', '봤', '자도']
# ['▁', '댕', '겨', '봤', '자', '도']
# ##################################################
# 그릅쌘
# ['그릅쌘']
# ['▁그', '릅', '쌘']
# ##################################################
# 갠디
# ['갠디']
# ['▁', '갠', '디']
# ##################################################
# 촙쌀떡
# ['촙쌀떡']
# ['▁', '촙', '쌀', '떡']
# ##################################################
# 못할껀디
# ['못할껀디']
# ['▁못할', '껀', '디']
# ##################################################
# 나와가믄
# ['나와가', '믄']
# ['▁나와', '가', '믄']
# ##################################################
# 꼴아놩
# ['꼴아놩']
# ['▁', '꼴', '아', '놩']
# ##################################################
# 맫기는거라
# ['맫', '기는거라']
# ['▁', '맫', '기는', '거', '라']
# ##################################################
# 입어봐시믄
# ['입어봐시', '믄']
# ['▁입', '어', '봐', '시', '믄']
# ##################################################
# 왐수겐
# ['왐수겐']
# ['▁', '왐', '수', '겐']
# ##################################################
# 폴잰
# ['폴', '잰']
# ['▁폴', '잰']
# ##################################################
# 골았댕
# ['골았', '댕']
# ['▁골', '았', '댕']
# ##################################################
# 알암수꽈
# ['알', '암', '수', '꽈']
# ['▁알', '암', '수', '꽈']
# ##################################################
# 들어보잰이
# ['들어', '보', '잰이']
# ['▁들어', '보', '잰', '이']
# ##################################################
# 촞앙그냉
# ['촞앙그냉']
# ['▁', '촞', '앙', '그', '냉']
# ##################################################
# 겅허맨
# ['겅허맨']
# ['▁', '겅', '허', '맨']
# ##################################################
# 못촞나
# ['못촞', '나']
# ['▁못', '촞', '나']
# ##################################################
# 매꼉
# ['매꼉']
# ['▁매', '꼉']
# ##################################################
# 들어봥
# ['들어봥']
# ['▁들어', '봥']
# ##################################################
# 아팜수꽈
# ['아팜수꽈']
# ['▁아', '팜', '수', '꽈']
# ##################################################
# 꺼졍은
# ['꺼졍', '은']
# ['▁꺼', '졍', '은']
# ##################################################
# 가졍가부난
# ['가졍가부', '난']
# ['▁', '가', '졍', '가', '부', '난']
# ##################################################
# 살잰허난
# ['살', '잰', '허난']
# ['▁살', '잰', '허', '난']
# ##################################################
# 가져감니껜
# ['가져감니', '껜']
# ['▁가져', '감', '니', '껜']
# ##################################################
# 가졍와수께
# ['가졍와수', '께']
# ['▁', '가', '졍', '와', '수', '께']
# ##################################################
# 죽었지않우꽈
# ['죽었지', '않우', '꽈']
# ['▁죽', '었', '지', '않', '우', '꽈']
# ##################################################
# 각시까졍
# ['각', '시', '까졍']
# ['▁각', '시', '까', '졍']
# ##################################################
# 적시꺼졍
# ['적시꺼', '졍']
# ['▁적', '시', '꺼', '졍']
# ##################################################
# 그것꺼졍
# ['그것', '꺼', '졍']
# ['▁그', '것', '꺼', '졍']
# ##################################################
# 밭꺼졍
# ['밭꺼졍']
# ['▁', '밭', '꺼', '졍']
# ##################################################
# 아들이믄산디
# ['아들', '이', '믄', '산디']
# ['▁아들', '이', '믄', '산', '디']
# ##################################################
# 어떵함신가
# ['어떵함신', '가']
# ['▁어', '떵', '함', '신', '가']
# ##################################################
# 겅해노니까
# ['겅해노', '니까']
# ['▁', '겅', '해', '노', '니까']
# ##################################################
# 겅해니까
# ['겅해', '니까']
# ['▁', '겅', '해', '니까']
# ##################################################
# 겅해고
# ['겅해', '고']
# ['▁', '겅', '해', '고']
# ##################################################
# 잤다매
# ['잤다매']
# ['▁', '잤', '다', '매']
# ##################################################
# 이거땜에
# ['이', '거땜', '에']
# ['▁이', '거', '땜', '에']
# ##################################################
# 중간되믄
# ['중간', '되', '믄']
# ['▁중간', '되', '믄']
# ##################################################
# 해났지안하꽈
# ['해', '났지안하', '꽈']
# ['▁해', '났', '지', '안', '하', '꽈']
# ##################################################
# 안되지안하꽈예
# ['안되지안하', '꽈예']
# ['▁안', '되지', '안', '하', '꽈', '예']
# ##################################################
# 겅하주게
# ['겅하주', '게']
# ['▁', '겅', '하', '주', '게']
# ##################################################
# 행나두믄
# ['행', '나', '두', '믄']
# ['▁행', '나', '두', '믄']
# ##################################################
# 감쪄이
# ['감', '쪄이']
# ['▁감', '쪄', '이']
# ##################################################
# 이서노믄예
# ['이', '서', '노', '믄', '예']
# ['▁이', '서', '노', '믄', '예']
# ##################################################
# 안해시믄
# ['안', '해시', '믄']
# ['▁안', '해', '시', '믄']
# ##################################################
# 미싯가루랜
# ['미싯가루랜']
# ['▁미', '싯', '가', '루', '랜']
# ##################################################
# 가루빻앙
# ['가루', '빻앙']
# ['▁', '가', '루', '빻', '앙']
# ##################################################
# 작영놩
# ['작', '영', '놩']
# ['▁작', '영', '놩']
# ##################################################
# 하영놩
# ['하영놩']
# ['▁하', '영', '놩']
# ##################################################
# 설탕놩
# ['설탕', '놩']
# ['▁설', '탕', '놩']
# ##################################################
# 켁켁하멍으네
# ['켁켁하멍으', '네']
# ['▁', '켁켁', '하', '멍', '으', '네']
# ##################################################
# 같아시믄
# ['같아시', '믄']
# ['▁같아', '시', '믄']
# ##################################################
# 영보믄
# ['영', '보', '믄']
# ['▁영', '보', '믄']
# ##################################################
# 무쳥
# ['무쳥']
# ['▁무', '쳥']
# ##################################################
# 겅하영행
# ['겅', '하', '영', '행']
# ['▁', '겅', '하', '영', '행']
# ##################################################
# 겅하영
# ['겅하영']
# ['▁', '겅', '하', '영']
# ##################################################
# 개역하믄
# ['개역', '하믄']
# ['▁개', '역', '하', '믄']
# ##################################################
# 비와가믄
# ['비', '와', '가', '믄']
# ['▁비', '와', '가', '믄']
# ##################################################
# 받젠하믄예
# ['받', '젠', '하', '믄', '예']
# ['▁받', '젠', '하', '믄', '예']
# ##################################################
# 수매하젠하믄
# ['수', '매', '하젠', '하믄']
# ['▁수', '매', '하', '젠', '하', '믄']
# ##################################################
# 훅지가
# ['훅', '지', '가']
# ['▁', '훅', '지가']
# ##################################################
# 가졍와도
# ['가졍', '와도']
# ['▁', '가', '졍', '와', '도']
# ##################################################
# 싱겅나사믄
# ['싱겅나사믄']
# ['▁', '싱', '겅', '나', '사', '믄']
# ##################################################
# 마농쫑이
# ['마농쫑', '이']
# ['▁마', '농', '쫑', '이']
# ##################################################
# 걘
# ['걘']
# ['▁', '걘']
# ##################################################
# 뭐냐믄예
# ['뭐', '냐', '믄', '예']
# ['▁뭐', '냐', '믄', '예']
# ##################################################
# 어떵해보라
# ['어떵', '해보라']
# ['▁어', '떵', '해', '보', '라']
# ##################################################
# 짤람시녠하난
# ['짤람', '시', '녠', '하', '난']
# ['▁', '짤', '람', '시', '녠', '하', '난']
# ##################################################
# 알으꽈
# ['알으꽈']
# ['▁알', '으', '꽈']
# ##################################################
# 마농쫑
# ['마농', '쫑']
# ['▁마', '농', '쫑']
# ##################################################
# 어떵되부런마씨
# ['어떵', '되', '부런', '마씨']
# ['▁어', '떵', '되', '부', '런', '마', '씨']
# ##################################################
# 어떵하여
# ['어떵하', '여']
# ['▁어', '떵', '하여']
# ##################################################
# 나도마씸게
# ['나도마', '씸', '게']
# ['▁나', '도', '마', '씸', '게']
# ##################################################
# 겅아니라도
# ['겅아니', '라도']
# ['▁', '겅', '아', '니', '라도']
# ##################################################
# 저래착하믄
# ['저래', '착', '하믄']
# ['▁저', '래', '착', '하', '믄']
# ##################################################
# 엇지안하꽈
# ['엇', '지안하', '꽈']
# ['▁', '엇', '지', '안', '하', '꽈']
# ##################################################
# 거믄은
# ['거', '믄', '은']
# ['▁거', '믄', '은']
# ##################################################
# 겡해난
# ['겡해', '난']
# ['▁', '겡', '해', '난']
# ##################################################
# 가당보믄예
# ['가당', '보', '믄', '예']
# ['▁', '가', '당', '보', '믄', '예']
# ##################################################
# 검질메믄
# ['검질', '메', '믄']
# ['▁검', '질', '메', '믄']
# ##################################################
# 겅하당보난예
# ['겅', '하', '당', '보', '난', '예']
# ['▁', '겅', '하', '당', '보', '난', '예']
# ##################################################
# 의하믄
# ['의', '하믄']
# ['▁', '의', '하', '믄']
# ##################################################
# 오꼿하게
# ['오', '꼿', '하', '게']
# ['▁오', '꼿', '하게']
# ##################################################
# 적셩이네
# ['적셩', '이네']
# ['▁적', '셩', '이', '네']
# ##################################################
# 할떄
# ['할떄']
# ['▁할', '떄']
# ##################################################
# 뽄이
# ['뽄', '이']
# ['▁', '뽄', '이']
# ##################################################
# 맞촹이네
# ['맞촹', '이네']
# ['▁맞', '촹', '이', '네']
# ##################################################
# 겅했져
# ['겅했져']
# ['▁', '겅', '했', '져']
# ##################################################
# 걸쳥
# ['걸쳥']
# ['▁걸', '쳥']
# ##################################################
# 벹조으민
# ['벹조으민']
# ['▁', '벹', '조', '으', '민']
# ##################################################
# 적시믄
# ['적시', '믄']
# ['▁적', '시', '믄']
# ##################################################
# 적졍예
# ['적졍예']
# ['▁적', '졍', '예']
# ##################################################
# 시작하믄
# ['시작', '하믄']
# ['▁시작', '하', '믄']
# ##################################################
# 골아불믄
# ['골아', '불', '믄']
# ['▁골', '아', '불', '믄']
# ##################################################
# 모르커녠
# ['모르커녠']
# ['▁모르', '커', '녠']
# ##################################################
# 지나불믄
# ['지', '나불', '믄']
# ['▁지나', '불', '믄']
# ##################################################
# 될거아니꽈
# ['될거아니', '꽈']
# ['▁될', '거', '아', '니', '꽈']
# ##################################################
# 쎼주기
# ['쎼', '주기']
# ['▁', '쎼', '주기']
# ##################################################
# 쳠덴핸게마는
# ['쳠덴핸게마', '는']
# ['▁', '쳠', '덴', '핸', '게', '마', '는']
# ##################################################
# 말렸지안하꽈예
# ['말렸지안하', '꽈예']
# ['▁말', '렸', '지', '안', '하', '꽈', '예']
# ##################################################
# 호로록해믄
# ['호로록', '해', '믄']
# ['▁호', '로', '록', '해', '믄']
# ##################################################
# 할꺼아니꽈예
# ['할꺼아니', '꽈예']
# ['▁할', '꺼', '아', '니', '꽈', '예']
# ##################################################
# 어떵했수가
# ['어떵했수', '가']
# ['▁어', '떵', '했', '수가']
# ##################################################
# 댕겼지게
# ['댕', '겼지게']
# ['▁', '댕', '겼', '지', '게']
# ##################################################
# 벌겅해부런
# ['벌겅', '해', '부런']
# ['▁벌', '겅', '해', '부', '런']
# ##################################################
# 벌겅핸
# ['벌겅핸']
# ['▁벌', '겅', '핸']
# ##################################################
# 벌겅하난
# ['벌겅하', '난']
# ['▁벌', '겅', '하', '난']
# ##################################################
# 벌겅핸예
# ['벌겅핸예']
# ['▁벌', '겅', '핸', '예']
# ##################################################
# 어떵해시냐믄예
# ['어떵', '해시냐', '믄', '예']
# ['▁어', '떵', '해', '시', '냐', '믄', '예']
# ##################################################
# 쪄서
# ['쪄서']
# ['▁', '쪄', '서']
# ##################################################
# 쪄가지고예
# ['쪄가지고', '예']
# ['▁', '쪄', '가', '지고', '예']
# ##################################################
# 찝디다
# ['찝', '디다']
# ['▁', '찝', '디', '다']
# ##################################################
# 쪄사주게
# ['쪄', '사주게']
# ['▁', '쪄', '사', '주', '게']
# ##################################################
# 찌믄예
# ['찌', '믄', '예']
# ['▁', '찌', '믄', '예']
# ##################################################
# 다놤신지
# ['다놤신', '지']
# ['▁다', '놤', '신', '지']
# ##################################################
# 겅할수밖에
# ['겅할수', '밖에']
# ['▁', '겅', '할', '수', '밖에']
# ##################################################
# 있지안하꽈
# ['있지안하', '꽈']
# ['▁있지', '안', '하', '꽈']
# ##################################################
# 조믄덴하영으네
# ['조', '믄', '덴', '하영', '으', '네']
# ['▁조', '믄', '덴', '하', '영', '으', '네']
# ##################################################
# 딸아니꽈예
# ['딸아', '니', '꽈예']
# ['▁딸', '아', '니', '꽈', '예']
# ##################################################
# 삶으믄
# ['삶으', '믄']
# ['▁삶', '으', '믄']
# ##################################################
# 뭐녠하민
# ['뭐녠하민']
# ['▁뭐', '녠', '하', '민']
# ##################################################
# 어떵하민
# ['어떵하민']
# ['▁어', '떵', '하', '민']
# ##################################################
# 심겅으네
# ['심겅으', '네']
# ['▁심', '겅', '으', '네']
# ##################################################
# 들어가믄
# ['들어가', '믄']
# ['▁들어가', '믄']
# ##################################################
# 톧앙도
# ['톧앙', '도']
# ['▁', '톧', '앙', '도']
# ##################################################
# 놩해야
# ['놩해', '야']
# ['▁', '놩', '해야']
# ##################################################
# 안지켱예
# ['안지', '켱예']
# ['▁안', '지', '켱', '예']
# ##################################################
# 살젠하믄게
# ['살젠', '하믄게']
# ['▁살', '젠', '하', '믄', '게']
# ##################################################
# 오죽해시믄
# ['오죽해시', '믄']
# ['▁오', '죽', '해', '시', '믄']
# ##################################################
# 구웡먹고
# ['구웡먹', '고']
# ['▁구', '웡', '먹', '고']
# ##################################################
# 인겅에
# ['인겅', '에']
# ['▁인', '겅', '에']
# ##################################################
# 먹젠하믄
# ['먹', '젠', '하믄']
# ['▁먹', '젠', '하', '믄']
# ##################################################
# 어딨수가게이
# ['어딨수', '가게', '이']
# ['▁어', '딨', '수가', '게', '이']
# ##################################################
# 담그믄
# ['담그', '믄']
# ['▁담', '그', '믄']
# ##################################################
# 먹었냐하믄
# ['먹었냐', '하믄']
# ['▁먹', '었', '냐', '하', '믄']
# ##################################################
# 들었져하믄
# ['들었져', '하믄']
# ['▁들', '었', '져', '하', '믄']
# ##################################################
# 건져다놩이네
# ['건져다', '놩', '이네']
# ['▁건', '져', '다', '놩', '이', '네']
# ##################################################
# 하당버치믄
# ['하당버치믄']
# ['▁하', '당', '버', '치', '믄']
# ##################################################
# 버치믄
# ['버치믄']
# ['▁버', '치', '믄']
# ##################################################
# 싹하믄
# ['싹', '하믄']
# ['▁', '싹', '하', '믄']
# ##################################################
# 좋으꽈
# ['좋으꽈']
# ['▁좋', '으', '꽈']
# ##################################################
# 여름하믄
# ['여름', '하믄']
# ['▁여름', '하', '믄']
# ##################################################
# 멜하믄
# ['멜', '하믄']
# ['▁', '멜', '하', '믄']
# ##################################################
# 겅해여그네
# ['겅', '해여', '그네']
# ['▁', '겅', '해', '여', '그', '네']
# ##################################################
# 잡아댕겨뒁
# ['잡아댕겨뒁']
# ['▁잡아', '댕', '겨', '뒁']
# ##################################################
# 다듬아뒁
# ['다듬아', '뒁']
# ['▁다', '듬', '아', '뒁']
# ##################################################
# 쬐끔놓곡
# ['쬐', '끔놓', '곡']
# ['▁', '쬐', '끔', '놓', '곡']
# ##################################################
# 조꼬띠아니꽈
# ['조꼬띠아니꽈']
# ['▁조', '꼬', '띠', '아', '니', '꽈']
# ##################################################
# 나오젠하믄
# ['나오', '젠', '하믄']
# ['▁나오', '젠', '하', '믄']
# ##################################################
# 멘물이여하믄은
# ['멘', '물이', '여', '하믄은']
# ['▁', '멘', '물', '이', '여', '하', '믄', '은']
# ##################################################
# 떵오젠
# ['떵오젠']
# ['▁', '떵', '오', '젠']
# ##################################################
# 넘어시믄
# ['넘어시', '믄']
# ['▁넘어', '시', '믄']
# ##################################################
# 자리물횐
# ['자리', '물횐']
# ['▁자리', '물', '횐']
# ##################################################
# 바당동네아니꽈예
# ['바', '당', '동네', '아니', '꽈예']
# ['▁바', '당', '동', '네', '아', '니', '꽈', '예']
# ##################################################
# 겅합디다게
# ['겅합디다', '게']
# ['▁', '겅', '합', '디', '다', '게']
# ##################################################
# 하꼼이시믄
# ['하', '꼼', '이', '시', '믄']
# ['▁하', '꼼', '이', '시', '믄']
# ##################################################
# 안해마씸게
# ['안', '해마', '씸', '게']
# ['▁안', '해', '마', '씸', '게']
# ##################################################
# 닮으꽈
# ['닮으꽈']
# ['▁', '닮', '으', '꽈']
# ##################################################
# 비살졍
# ['비살졍']
# ['▁비', '살', '졍']
# ##################################################
# 뜨지말랜하믄
# ['뜨지말', '랜', '하믄']
# ['▁', '뜨', '지', '말', '랜', '하', '믄']
# ##################################################
# 이시냐믄
# ['이', '시냐', '믄']
# ['▁이', '시', '냐', '믄']
# ##################################################
# 뿌령놔두믄
# ['뿌령놔두믄']
# ['▁', '뿌', '령', '놔', '두', '믄']
# ##################################################
# 똗으멍
# ['똗으멍']
# ['▁', '똗', '으', '멍']
# ##################################################
# 놔뒁완
# ['놔뒁완']
# ['▁', '놔', '뒁', '완']
# ##################################################
# 오라하믄
# ['오라', '하믄']
# ['▁오', '라', '하', '믄']
# ##################################################
# 내비뒁가서
# ['내비', '뒁', '가서']
# ['▁내', '비', '뒁', '가', '서']
# ##################################################
# 갔다왐시라
# ['갔다왐시', '라']
# ['▁', '갔다', '왐', '시', '라']
# ##################################################
# 똗앙
# ['똗앙']
# ['▁', '똗', '앙']
# ##################################################
# 똗앙이네
# ['똗앙', '이네']
# ['▁', '똗', '앙', '이', '네']
# ##################################################
# 행이네하믄
# ['행', '이네', '하믄']
# ['▁행', '이', '네', '하', '믄']
# ##################################################
# 동그믄예
# ['동', '그', '믄', '예']
# ['▁동', '그', '믄', '예']
# ##################################################
# 살아나믄예
# ['살아나', '믄', '예']
# ['▁살아', '나', '믄', '예']
# ##################################################
# 똗앙온거
# ['똗앙온거']
# ['▁', '똗', '앙', '온', '거']
# ##################################################
# 구추룩하믄
# ['구', '추', '룩', '하믄']
# ['▁구', '추', '룩', '하', '믄']
# ##################################################
# 나왐찌예
# ['나왐찌예']
# ['▁나', '왐', '찌', '예']
# ##################################################
# 못먹었지안하꽈
# ['못', '먹었지안하', '꽈']
# ['▁못', '먹', '었', '지', '안', '하', '꽈']
# ##################################################
# 섭췰한거라
# ['섭췰한거', '라']
# ['▁', '섭', '췰', '한', '거', '라']
# ##################################################
# 겅한디예
# ['겅한디예']
# ['▁', '겅', '한', '디', '예']
# ##################################################
# 수댕에다가
# ['수', '댕', '에다가']
# ['▁수', '댕', '에', '다', '가']
# ##################################################
# 어떵한지
# ['어떵한', '지']
# ['▁어', '떵', '한', '지']
# ##################################################
# 벌겅하주게
# ['벌겅하주', '게']
# ['▁벌', '겅', '하', '주', '게']
# ##################################################
# 깻잎인디
# ['깻잎', '인', '디']
# ['▁', '깻', '잎', '인', '디']
# ##################################################
# 벌겅하꽈
# ['벌겅하꽈']
# ['▁벌', '겅', '하', '꽈']
# ##################################################
# 뒤집으믄예
# ['뒤집으', '믄', '예']
# ['▁뒤집', '으', '믄', '예']
# ##################################################
# 깻잎이옌
# ['깻잎', '이', '옌']
# ['▁', '깻', '잎', '이', '옌']
# ##################################################
# 가지가지햄쪄
# ['가지가지', '햄', '쪄']
# ['▁가지', '가지', '햄', '쪄']
# ##################################################
# 풀어보잰하난
# ['풀', '어보', '잰하난']
# ['▁풀어', '보', '잰', '하', '난']
# ##################################################
# 놉담시난
# ['놉', '담시', '난']
# ['▁', '놉', '담', '시', '난']
# ##################################################
# 놉닸덴
# ['놉닸덴']
# ['▁', '놉닸', '덴']
# ##################################################
# 어떵한다
# ['어떵한다']
# ['▁어', '떵', '한다']
# ##################################################
# 갖다주믄
# ['갖다주', '믄']
# ['▁갖', '다', '주', '믄']
# ##################################################
# 쫀쫀한거
# ['쫀쫀한거']
# ['▁', '쫀쫀', '한', '거']
# ##################################################
# 낭보믄
# ['낭보', '믄']
# ['▁', '낭', '보', '믄']
# ##################################################
# 어떵하는지
# ['어떵', '하는지']
# ['▁어', '떵', '하는', '지']
# ##################################################
# 어떤거녠하믄이
# ['어떤거', '녠', '하믄이']
# ['▁어떤', '거', '녠', '하', '믄', '이']
# ##################################################
# 고르랜하믄
# ['고르', '랜', '하믄']
# ['▁고', '르', '랜', '하', '믄']
# ##################################################
# 안하꽈예
# ['안하꽈예']
# ['▁안', '하', '꽈', '예']
# ##################################################
# 표현하믄
# ['표현', '하믄']
# ['▁표현', '하', '믄']
# ##################################################
# 기지안하꽈예
# ['기', '지안', '하', '꽈예']
# ['▁기', '지', '안', '하', '꽈', '예']
# ##################################################
# 벌겅한거예
# ['벌겅한거예']
# ['▁벌', '겅', '한', '거', '예']
# ##################################################
# 호박이녠하믄
# ['호박', '이', '녠', '하믄']
# ['▁호', '박', '이', '녠', '하', '믄']
# ##################################################
# 깻고루만
# ['깻고루', '만']
# ['▁', '깻', '고', '루', '만']
# ##################################################
# 들어봥옵써예
# ['들어봥옵써예']
# ['▁들어', '봥', '옵', '써', '예']
# ##################################################
# 끊어졍
# ['끊어졍']
# ['▁', '끊', '어', '졍']
# ##################################################
# 모여그넹
# ['모여', '그', '넹']
# ['▁모여', '그', '넹']
# ##################################################
# 짤라그넹
# ['짤', '라', '그', '넹']
# ['▁', '짤', '라', '그', '넹']
# ##################################################
# 끼믄
# ['끼', '믄']
# ['▁끼', '믄']
# ##################################################
# 뛰어와그넹
# ['뛰어와', '그', '넹']
# ['▁뛰어', '와', '그', '넹']
# ##################################################
# 꼉그넹
# ['꼉그넹']
# ['▁', '꼉', '그', '넹']
# ##################################################
# 안들어봔
# ['안', '들어', '봔']
# ['▁안', '들어', '봔']
# ##################################################
# 생각해봔
# ['생각', '해', '봔']
# ['▁생각해', '봔']
# ##################################################
# 떼믄
# ['떼', '믄']
# ['▁', '떼', '믄']
# ##################################################
# 터졈서
# ['터졈', '서']
# ['▁터', '졈', '서']
# ##################################################
# 느껴봔
# ['느껴봔']
# ['▁느껴', '봔']
# ##################################################
# 부르믄
# ['부르', '믄']
# ['▁부르', '믄']
# ##################################################
# 바꿀꺼녠
# ['바꿀꺼', '녠']
# ['▁바', '꿀', '꺼', '녠']
# ##################################################
# 써먹잰사
# ['써', '먹', '잰사']
# ['▁써', '먹', '잰', '사']
# ##################################################
# 어떵허연
# ['어떵허연']
# ['▁어', '떵', '허', '연']
# ##################################################
# 생각하믄야
# ['생각', '하믄야']
# ['▁생각', '하', '믄', '야']
# ##################################################
# 추천해시냐믄
# ['추천', '해시냐', '믄']
# ['▁추천', '해', '시', '냐', '믄']
# ##################################################
# 순댕이
# ['순댕', '이']
# ['▁순', '댕', '이']
# ##################################################
# 시키잰
# ['시키', '잰']
# ['▁', '시키', '잰']
# ##################################################
# 뺌쩌
# ['뺌쩌']
# ['▁', '뺌', '쩌']
# ##################################################
# 뺌쑤게
# ['뺌', '쑤게']
# ['▁', '뺌', '쑤', '게']
# ##################################################
# 뺌수댄
# ['뺌수', '댄']
# ['▁', '뺌', '수', '댄']
# ##################################################
# 이추겅
# ['이추겅']
# ['▁이', '추', '겅']
# ##################################################
# 뺄라진
# ['뺄', '라진']
# ['▁', '뺄', '라', '진']
# ##################################################
# 순댕인디
# ['순댕', '인', '디']
# ['▁순', '댕', '인', '디']
# ##################################################
# 둣
# ['둣']
# ['▁', '둣']
# ##################################################
# 놀잰허난
# ['놀', '잰', '허난']
# ['▁놀', '잰', '허', '난']
# ##################################################
# 어뜽행
# ['어뜽행']
# ['▁어', '뜽', '행']
# ##################################################
# 뭣하리
# ['뭣', '하리']
# ['▁', '뭣', '하', '리']
# ##################################################
# 오뎅이영
# ['오뎅', '이영']
# ['▁오', '뎅', '이', '영']
# ##################################################
# 걷잰하주기게
# ['걷', '잰하', '주기', '게']
# ['▁걷', '잰', '하', '주기', '게']
# ##################################################
# 내려오잰
# ['내려오', '잰']
# ['▁내려', '오', '잰']
# ##################################################
# 곶잰하난
# ['곶', '잰하난']
# ['▁', '곶', '잰', '하', '난']
# ##################################################
# 재밉디강
# ['재', '밉', '디강']
# ['▁재', '밉', '디', '강']
# ##################################################
# 치잰
# ['치', '잰']
# ['▁치', '잰']
# ##################################################
# 좁아댕긴
# ['좁아', '댕', '긴']
# ['▁', '좁', '아', '댕', '긴']
# ##################################################
# 싸시믄
# ['싸시', '믄']
# ['▁싸', '시', '믄']
# ...
# ##################################################
# 걸러졍으네
# ['걸러졍으', '네']
# ['▁걸', '러', '졍', '으', '네']
# ##################################################
# 겅해났주게
# ['겅', '해', '났주게']
# ['▁', '겅', '해', '났', '주', '게']
# ##################################################
# 쳥으네
# ['쳥으', '네']
# ['▁', '쳥', '으', '네']
# ##################################################
# 가졍으네
# ['가졍으', '네']
# ['▁', '가', '졍', '으', '네']
# ##################################################
# 겅해난거
# ['겅', '해난', '거']
# ['▁', '겅', '해', '난', '거']
# ##################################################
# 어떵되불카부덴
# ['어떵되불카부덴']
# ['▁어', '떵', '되', '불', '카', '부', '덴']
# ##################################################
# 겅한 닮아
# ['겅', '한', '닮아']
# ['▁', '겅', '한', '▁', '닮', '아']
# ##################################################
# 겅허믄이
# ['겅허믄', '이']
# ['▁', '겅', '허', '믄', '이']
# ##################################################
# 겅헐건디
# ['겅', '헐건디']
# ['▁', '겅', '헐', '건', '디']
# ##################################################
# 먹잰허멍
# ['먹', '잰', '허', '멍']
# ['▁먹', '잰', '허', '멍']
# ##################################################
# 가잰하믄
# ['가', '잰', '하믄']
# ['▁', '가', '잰', '하', '믄']
# ##################################################
# 못찾으시믄예
# ['못', '찾으시', '믄', '예']
# ['▁못', '찾', '으', '시', '믄', '예']
# ##################################################
# 겅헌적도
# ['겅헌적', '도']
# ['▁', '겅', '헌', '적', '도']
# ##################################################
# 겅헌거냐
# ['겅헌거', '냐']
# ['▁', '겅', '헌', '거', '냐']
# ##################################################
# 겅햄신지
# ['겅햄신', '지']
# ['▁', '겅', '햄', '신', '지']
# ##################################################
# 겨울되믄이
# ['겨울되', '믄', '이']
# ['▁겨울', '되', '믄', '이']
# ##################################################
# 겨울되믄
# ['겨울되', '믄']
# ['▁겨울', '되', '믄']
# ##################################################
# 가졍와이
# ['가졍와이']
# ['▁', '가', '졍', '와', '이']
# ##################################################
# 낭푼에다그넹
# ['낭푼', '에다', '그', '넹']
# ['▁', '낭', '푼', '에', '다', '그', '넹']
# ##################################################
# 놔두믄이
# ['놔두', '믄', '이']
# ['▁', '놔', '두', '믄', '이']
# ##################################################
# 겨믄이
# ['겨', '믄', '이']
# ['▁', '겨', '믄', '이']
# ##################################################
# 차리잰
# ['차리', '잰']
# ['▁차', '리', '잰']
# ##################################################
# 돌리잰
# ['돌리', '잰']
# ['▁돌', '리', '잰']
# ##################################################
# 하당보믄이
# ['하', '당', '보', '믄', '이']
# ['▁하', '당', '보', '믄', '이']
# ##################################################
# 컹으네이
# ['컹으', '네', '이']
# ['▁', '컹', '으', '네', '이']
# ##################################################
# 쪄그네
# ['쪄', '그네']
# ['▁', '쪄', '그', '네']
# ##################################################
# 나오잰허믄
# ['나오', '잰', '허', '믄']
# ['▁나오', '잰', '허', '믄']
# ##################################################
# 솓아
# ['솓', '아']
# ['▁', '솓', '아']
# ##################################################
# 보인댕
# ['보인', '댕']
# ['▁보', '인', '댕']
# ##################################################
# 꺾어그넹
# ['꺾어', '그', '넹']
# ['▁', '꺾', '어', '그', '넹']
# ##################################################
# 캐오잰
# ['캐오', '잰']
# ['▁캐', '오', '잰']
# ##################################################
# 싯엉
# ['싯엉']
# ['▁', '싯', '엉']
# ##################################################
# 고사리꽈
# ['고사리', '꽈']
# ['▁고', '사', '리', '꽈']
# ##################################################
# 겅햄주
# ['겅햄주']
# ['▁', '겅', '햄', '주']
# ##################################################
# 욜로
# ['욜', '로']
# ['▁', '욜', '로']
# ##################################################
# 벗어제껸
# ['벗어', '제', '껸']
# ['▁벗', '어', '제', '껸']
# ##################################################
# 목욕헙샌
# ['목욕', '헙', '샌']
# ['▁목', '욕', '헙', '샌']
# ##################################################
# 꿩마늘도
# ['꿩', '마늘', '도']
# ['▁', '꿩', '마', '늘', '도']
# ##################################################
# 꿩마늘이
# ['꿩', '마늘', '이']
# ['▁', '꿩', '마', '늘', '이']
# ##################################################
# 무쳥주고
# ['무쳥주', '고']
# ['▁무', '쳥', '주', '고']
# ##################################################
# 무쳥으네
# ['무쳥으', '네']
# ['▁무', '쳥', '으', '네']
# ##################################################
# 겅해보게
# ['겅', '해보게']
# ['▁', '겅', '해', '보', '게']
# ##################################################
# 안왐신고예
# ['안왐', '신고', '예']
# ['▁안', '왐', '신', '고', '예']
# ##################################################
# 따라가잰
# ['따라가', '잰']
# ['▁따라', '가', '잰']
# ##################################################
# 안허꽈예
# ['안허꽈예']
# ['▁안', '허', '꽈', '예']
# ##################################################
# 추웡으네이
# ['추', '웡으', '네', '이']
# ['▁추', '웡', '으', '네', '이']
# ##################################################
# 해시냬이
# ['해시', '냬', '이']
# ['▁해', '시', '냬', '이']
# ##################################################
# 버텽그네
# ['버텽그', '네']
# ['▁버', '텽', '그', '네']
# ##################################################
# 쌓아놩으네
# ['쌓아놩으', '네']
# ['▁쌓', '아', '놩', '으', '네']
# ##################################################
# 이서나시냬이
# ['이서', '나', '시', '냬', '이']
# ['▁이', '서', '나', '시', '냬', '이']
# ##################################################
# 유채낭뎅이
# ['유채', '낭뎅', '이']
# ['▁유', '채', '낭', '뎅', '이']
# ##################################################
# 태우잰
# ['태우', '잰']
# ['▁태', '우', '잰']
# ##################################################
# 겅했당
# ['겅했당']
# ['▁', '겅', '했', '당']
# ##################################################
# 싣겅으네
# ['싣겅으', '네']
# ['▁', '싣', '겅', '으', '네']
# ##################################################
# 어떵해마시
# ['어떵', '해', '마시']
# ['▁어', '떵', '해', '마', '시']
# ##################################################
# 어떵해마씨
# ['어떵', '해마', '씨']
# ['▁어', '떵', '해', '마', '씨']
# ##################################################
# 모아놩이네
# ['모아놩', '이네']
# ['▁모아', '놩', '이', '네']
# ##################################################
# 어떵안헌다
# ['어떵안헌다']
# ['▁어', '떵', '안', '헌', '다']
# ##################################################
# 더웡으네
# ['더웡으', '네']
# ['▁더', '웡', '으', '네']
# ##################################################
# 지나잰
# ['지나', '잰']
# ['▁지나', '잰']
# ##################################################
# 해시냬
# ['해시', '냬']
# ['▁해', '시', '냬']
# ##################################################
# 겅허는게
# ['겅허는', '게']
# ['▁', '겅', '허', '는', '게']
# ##################################################
# 잡잰하믄
# ['잡', '잰', '하믄']
# ['▁잡', '잰', '하', '믄']
# ##################################################
# 홑솔
# ['홑솔']
# ['▁', '홑', '솔']
# ##################################################
# 입혀쪄게
# ['입혀', '쪄게']
# ['▁입', '혀', '쪄', '게']
# ##################################################
# 그행보믄
# ['그', '행보', '믄']
# ['▁그', '행', '보', '믄']
# ##################################################
# 받잰하믄
# ['받', '잰', '하믄']
# ['▁받', '잰', '하', '믄']
# ##################################################
# 보잰 하믄
# ['보', '잰', '하믄']
# ['▁보', '잰', '▁하', '믄']
# ##################################################
# 어떵해수까
# ['어떵', '해수까']
# ['▁어', '떵', '해', '수', '까']
# ##################################################
# 줘시믄
# ['줘시', '믄']
# ['▁', '줘', '시', '믄']
# ##################################################
# 내려 시믄
# ['내려', '시', '믄']
# ['▁내려', '▁시', '믄']
# ##################################################
# 내려나믄
# ['내려나', '믄']
# ['▁내려', '나', '믄']
# ##################################################
# 겅 행이
# ['겅', '행', '이']
# ['▁', '겅', '▁행', '이']
# ##################################################
# 물통옅
# ['물통', '옅']
# ['▁물', '통', '옅']
# ##################################################
# 행보믄
# ['행보', '믄']
# ['▁행보', '믄']
# ##################################################
# 물내쳠쪄
# ['물내쳠쪄']
# ['▁물', '내', '쳠쪄']
# ##################################################
# 타러가믄
# ['타러가', '믄']
# ['▁타', '러', '가', '믄']
# ##################################################
# 쪄신디
# ['쪄신', '디']
# ['▁', '쪄', '신', '디']
# ##################################################
# 뺄거라
# ['뺄거라']
# ['▁', '뺄', '거', '라']
# ##################################################
# 빠졍이서
# ['빠졍이', '서']
# ['▁빠', '졍', '이', '서']
# ##################################################
# 살쪄으네
# ['살쪄으네']
# ['▁살', '쪄', '으', '네']
# ##################################################
# 졈시냐
# ['졈시', '냐']
# ['▁', '졈', '시', '냐']
# ##################################################
# 졈쭈
# ['졈쭈']
# ['▁', '졈', '쭈']
# ##################################################
# 빠졈쭈
# ['빠졈쭈']
# ['▁빠', '졈', '쭈']
# ##################################################
# 졈신게
# ['졈신', '게']
# ['▁', '졈', '신', '게']
# ##################################################
# 이신믄
# ['이', '신', '믄']
# ['▁이', '신', '믄']
# ##################################################
# 됀댄행
# ['됀', '댄', '행']
# ['▁', '됀', '댄', '행']
# ##################################################
# 건졍으네
# ['건졍으', '네']
# ['▁건', '졍', '으', '네']
# ##################################################
# 시켱으네
# ['시켱으', '네']
# ['▁시', '켱', '으', '네']
# ##################################################
#  겅
# ['겅']
# ['▁', '겅']
# ##################################################
# 커그넹
# ['커그넹']
# ['▁커', '그', '넹']
# ##################################################
# 채령으넹
# ['채령', '으넹']
# ['▁채', '령', '으', '넹']
# ##################################################
# 먹엉으넹
# ['먹엉으넹']
# ['▁먹', '엉', '으', '넹']
# ##################################################
# 먹고졍해
# ['먹고졍해']
# ['▁먹고', '졍', '해']
# ##################################################
# 덜어붑서
# ['덜어', '붑서']
# ['▁덜', '어', '붑', '서']
# ##################################################
# 혿
# ['혿']
# ['▁', '혿']
# ##################################################
# 살쪄부러서
# ['살쪄', '부러', '서']
# ['▁살', '쪄', '부', '러', '서']
# ##################################################
# 겅하주
# ['겅', '하주']
# ['▁', '겅', '하', '주']
# ##################################################
# 먹엄시믄
# ['먹엄시믄']
# ['▁먹', '엄', '시', '믄']
# ##################################################
# 어떵할꺼라
# ['어떵할꺼', '라']
# ['▁어', '떵', '할', '꺼', '라']
# ##################################################
# 하잰해도
# ['하', '잰', '해도']
# ['▁하', '잰', '해', '도']
# ##################################################
# 영하믄
# ['영', '하믄']
# ['▁영하', '믄']
# ##################################################
# 걸엉으넹
# ['걸엉으넹']
# ['▁걸', '엉', '으', '넹']
# ##################################################
# 뿡뿡하게
# ['뿡뿡하', '게']
# ['▁', '뿡뿡', '하게']
# ##################################################
# 해졍으네
# ['해졍으', '네']
# ['▁해', '졍', '으', '네']
# ##################################################
# 남아수꽈
# ['남아', '수', '꽈']
# ['▁남아', '수', '꽈']
# ##################################################
# 짜보잰
# ['짜', '보', '잰']
# ['▁짜', '보', '잰']
# ##################################################
# 와그넹이
# ['와그넹', '이']
# ['▁', '와', '그', '넹', '이']
# ##################################################
# 왕그넹
# ['왕그넹']
# ['▁왕', '그', '넹']
# ##################################################
# 쪈
# ['쪈']
# ['▁', '쪈']
# ##################################################
# 생겨그넹이
# ['생겨', '그', '넹', '이']
# ['▁생', '겨', '그', '넹', '이']
# ##################################################
# 뺄건디
# ['뺄건', '디']
# ['▁', '뺄', '건', '디']
# ##################################################
# 겅에난이
# ['겅에난', '이']
# ['▁', '겅', '에', '난', '이']
# ##################################################
# 겅해그넹이
# ['겅해그넹', '이']
# ['▁', '겅', '해', '그', '넹', '이']
# ##################################################
# 겅하댄
# ['겅하댄']
# ['▁', '겅', '하', '댄']
# ##################################################
# 겅해이
# ['겅', '해이']
# ['▁', '겅', '해', '이']
# ##################################################
# 겅허
# ['겅허']
# ['▁', '겅', '허']
# ##################################################
# 예민해그넹
# ['예민해', '그', '넹']
# ['▁예', '민', '해', '그', '넹']
# ##################################################
# 가르켜줜이
# ['가르켜줜', '이']
# ['▁가르', '켜', '줜', '이']
# ##################################################
# 놩신디
# ['놩신디']
# ['▁', '놩', '신', '디']
# ##################################################
# 기억해그넹
# ['기억', '해', '그', '넹']
# ['▁기억', '해', '그', '넹']
# ##################################################
# 틀어놘
# ['틀어놘']
# ['▁틀', '어', '놘']
# ##################################################
# 얻어와그넹
# ['얻어와', '그', '넹']
# ['▁얻어', '와', '그', '넹']
# ##################################################
# 돈마씸
# ['돈마씸']
# ['▁돈', '마', '씸']
# ##################################################
# 겅행가난
# ['겅행가', '난']
# ['▁', '겅', '행', '가', '난']
# ##################################################
# 겅해난부난
# ['겅', '해난', '부', '난']
# ['▁', '겅', '해', '난', '부', '난']
# ##################################################
# 약해그넹이
# ['약해', '그', '넹', '이']
# ['▁약', '해', '그', '넹', '이']
# ##################################################
# 쨍
# ['쨍']
# ['▁', '쨍']
# ##################################################
# 아껴그넹
# ['아껴', '그', '넹']
# ['▁아', '껴', '그', '넹']
# ##################################################
# 씹다그넹
# ['씹다', '그', '넹']
# ['▁', '씹', '다', '그', '넹']
# ##################################################
# 울잰
# ['울', '잰']
# ['▁울', '잰']
# ##################################################
# 끌어그넹
# ['끌어', '그', '넹']
# ['▁끌어', '그', '넹']
# ##################################################
# 무서웡이
# ['무서웡', '이']
# ['▁무', '서', '웡', '이']
# ##################################################
# 허하그넹
# ['허하', '그', '넹']
# ['▁허', '하', '그', '넹']
# ##################################################
# 겅하부난
# ['겅하부', '난']
# ['▁', '겅', '하', '부', '난']
# ##################################################
# 걔네는이
# ['걔네', '는', '이']
# ['▁', '걔', '네', '는', '이']
# ##################################################
# 겅해부넹
# ['겅해부넹']
# ['▁', '겅', '해', '부', '넹']
# ##################################################
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-fd2ca8ee4626> in <cell line: 6>()
#       5 import time
#       6 for i,v in tqdm(enumerate(dw_dict["utterance"])):
# ----> 7     if 0 in src_tokenizer.encode(v["dialect_form"]) and not (v["dialect_form"] in cnt_words):
#       8         cnt_words.append(v["dialect_form"])
#       9         print(v["dialect_form"])
#
# /usr/local/lib/python3.9/dist-packages/transformers/tokenization_utils_base.py in encode(self, text, text_pair, add_special_tokens, padding, truncation, max_length, stride, return_tensors, **kwargs)
#    2299                 method).
#    2300         """
# -> 2301         encoded_inputs = self.encode_plus(
#    2302             text,
#    2303             text_pair=text_pair,
#
# /usr/local/lib/python3.9/dist-packages/transformers/tokenization_utils_base.py in encode_plus(self, text, text_pair, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, **kwargs)
#    2707         )
#    2708
# -> 2709         return self._encode_plus(
#    2710             text=text,
#    2711             text_pair=text_pair,
#
# /usr/local/lib/python3.9/dist-packages/transformers/tokenization_utils.py in _encode_plus(self, text, text_pair, add_special_tokens, padding_strategy, truncation_strategy, max_length, stride, is_split_into_words, pad_to_multiple_of, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, **kwargs)
#     650         second_ids = get_input_ids(text_pair) if text_pair is not None else None
#     651
# --> 652         return self.prepare_for_model(
#     653             first_ids,
#     654             pair_ids=second_ids,
#
# /usr/local/lib/python3.9/dist-packages/transformers/tokenization_utils_base.py in prepare_for_model(self, ids, pair_ids, add_special_tokens, padding, truncation, max_length, stride, pad_to_multiple_of, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, prepend_batch_axis, **kwargs)
#    3106
#    3107         # Backward compatibility for 'truncation_strategy', 'pad_to_max_length'
# -> 3108         padding_strategy, truncation_strategy, max_length, kwargs = self._get_padding_truncation_strategies(
#    3109             padding=padding,
#    3110             truncation=truncation,
#
# /usr/local/lib/python3.9/dist-packages/transformers/tokenization_utils_base.py in _get_padding_truncation_strategies(self, padding, truncation, max_length, pad_to_multiple_of, verbose, **kwargs)
#    2369                         warnings.warn("Though `pad_to_max_length` = `True`, it is ignored because `padding`=`True`.")
#    2370                 padding_strategy = PaddingStrategy.LONGEST  # Default to pad to the longest sequence in the batch
# -> 2371             elif not isinstance(padding, PaddingStrategy):
#    2372                 padding_strategy = PaddingStrategy(padding)
#    2373             elif isinstance(padding, PaddingStrategy):
#
# KeyboardInterrupt:

# %%
print(len(src_tokenizer))
print(len(add_tokenizer))
# Out:
# 12291
# 8002
