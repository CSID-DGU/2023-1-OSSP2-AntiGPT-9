# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install transformers;
# !pip install sentencepiece;
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.28.1-py3-none-any.whl (7.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 54.2 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.0)
# Collecting huggingface-hub<1.0,>=0.11.0 (from transformers)
#   Downloading huggingface_hub-0.14.1-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 25.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.27.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 94.7 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (2023.4.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.14.1 tokenizers-0.13.3 transformers-4.28.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 19.6 MB/s eta 0:00:00
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.99

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# Token is valid.
# Your token has been saved in your configured git credential helpers (store).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
import json
from copy import deepcopy
import random
from tqdm.notebook import tqdm

from transformers import (
    PreTrainedTokenizerFast as BaseGPT2Tokenizer,
    EncoderDecoderModel,
    DataCollatorForSeq2Seq,
    Seq2SeqTrainingArguments,
    Seq2SeqTrainer,
    AdamW
)
import pickle

from drive.MyDrive.WARNING_PRIVATE_FOLDER.OSSP2AntiGPT9.ai.tokenization_kobert import KoBertTokenizer
from drive.MyDrive.WARNING_PRIVATE_FOLDER.OSSP2AntiGPT9.ai import tokenization_kobert
src_tokenizer = KoBertTokenizer.from_pretrained('monologg/kobert')
# Out:
# Downloading (…)zer_78b3253a26.model:   0%|          | 0.00/371k [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/77.8k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/51.0 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/426 [00:00<?, ?B/s]
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'BertTokenizer'.
# The class this function is called from is 'KoBertTokenizer'.

# %%
class GPT2Tokenizer(BaseGPT2Tokenizer):
    def build_inputs_with_special_tokens(self, token_ids, _):
        return token_ids + [self.eos_token_id]
trg_tokenizer = GPT2Tokenizer.from_pretrained("skt/kogpt2-base-v2",
  bos_token='</s>', eos_token='</s>', unk_token='<unk>',
  pad_token='<pad>', mask_token='<mask>')
# Out:
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/2.83M [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.00k [00:00<?, ?B/s]

# %%
# %cd /content/drive/MyDrive/WARNING_PRIVATE_FOLDER/OSSP2AntiGPT9/ai
with open('/content/drive/MyDrive/WARNING_PRIVATE_FOLDER/OSSP2AntiGPT9/ai/no_commit/save_src_tk.pickle','rb') as f:
    src_tokenizer = pickle.load(f)
# Out:
# /content/drive/MyDrive/WARNING_PRIVATE_FOLDER/OSSP2AntiGPT9/ai

# %%
# %cd /content
# !pwd
# Out:
# /content
# /content

# %% [markdown]
# ## 데이터 불러오기 && 데이터셋 만들기

# %%
def split_input_dict(input_dict, ratio = 0.01, seed = 42):
    split_point = int(len(input_dict['utterance']) * ratio)
    random.seed(seed)
    random.shuffle(input_dict['utterance'])
    valid_dict = deepcopy(input_dict)
    train_dict = input_dict

    valid_dict['utterance'] = input_dict['utterance'][:split_point]
    train_dict['utterance'] = input_dict['utterance'][split_point:]
    return train_dict, valid_dict

# %%
def read_input(path):
    with open(path, 'rb') as f:
        input_dict = json.load(f)
    train_dict,valid_dict = split_input_dict(input_dict)
    train_standard = []
    train_dialect = []
    for pairs in tqdm(train_dict['utterance']):
        train_standard.append(pairs['standard_form'])
        train_dialect.append(pairs['dialect_form'])

    valid_standard = []
    valid_dialect = []
    for pairs in tqdm(valid_dict['utterance']):
        valid_standard.append(pairs['standard_form'])
        valid_dialect.append(pairs['dialect_form'])

    
    return train_standard ,train_dialect , valid_standard , valid_dialect

# %%
train_s ,train_d , valid_s , valid_d = read_input("/content/drive/MyDrive/WARNING_PRIVATE_FOLDER/OSSP2AntiGPT9/ai/no_commit/real_data.json")
# Out:
#   0%|          | 0/1220349 [00:00<?, ?it/s]
#   0%|          | 0/12326 [00:00<?, ?it/s]

# %%
####제주데이터 100개씩 끊어보는 기능
n=2
for ind,i in enumerate(zip(train_s,train_d)):
    if ind<n*100:
        continue
    if ind>(n+1)*100:
        break
    print(i[1],"## ##",i[0])
# Out:
# 근데 아 아들 입양해부난 이제 아들 안 나아도 되 되크라  ## ## 근데 아 아들 입양 해버려서 이제 아들 안 나아도 되 되겠어
# 빨리 교환하고 심 ## ## 빨리 교환하고 싶어
# 금요일날 가사켜 ## ## 금요일날 가야지
# 뭐가 잘못된 근데 그사람 일등도 아니고 삼등이연 ## ## 뭐가 잘못됬어 근데 그사람 일등도 아니고 삼등이였어
# 믿어부난 놓고 가신디 거기 똥파리들이 막 꼬이는거라  ## ## 믿어서 놓고 가신디 거기 똥파리들이 막 꼬여
# 겅행 또 ## ## 그리고 또
# 요새 누게가 겅 들렁댕기는 사람 이시니 게 ## ## 요새 누가 그렇게 들고다니는 사람 있니 게
# 그렇게 아플꺼면 그냥 죽여줬으면 좋겐 차라리 ## ## 그렇게 아플꺼면 그냥 죽여줬으면 좋겠어 차라리
# 건 맞수다 ## ## 건 맞아요
# 게난 제주도 사람들은예 어디 모소왕 못나가네 ## ## 그러니까 제주도 사람들은 어디 무서워서 못나가잖아
# 직장에서 이제 좀 말 가라발 사람은 어신가 ## ## 직장에서 이제 좀 말 할 사람은 없을까
# 저 친척네 집이 한림이  한 시간 버스 탕으네 갔다오랜하믄 어떵 ## ## 저 친척네 집에 한림이  한 시간 버스 타서 갔다 오라고 하면 어떻게
# 너무 하영 ## ## 너무 많이
# 주켄 허멍 이 사람 편에 들켄허멍 ## ## 주겠다 하면서 이 사람 편에 들겠다면서
# 게난 무사 어멍 저추룩햄시냐 저추루햄시냐 싸우당 보난 ## ## 그니깐 왜 엄마 저러냐 저러냐 싸우다 보니깐
# 겅헌디 ## ## 그러는데
# 자기도 이제 며느리한테 이제 그추룩 허여주고싶덴 ## ## 자기도 이제 며느리한테 이제 그처럼 해주고싶다고
# 옷 쫙쫙 빼멍이 놀래가는 사진을 다 카톡 사진에 올린거라 열이 받는거라 ## ## 옷 쫙쫙 빼입고 놀러가는 사진을 다 카톡 사진에 올린거야 열이 받는거야
# 가신디 딱 가이 보는 순간 아 이건 안되겠다 영 싶은 거라 ## ## 갔는데 딱 걔 보는 순간 아 이건 안되겠다 이렇게 싶은 거야
# 일 이 년 전에 얘긴디예 겅하고 이제는 그 사람들이 제주도 음식이나 그런 것에 대해서 ## ## 일 이 년 전에 얘기인데요 그리고 이제는 그 사람들이 제주도 음식이나 그런 것에 대해서
# 삼촌이 보내 준 거랜 ## ## 삼촌이 보내 준거래
# 영 하니까 이제 목사님이 아니 뭐 있으면 좋긴헌디 ## ## 이렇게 하니까 이제 목사님이 아니 뭐 있으면 좋긴 하지만
# 영행 가는디 붙엉 이제 가주 게 난 차도 없고 하니까 이 붙엉 가면은 ## ## 이렇게 해서 가는데 붙어서 이제 가거든 게 난 차도 없고 하니까 이 붙어서 가면은
# 내쫓아분 거 아니 ## ## 내쫓은 거 아니
# 그래이제 해녀 갔다오면 몸 아펑 쉬고 해야되는데 쉬지도 못하고 아기들 챙기고 밥 챙기고 ## ## 그래이제 해녀 갔다오면 몸 아파서 쉬고 해야되는데 쉬지도 못하고 아기들 챙기고 밥 챙기고
# 어 들어본 거 닮아 ## ## 어 들어본 거 같아
# 칡이 끅이잖아 끅 끅 끅 ## ## 칡이 칡이잖아 칡 칡 칡
# 하나 씩 먹언 ## ## 하나 씩 먹었어
# 독새기는 안 먹는생이네이 ## ## 계란은 안 먹는가보네
# 그냥 난 찬바람 좀 쐬젠 ## ## 그냥 난 찬바람 좀 쐴거야
# 거를 트레이닝을 해야지 ## ## 그거를 트레이닝을 해야지
# 노인 일자리랜 해 가지고 ## ## 노인 일자리라고 해 가지고
# 나랑 숨바꼭질 하멍 십사일을 경 허멍 ## ## 나랑 숨바꼭질 하면서 십사일을 그렇게 하면서
# 어 그거 진짜 재밌게 봔 ## ## 어 그거 진짜 재밌게 봤어
# 거난 우리도 우리는 이제 경운기도 없고 딸딸이도 없고 ## ## 그니까 우리도 우리는 이제 경운기도 없고 딸딸이도 없고
# 게난 매누리가 막 발 버덩 아장 울어 ## ## 그러니까 며느리가 막 발 뻗고 앉아서 울어
# 약간 있네 최대한 최대한 그거 없는걸로 시켜줜 그 ## ## 약간 있잖아 최대한 최대한 그거 없는걸로 시켜줬어 그
# 그때 지역감정으로 다 얘기 했네 편지 읽으면 나와있을걸 ## ## 그때 지역감정으로 다 얘기 했잖아 편지 읽으면 나와있을걸
# 다 들은거 같애마씨 ## ## 다 들은거 같아요
# 뭐 회사 약간 옆에서 동료들 막 하젠 하면양 ## ## 뭐 회사 약간 옆에서 동료들 막 하려고 하면요
# 넌 안 갔나 ## ## 넌 안 갔어
# 막 그추룩 하고 아니 ## ## 막 그렇게 하고 아니야
# 한달 되난 ## ## 한달 되니까
# 게메 이 이게 어마 징징허다 ## ## 그러게 이 이게 어마 흉하다
# 그 마음은 이서 그거는 지금도 그거는 하고 싶은 게 그거는 ## ## 그 마음은 있어 그거는 지금도 그거는 하고 싶은 게 그거는
# 약 사도라 몇 번 햄실껀디 예 올힌 ## ## 약 사줘라 몇 번 할텐데 예 올해는
# 내창에 강 앉앙 놀안 영 하난 예 거멍한 것이 ## ## 내창에 가서 앉아서 놀았어 이렇게 하니까 예 까만 것이
# 알지 그 뚠뚠이네 맞은편에 맨날 서이서 ## ## 알지 그 뚠뚠이네 맞은편에 맨날 서있어
# 그니까 손가락 몇 개 띵땅거리는 것 갖고는이 ## ## 그니까 손가락 몇 개 띵땅거리는 것 가지고는
# 근데 혼자 살게 되면 겅 된데 ## ## 근데 혼자 살게 되면 그렇게 된데
# 혼자 보는데 귀신 나오는 건 못 보겐 ## ## 혼자 보는데 귀신 나오는 건 못 보겠어
# 근데 이거전자기기 그 친구 고른 사람 인 ## ## 근데 이거전자기기 그 친구 고른 사람 있어
# 육십은 된 줄 아란이 계신데 완전히 나이 들어 보이는 외모에 있지 말하는 것 ## ## 육십은 된 줄 알았어 그랬는데 완전히 나이 들어 보이는 외모에 있지 말하는 것
# 허쉬 미쓰에이 노래 아니 ## ## 허쉬 미쓰에이 노래 아니야
# 거기도 예약했주 했고 이 씽크대 놓인 인테리어 하는 거 이 ## ## 거기도 예약했지 했고 이 씽크대 놓인 인테리어 하는 거 이
# 옆에 누게 ## ## 옆에 누구야
# 예 맞수다 예 예 ## ## 예 맞아요 예 예
# 근데 다가와줬음 좋겐 ## ## 근데 다가와줬음 좋겠어
# 이제 아이들도 컹가믄 ## ## 이제 아이들도 커가면
# 그냥 고구마 쪄가지고 썰어기넹 뭐 말리면 될 거 아니우꽈 ## ## 그냥 고구마 쪄가지고 썰어서 뭐 말리면 될 거 아니에요
# 선생님이 너미 아이들 말을 잘 들어주기도 허고 ## ## 선생님이 너무 아이들 말을 잘 들어주기도 허고
# 어떵 살아신지 모를크라 ## ## 어떻게 살아신지 모르겠어
# 훔쳥 와선게 깨끗한 걸로 ## ## 훔치고 왔더라 깨끗한 걸로
#  맛 진짜 맛있더라 그치 나도 그건 맛 좋게 먹어 ## ##  맛 진짜 맛있더라 그렇지 나도 그건 맛 좋게 먹어
# 어릴 때 친구들끼리 막 얘기 할 때 막 그런 말 안써봔 ## ## 어릴 때 친구들끼리 막 얘기 할 때 막 그런 말 안써봤어
# 건디 나중에 그추룩 허젠허난 그 힘이 나오지 않어드랜예 ## ## 그런데 나중에 그렇게 하려하니 그 힘이 나오지 않았대요
# 신부상이연 뭐연 그런 것도 하지 말고 그냥 깔끔하게 ## ## 신부상이다 뭐다 그런 것도 하지 말고 그냥 깔끔하게
# 아 기 ## ## 아 진짜
# 너가 회장 해불라 허는거라 ## ## 너가 회장 해버려랴 하는거야
# 근데 뭐 다른 것도이 내가 뭐 방언 약간 방언학이면 방언학의 정의 같은 게 시험에 잘 안 나와 원래 ## ## 근데 뭐 다른 것도 내가 뭐 방언 약간 방언학이면 방언학의 정의 같은 게 시험에 잘 안 나와 원래
# 이게 그러니까 형이 공부를 잘핸예 ## ## 이게 그러니까 형이 공부를 잘했어요
# 모 몸이 내가 더 앞이네 ## ## 모 몸이 내가 더 앞이잖아
# 요즘 걔 누구냐 가이 ## ## 요즘 걔 누구냐 걔
# 얘 어제 우리집 앞에서 담배 네갑 내가 갖고 있는 거 다  ## ## 이아이 어제 우리집 앞에서 담배 네갑 내가 갖고 있는 거 다
# 야이 친구한테 ## ## 얘 친구한테
# 안 가크라 겅 해도 ## ## 안 가겠다 그리 해도
# 뭐뭐 할타가 난 너무 충격적 이연 ## ## 뭐뭐 할타가 난 너무 충격적 이였어
# 아 나 여기 어디 들릴 데 이성왔당 걸으맨허고이 ## ## 아 나 여기 어디 들릴 데 있어서왔다가 걷고있어하고
# 먹고정헌것만 고라보라 먹고정헌것만 고라보라허난 ## ## 먹고싶은것만 말해보라 먹고싶은것만 말해보라하니까
# 거기에 탁자에 다 차지행 이신거라 ## ## 거기에 탁자에 다 차지하고 있는거야
# 저기 어머니 나이가게 백 살 다 돼 가는데 거 ## ## 저기 어머니 나이가 백 살 다 돼 가는데 그거
# 난 그냥 그때 막 만 구천 팔백 원 채워서 사 사버리는디 ## ## 난 그냥 그때 엄청 만 구천 팔백 원 채워서 사 사버리는데
# 우린예 ## ## 우린요
# 나도 바로 왜 저기 서사라 사거리 그 거기 뒤에  살암신디 ## ## 나도 바로 왜 저기 서사라 사거리 그 거기 뒤에  사는데
# 음 한라수목원 이쪽에 있는데이 ## ## 음 한라수목원 이쪽에 있는데
# 겅해그넨 저기 뭐야 혼자도 있을 때도 또 눕고 여자친구 집에 가면 또 눕고 ## ## 그러면서 저기 뭐야 혼자도 있을 때도 또 눕고 여자친구 집에 가면 또 눕고
# 떨려가지구 아 선생님 못 할 것 같은데요 ## ## 떨려서 아 선생님 못 할 것 같은데요
# 근데 맨날 겅 겅 얘기한다난니까 뭐 현차장님 많이 바빠 보인다 남주임님 많이 도와달라 ## ## 근데 맨날 그렇게 그렇게 얘기한다난니까 뭐 현차장님 많이 바빠 보인다 남주임님 많이 도와달라
# 허영 수업 받으러 오라 영허멍 교장선 ## ## 하고 수업 받으러 와라 이렇게하면서 교장선
# 아니 나 요새 안하고 인 ## ## 아니 나 요새 안하고 있어
# 모르난 물어보는디  ## ## 모르니까 물어보는데
# 기지예 ## ## 그치요
# 참 그난이 그 비법 하나만큼은 이제만큼도 진짜 그거는 신기해 ## ## 참 그니까 그 비법 하나만큼은 이제만큼도 진짜 그거는 신기해
# 이천이십년을 맞이해서는 제 십육회 사단법인 제주영화제 그 페스티벌을 막 재미나게 진행 했수다 ## ## 이천이십년을 맞이해서는 제 십육회 사단법인 제주영화제 그 페스티벌을 막 재미있게 진행 했어요
# 아니 겨울에 심해질거랜 해신디 ## ## 아니 겨울에 심해질꺼라 했는데
# 어디 토익 학원 다닐꺼 같이 다니잰 ## ## 어디 토익 학원 다닐꺼 같이 다닐래
# 아 살다가 나완 ## ## 아 살다가 나왔어
# 성님 성님 성님 서춘 성님 시집살이가 어떵 헙디가 ## ## 형님 형님 형님 서춘 형님 시집살이가 어떻게 합니까
# 어 맞아 어떻게 알안 ## ## 어 맞아 어떻게 알았어
# 아 이거 진짜 바닷가에도 그냥 버려불고이 ## ## 아 이거 진짜 바닷가에도 그냥 버려버리고
# 닭가슴살도 주문 해서 ## ## 닭가슴살도 주문 했어

# %%
class PairedDataset:
    def __init__(self, src_tokenizer, tgt_tokenizer,file_standard , file_dialect):
        self.src_tokenizer = src_tokenizer
        self.trg_tokenizer = tgt_tokenizer
        self.data_s = file_standard
        self.data_d = file_dialect
        self.data = [[self.data_s[i],self.data_d[i]] for i in range(len(self.data_s)) ]
    def __getitem__(self, index):
        src, trg = self.data_s[index] , self.data_d[index]
        embeddings = self.src_tokenizer(src, return_attention_mask=False, return_token_type_ids=False)
        embeddings['labels'] = self.trg_tokenizer(trg, return_attention_mask=False)['input_ids']

        return embeddings

    def __len__(self):
        return len(self.data)

# %%
train_s ,train_d , valid_s , valid_d = read_input("/content/drive/MyDrive/WARNING_PRIVATE_FOLDER/OSSP2AntiGPT9/ai/no_commit/real_data.json")
dataset = PairedDataset(src_tokenizer, trg_tokenizer, train_d , train_s)
eval_dataset = PairedDataset(src_tokenizer, trg_tokenizer, valid_d , valid_s)
# Out:
#   0%|          | 0/1220349 [00:00<?, ?it/s]
#   0%|          | 0/12326 [00:00<?, ?it/s]

# %% [markdown]
# ## 사전학습 모델 불러오기

# %%
model = EncoderDecoderModel.from_pretrained('leadawon/ossp-v0_2')
model
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/5.27k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/1.02G [00:00<?, ?B/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/132 [00:00<?, ?B/s]
# EncoderDecoderModel(
#   (encoder): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(12291, 768, padding_idx=1)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (decoder): GPT2LMHeadModel(
#     (transformer): GPT2Model(
#       (wte): Embedding(51200, 768)
#       (wpe): Embedding(1024, 768)
#       (drop): Dropout(p=0.1, inplace=False)
#       (h): ModuleList(
#         (0-11): 12 x GPT2Block(
#           (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (attn): GPT2Attention(
#             (c_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.1, inplace=False)
#             (resid_dropout): Dropout(p=0.1, inplace=False)
#           )
#           (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (crossattention): GPT2Attention(
#             (c_attn): Conv1D()
#             (q_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.1, inplace=False)
#             (resid_dropout): Dropout(p=0.1, inplace=False)
#           )
#           (ln_cross_attn): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): GPT2MLP(
#             (c_fc): Conv1D()
#             (c_proj): Conv1D()
#             (act): NewGELUActivation()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (ln_f): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     )
#     (lm_head): Linear(in_features=768, out_features=51200, bias=False)
#   )
# )

# %% [markdown]
# ## 학습 코드

# %%
# !pwd
# Out:
# /content

# %%
collator = DataCollatorForSeq2Seq(src_tokenizer, model)

arguments = Seq2SeqTrainingArguments(
    output_dir='ossp-v0_3',
    do_train=True,
    do_eval=True,
    evaluation_strategy="steps",
    eval_steps=10000,
    save_strategy="steps",
    save_steps=10000,
    num_train_epochs=4,
    per_device_train_batch_size=24,
    per_device_eval_batch_size=24,
    warmup_ratio=0.1,
    gradient_accumulation_steps=1,
    save_total_limit=1,
    dataloader_num_workers=1,
    fp16=True,
    load_best_model_at_end=True,
    push_to_hub=True,
    learning_rate = 5e-5
)

trainer = Seq2SeqTrainer(
    model,
    arguments,
    data_collator=collator,
    train_dataset=dataset,
    eval_dataset=eval_dataset
)
# Out:
# Cloning https://huggingface.co/leadawon/ossp-v0_3 into local empty directory.
# WARNING:huggingface_hub.repository:Cloning https://huggingface.co/leadawon/ossp-v0_3 into local empty directory.

# %%
trainer.train()

model.save_pretrained("ossp-v0_3/best_model")
# Out:
# /usr/local/lib/python3.9/dist-packages/transformers/optimization.py:391: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:634: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
#     <div>
#
#       <progress value='203392' max='203392' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [203392/203392 13:44:39, Epoch 4/4]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10000</td>
#       <td>0.399900</td>
#       <td>0.407919</td>
#     </tr>
#     <tr>
#       <td>20000</td>
#       <td>0.444100</td>
#       <td>0.455541</td>
#     </tr>
#     <tr>
#       <td>30000</td>
#       <td>0.436100</td>
#       <td>0.437814</td>
#     </tr>
#     <tr>
#       <td>40000</td>
#       <td>0.430200</td>
#       <td>0.425534</td>
#     </tr>
#     <tr>
#       <td>50000</td>
#       <td>0.439200</td>
#       <td>0.407628</td>
#     </tr>
#     <tr>
#       <td>60000</td>
#       <td>0.371400</td>
#       <td>0.400630</td>
#     </tr>
#     <tr>
#       <td>70000</td>
#       <td>0.369400</td>
#       <td>0.390813</td>
#     </tr>
#     <tr>
#       <td>80000</td>
#       <td>0.359100</td>
#       <td>0.380976</td>
#     </tr>
#     <tr>
#       <td>90000</td>
#       <td>0.359400</td>
#       <td>0.376197</td>
#     </tr>
#     <tr>
#       <td>100000</td>
#       <td>0.356700</td>
#       <td>0.366661</td>
#     </tr>
#     <tr>
#       <td>110000</td>
#       <td>0.304100</td>
#       <td>0.366276</td>
#     </tr>
#     <tr>
#       <td>120000</td>
#       <td>0.299000</td>
#       <td>0.360299</td>
#     </tr>
#     <tr>
#       <td>130000</td>
#       <td>0.297200</td>
#       <td>0.356883</td>
#     </tr>
#     <tr>
#       <td>140000</td>
#       <td>0.289200</td>
#       <td>0.351852</td>
#     </tr>
#     <tr>
#       <td>150000</td>
#       <td>0.284400</td>
#       <td>0.346317</td>
#     </tr>
#     <tr>
#       <td>160000</td>
#       <td>0.237200</td>
#       <td>0.352225</td>
#     </tr>
#     <tr>
#       <td>170000</td>
#       <td>0.236700</td>
#       <td>0.350815</td>
#     </tr>
#     <tr>
#       <td>180000</td>
#       <td>0.229500</td>
#       <td>0.348893</td>
#     </tr>
#     <tr>
#       <td>190000</td>
#       <td>0.228100</td>
#       <td>0.346798</td>
#     </tr>
#     <tr>
#       <td>200000</td>
#       <td>0.223300</td>
#       <td>0.345087</td>
#     </tr>
#   </tbody>
# </table><p>
# /usr/local/lib/python3.9/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:634: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# /usr/local/lib/python3.9/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:634: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# /usr/local/lib/python3.9/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:634: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# /usr/local/lib/python3.9/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:634: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# /usr/local/lib/python3.9/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:634: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# /usr/local/lib/python3.9/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:634: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# /usr/local/lib/python3.9/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:634: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# /usr/local/lib/python3.9/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:634: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# /usr/local/lib/python3.9/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:634: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# /usr/local/lib/python3.9/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:634: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# /usr/local/lib/python3.9/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:634: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# /usr/local/lib/python3.9/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:634: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# /usr/local/lib/python3.9/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:634: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# /usr/local/lib/python3.9/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:634: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# /usr/local/lib/python3.9/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:634: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# /usr/local/lib/python3.9/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:634: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# /usr/local/lib/python3.9/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:634: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# /usr/local/lib/python3.9/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:634: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# /usr/local/lib/python3.9/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:634: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# /usr/local/lib/python3.9/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:634: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)

# %%
trainer.push_to_hub()
# Out:
# Upload file runs/Apr15_07-08-36_7aeb1107af9b/events.out.tfevents.1681542544.7aeb1107af9b.2538.0:  41%|####1   …
# To https://huggingface.co/leadawon/ossp-v0_3
#    6996d30..2735f58  main -> main
#
# WARNING:huggingface_hub.repository:To https://huggingface.co/leadawon/ossp-v0_3
#    6996d30..2735f58  main -> main
#
# To https://huggingface.co/leadawon/ossp-v0_3
#    2735f58..590ea18  main -> main
#
# WARNING:huggingface_hub.repository:To https://huggingface.co/leadawon/ossp-v0_3
#    2735f58..590ea18  main -> main
# 'https://huggingface.co/leadawon/ossp-v0_3/commit/2735f58d0956308850a445d4dcdf4c64c53cf949'
